# %%
### IMPORTS

import math
import numpy
import scipy,scipy.optimize,scipy.spatial,scipy.spatial.distance,scipy.stats
import json
import sqlite3
from collections import *
from enum import Enum
numpy.random.seed(1)

# %%
### CONSTANTS

# Names of goods
Goods = ["Credits","Grain","Food","Fuel","Diamonds","null"]

def createInventory(credits=0,grain=0,food=0,fuel=0,diamonds=0):
    return numpy.array([credits,grain,food,fuel,diamonds,0])

# %%
class BoundedAdaptiveNormalDistribution:
    NumSamples = 1000
    
    def __init__(self, mean, variance, lower=None, upper=None):
        self.mean = mean
        self.variance = variance
        self.lower = lower
        self.upper = upper
        
    def __repr__(self):
        return str(self.mean) + str(",") + str(math.sqrt(self.variance))
        
    def draw(self):
        while True:
            value = scipy.stats.norm.rvs(loc=self.mean, scale=self.variance)
            if self.lower and self.lower > value:
                continue
            if self.upper and self.upper < value:
                continue
            return value
        
    def update(self,newValue):
        NumSamples = BoundedAdaptiveNormalDistribution.NumSamples
        oldMean = self.mean;
        self.mean = ((self.mean * (NumSamples - 1)) + newValue) / NumSamples
        self.variance = (self.variance*(NumSamples-1) + ((newValue - oldMean)*(newValue - self.mean))) / NumSamples;

class Agent:
    def __init__(self, loc):
        self.loc = numpy.copy(loc)
        
    def __repr__(self):
        return self.__dict__.__repr__()

class Trader(Agent):
    def __init__(self, loc):
        Agent.__init__(self, loc)
        self.inventory = numpy.copy(createInventory(credits=1000))

class Factory(Trader):
    def __init__(self,loc,productionCost,output,capacity):
        Trader.__init__(self,loc)
        self.productionCost = numpy.copy(productionCost)
        self.output = numpy.copy(output)
        self.capacity = capacity
        self.demand = 0

    def getEpochsOfProduction(self):
        epochs = 100
        for i in range(0,len(self.productionCost)):
            if i == 0:
                continue # You can go negative in money with no penalty for now
            if self.productionCost[i] == 0:
                continue
            epochs = min(epochs, self.inventory[i] // self.productionCost[i] // self.capacity)
        return epochs
    
    def getCurrentProduction(self):
        currentProduction = self.capacity
        for i in range(0,len(self.productionCost)):
            if i == 0:
                continue # You can go negative in money with no penalty for now
            if self.productionCost[i] == 0:
                continue
            currentProduction = min(currentProduction, self.inventory[i] // self.productionCost[i])
        return currentProduction
    
    def produce(self):
        production = min(2,self.getCurrentProduction())
        self.inventory -= self.productionCost * production
        self.inventory += self.output * production
        

class Merchant(Trader):
    def __init__(self,loc):
        Trader.__init__(self,loc)

class Contract():
    def __init__(self,source,destination,good,quantity,pricePerUnit):
        self.source = source
        self.destination = destination
        self.good = good
        self.quantity = quantity
        self.pricePerUnit = pricePerUnit

# %%
## HELPER FUNCTIONS

def spawnLocation():
    return numpy.array([numpy.random.randint(0,100), numpy.random.randint(0,100)])

# %%
PlanetLocation = spawnLocation()
Factories = [
    # Farm: 1 credit -> 1 grain
    Factory(spawnLocation(), createInventory(credits=1), createInventory(grain=1), 100),
    
    # Bakery: 1 credit + 1 grain -> 1 food
    Factory(spawnLocation(), createInventory(credits=1, grain=1), createInventory(food=1), 100),
    
    # Oil rig: 5 credits -> 1 fuel
    Factory(spawnLocation(), createInventory(credits=5), createInventory(fuel=1), 100),
    
    # Diamond mine:  10 credits -> 1 diamond
    Factory(spawnLocation(), createInventory(credits=10), createInventory(diamonds=1), 100),
    
    # Planet: 1 food -> 10 credits, 1 fuel -> 40 credits, 1 diamond -> 160 credits
    Factory(PlanetLocation, createInventory(food=1), createInventory(credits=10), 100),
    Factory(PlanetLocation, createInventory(fuel=1), createInventory(credits=40), 50),
    Factory(PlanetLocation, createInventory(diamonds=1), createInventory(credits=160), 25),
]
Contracts = []

# Credits are always worth 1 credit with no variance
EstimatedPrices = [BoundedAdaptiveNormalDistribution(1,0)]
for x in range(1,len(Goods)):
    # All other goods have an unknown worth that we model with a normal distribution capped between [0,1000]
    # The mean & variance will change as people buy goods.
    EstimatedPrices.append(BoundedAdaptiveNormalDistribution(0,10,1,1000))

for epoch in range(0,1):
    for turn in range(0,10000):
        Contracts = []
        for i in range(0,1):
            # First, draw to estimate the prices of items
            prices = [1,]
            for i2 in range(1,len(Goods)):
                prices.append(EstimatedPrices[i2].draw())
            for f in Factories:
                currentProduction = f.getCurrentProduction()
                remainingProduction = f.capacity - currentProduction
                if remainingProduction > 0:
                    # Next, decide if more production makes sense given these prices
                    costValue = numpy.dot(f.productionCost,prices)
                    outputValue = numpy.dot(f.output,prices)
                    if costValue < outputValue:
                        # Try to find suppliers for missing goods
                        for goodToProduce in range(1,len(Goods)):
                            need = (f.productionCost[goodToProduce] * f.capacity) - f.inventory[goodToProduce]
                            if need > 0:
                                for supplier in Factories:
                                    if supplier.inventory[goodToProduce] > 0 and \
                                    supplier.productionCost[goodToProduce] == 0: # For now, don't buy from someone who needs the good in their production
                                        # Buy goods from supplier
                                        quantityToBuy = 1 # Don't try to max out in case your price estimate is bad
                                        #quantityToBuy = min(need, supplier.inventory[goodToProduce])
                                        f.inventory[goodToProduce] += quantityToBuy
                                        supplier.inventory[goodToProduce] -= quantityToBuy
                                        f.inventory[0] -= quantityToBuy * prices[goodToProduce]
                                        supplier.inventory[0] += quantityToBuy * prices[goodToProduce]
                                        Contracts.append(Contract(supplier,f,goodToProduce,quantityToBuy,prices[goodToProduce]))

        # Now, Produce when it makes sense
      
        # First, draw to estimate the prices of items
        prices = [1,]
        for i2 in range(1,len(Goods)):
            prices.append(EstimatedPrices[i2].draw())
        for f in Factories:
            # Next, decide if more production makes sense given these prices
            costValue = numpy.dot(f.productionCost,prices)
            outputValue = numpy.dot(f.output,prices)
            if costValue < outputValue:
                # Produce
                f.produce()

        # Based on the contracts, adjust the prices
        for c in Contracts:
            EstimatedPrices[c.good].update(c.pricePerUnit)
        
        # Some debug prints
        if turn % 10 == 0:
            newPrices = [1]
            for x in range(1,len(Goods)):
                newPrices.append(EstimatedPrices[c.good].mean)
            for c in Contracts:
                print("Updating from contract: ",Goods[c.good],c.pricePerUnit)
            print("New prices: ",EstimatedPrices)
            print("Factories")
            for f in Factories:
                print(f.inventory,"Valued at (based on MLE of price)",int(numpy.dot(f.inventory,newPrices)))
            print('done')
# Out:
# New prices:  [1,0.0, 0,3.1622776601683795, 0,3.1622776601683795, 0,3.1622776601683795, 0,3.1622776601683795, 0,3.1622776601683795]
# Factories
# [998   2   0   0   0   0] Valued at (based on MLE of price) 998
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# [990   0   0   2   0   0] Valued at (based on MLE of price) 990
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# done
# Updating from contract:  Grain 8.257816727925047
# Updating from contract:  Fuel 9.148416156361835
# New prices:  [1,0.0, 0.027678737596331885,3.196332798250743, 0.00760490152593594,3.1609588607145294, 0.08625691372030807,3.328647776259723, 0.03791838349200701,3.2020144293233566, 0,3.1622776601683795]
# Factories
# [1004   18    0    0    0    0] Valued at (based on MLE of price) 1005
# [973   1   0   0   0   0] Valued at (based on MLE of price) 973
# [1023    0    0    3    0    0] Valued at (based on MLE of price) 1023
# [956   0   0   0   2   0] Valued at (based on MLE of price) 956
# [1021    0    0    0    0    0] Valued at (based on MLE of price) 1021
# [1268    0    0    0    0    0] Valued at (based on MLE of price) 1268
# [1918    0    0    0    0    0] Valued at (based on MLE of price) 1918
# done
# Updating from contract:  Fuel 14.598560059155844
# Updating from contract:  Diamonds 12.44223221998659
# New prices:  [1,0.0, 0.044942328023346606,3.203948218946494, 0.0183847247696469,3.171554112866431, 0.1737512830851046,3.4849449292331007, 0.12098530361102663,3.345961709922009, 0,3.1622776601683795]
# Factories
# [999  34   0   0   0   0] Valued at (based on MLE of price) 1003
# [962   3   0   0   0   0] Valued at (based on MLE of price) 962
# [1037    0    0    7    0    0] Valued at (based on MLE of price) 1037
# [954   0   0   0   0   0] Valued at (based on MLE of price) 954
# [1029    0    0    0    0    0] Valued at (based on MLE of price) 1029
# [1574    0    0    0    0    0] Valued at (based on MLE of price) 1574
# [3430    0    0    0    0    0] Valued at (based on MLE of price) 3430
# done
# Updating from contract:  Food 1.9465744740218993
# Updating from contract:  Fuel 11.811894866298775
# Updating from contract:  Diamonds 8.449241329942888
# New prices:  [1,0.0, 0.06370019556599611,3.2182971826445037, 0.03210085527716283,3.1760334138435837, 0.31086934428579605,3.813602836254942, 0.13308512774041176,3.3550756247531157, 0,3.1622776601683795]
# Factories
# [997  51   0   0   0   0] Valued at (based on MLE of price) 1003
# [947   0   2   0   0   0] Valued at (based on MLE of price) 947
# [1080    0    0   15    0    0] Valued at (based on MLE of price) 1081
# [925   0   0   0   2   0] Valued at (based on MLE of price) 925
# [1053    0    0    0    0    0] Valued at (based on MLE of price) 1053
# [1831    0    0    0    0    0] Valued at (based on MLE of price) 1831
# [3737    0    0    0    0    0] Valued at (based on MLE of price) 3737
# done
# Updating from contract:  Fuel 8.947651104330623
# Updating from contract:  Diamonds 12.42246057349677
# New prices:  [1,0.0, 0.07582872712817151,3.2271994817984355, 0.04919711894996219,3.184961206196684, 0.4133161727429457,4.041845267219853, 0.19376351517591753,3.455665852904257, 0,3.1622776601683795]
# Factories
# [988  69   0   0   0   0] Valued at (based on MLE of price) 1001
# [948   0   0   0   0   0] Valued at (based on MLE of price) 948
# [1082    0    0   25    0    0] Valued at (based on MLE of price) 1086
# [924   0   0   0   1   0] Valued at (based on MLE of price) 924
# [1073    0    0    0    0    0] Valued at (based on MLE of price) 1073
# [2119    0    0    0    0    0] Valued at (based on MLE of price) 2119
# [4791    0    0    0    0    0] Valued at (based on MLE of price) 4791
# done
# Updating from contract:  Grain 12.316637334572386
# Updating from contract:  Fuel 17.3527946880821
# Updating from contract:  Diamonds 19.940488080049246
# New prices:  [1,0.0, 0.09907411619589733,3.2474241166501754, 0.061120780017230814,3.1929298182446115, 0.5851602934275529,4.468402109738632, 0.238812793761512,3.5272410089953037, 0,3.1622776601683795]
# Factories
# [990  84   0   0   0   0] Valued at (based on MLE of price) 1010
# [928   1   2   0   0   0] Valued at (based on MLE of price) 928
# [1174    0    0   31    0    0] Valued at (based on MLE of price) 1181
# [906   0   0   0   0   0] Valued at (based on MLE of price) 906
# [1080    0    0    0    0    0] Valued at (based on MLE of price) 1080
# [2337    0    0    0    0    0] Valued at (based on MLE of price) 2337
# [5862    0    0    0    0    0] Valued at (based on MLE of price) 5862
# done
# Updating from contract:  Grain 5.780795528680753
# Updating from contract:  Fuel 10.351333675805138
# Updating from contract:  Diamonds 4.49134752287837
# New prices:  [1,0.0, 0.11382571892612736,3.2513574136740995, 0.08196675060458829,3.199623204131519, 0.6945667676502285,4.689665455682174, 0.2786220056682397,3.5781783866380112, 0,3.1622776601683795]
# Factories
# [984 100   0   0   0   0] Valued at (based on MLE of price) 1011
# [925   2   0   0   0   0] Valued at (based on MLE of price) 925
# [1195    0    0   42    0    0] Valued at (based on MLE of price) 1206
# [864   0   0   0   3   0] Valued at (based on MLE of price) 864
# [1107    0    0    0    0    0] Valued at (based on MLE of price) 1107
# [2499    0    0    0    0    0] Valued at (based on MLE of price) 2499
# [6619    0    0    0    0    0] Valued at (based on MLE of price) 6619
# done
# Updating from contract:  Grain 9.803201384389752
# Updating from contract:  Fuel 8.235379034814574
# Updating from contract:  Diamonds 7.21258345498911
# New prices:  [1,0.0, 0.13400570112939492,3.266977955670706, 0.09301638049681678,3.201867542363211, 0.7748164719435008,4.800299211122, 0.35021071021279204,3.691371498548374, 0,3.1622776601683795]
# Factories
# [983 116   0   0   0   0] Valued at (based on MLE of price) 1023
# [907   1   2   0   0   0] Valued at (based on MLE of price) 908
# [1208    0    0   48    0    0] Valued at (based on MLE of price) 1224
# [874   0   0   0   2   0] Valued at (based on MLE of price) 874
# [1124    0    0    0    0    0] Valued at (based on MLE of price) 1124
# [2728    0    0    0    0    0] Valued at (based on MLE of price) 2728
# [7662    0    0    0    0    0] Valued at (based on MLE of price) 7662
# done
# Updating from contract:  Food 7.437152203702309
# Updating from contract:  Fuel 12.547430587631286
# Updating from contract:  Diamonds 11.883014297399999
# New prices:  [1,0.0, 0.1636206382611027,3.303819543310417, 0.11268803246804682,3.2082599830361493, 0.9424055267737684,5.1538607333941755, 0.4517352230008055,3.8964073971345625, 0,3.1622776601683795]
# Factories
# [991 132   0   0   0   0] Valued at (based on MLE of price) 1050
# [888   0   1   0   0   0] Valued at (based on MLE of price) 888
# [1278    0    0   59    0    0] Valued at (based on MLE of price) 1304
# [876   0   0   0   2   0] Valued at (based on MLE of price) 876
# [1160    0    0    0    0    0] Valued at (based on MLE of price) 1160
# [2909    0    0    0    0    0] Valued at (based on MLE of price) 2909
# [9150    0    0    0    0    0] Valued at (based on MLE of price) 9150
# done
# Updating from contract:  Fuel 16.605498177415082
# Updating from contract:  Diamonds 7.275936959059247
# New prices:  [1,0.0, 0.17608697904126586,3.309762020281156, 0.13125858128578288,3.2209920517752972, 1.0583103678661354,5.409782030645126, 0.565942882344289,4.164418928281846, 0,3.1622776601683795]
# Factories
# [982 149   0   0   0   0] Valued at (based on MLE of price) 1066
# [887   0   0   0   0   0] Valued at (based on MLE of price) 887
# [1308    0    0   70    0    0] Valued at (based on MLE of price) 1347
# [850   0   0   0   6   0] Valued at (based on MLE of price) 853
# [1180    0    0    0    0    0] Valued at (based on MLE of price) 1180
# [3062    0    0    0    0    0] Valued at (based on MLE of price) 3062
# [10626     0     0     0     0     0] Valued at (based on MLE of price) 10626
# done
# Updating from contract:  Fuel 2.2959875379207477
# Updating from contract:  Diamonds 6.058119618036783
# New prices:  [1,0.0, 0.1935294006419646,3.325129834010266, 0.14046249182046833,3.2211567481810066, 1.1961391842084352,5.69364356866702, 0.7092816668547495,4.496557724824094, 0,3.1622776601683795]
# Factories
# [979 166   0   0   0   0] Valued at (based on MLE of price) 1096
# [872   0   0   0   0   0] Valued at (based on MLE of price) 872
# [1352    0    0   81    0    0] Valued at (based on MLE of price) 1409
# [835   0   0   0  12   0] Valued at (based on MLE of price) 843
# [1199    0    0    0    0    0] Valued at (based on MLE of price) 1199
# [3269    0    0    0    0    0] Valued at (based on MLE of price) 3269
# [12071     0     0     0     0     0] Valued at (based on MLE of price) 12071
# done
# Updating from contract:  Grain 2.1698352370167933
# Updating from contract:  Fuel 32.92590775391487
# Updating from contract:  Diamonds 30.90985009082808
# New prices:  [1,0.0, 0.2163327461437743,3.354327591147106, 0.1495470164256461,3.227251361317637, 1.349955561991722,6.031065678867534, 0.8673433569294439,4.893842159315031, 0,3.1622776601683795]
# Factories
# [981 183   0   0   0   0] Valued at (based on MLE of price) 1139
# [853   1   0   0   0   0] Valued at (based on MLE of price) 853
# [1410    0    0   94    0    0] Valued at (based on MLE of price) 1491
# [876   0   0   0  14   0] Valued at (based on MLE of price) 888
# [1209    0    0    0    0    0] Valued at (based on MLE of price) 1209
# [3344    0    0    1    0    0] Valued at (based on MLE of price) 3344
# [13500     0     0     0     0     0] Valued at (based on MLE of price) 13500
# done
# Updating from contract:  Grain 4.017354164824421
# Updating from contract:  Fuel 16.65518801668929
# Updating from contract:  Diamonds 36.76020793836916
# New prices:  [1,0.0, 0.2644645886150645,3.4222722514865076, 0.16156800325923354,3.2330183711328004, 1.5567349673282889,6.421225755646232, 1.116372288871985,5.587166019401757, 0,3.1622776601683795]
# Factories
# [1008  198    0    0    0    0] Valued at (based on MLE of price) 1229
# [809   3   0   0   0   0] Valued at (based on MLE of price) 812
# [1535    0    0  102    0    0] Valued at (based on MLE of price) 1648
# [969   0   0   0  20   0] Valued at (based on MLE of price) 991
# [1225    0    0    0    0    0] Valued at (based on MLE of price) 1225
# [3559    0    0    0    0    0] Valued at (based on MLE of price) 3559
# [14837     0     0     0     0     0] Valued at (based on MLE of price) 14837
# done
# Updating from contract:  Grain 9.894279178792226
# Updating from contract:  Fuel 22.119635115458003
# Updating from contract:  Diamonds 10.877277488954803
# New prices:  [1,0.0, 0.28576150038120895,3.4449552620935546, 0.18239675363013097,3.2434917876488014, 1.6806148906817688,6.5902673879256195, 1.3302900625904566,6.140940816830221, 0,3.1622776601683795]
# Factories
# [1009  215    0    0    0    0] Valued at (based on MLE of price) 1295
# [801   2   0   0   0   0] Valued at (based on MLE of price) 803
# [1568    0    0  114    0    0] Valued at (based on MLE of price) 1719
# [1048    0    0    0   24    0] Valued at (based on MLE of price) 1079
# [1241    0    0    0    0    0] Valued at (based on MLE of price) 1241
# [3698    0    0    1    0    0] Valued at (based on MLE of price) 3699
# [16208     0     0     0     0     0] Valued at (based on MLE of price) 16208
# done
# Updating from contract:  Food 1.1988503323150599
# Updating from contract:  Fuel 16.988532262006693
# Updating from contract:  Diamonds 74.55052637974364
# New prices:  [1,0.0, 0.3140703292048311,3.459773103508742, 0.20011659795876738,3.2525495387787062, 1.792092488825024,6.712309302720599, 1.8569630120835345,8.836287424108043, 0,3.1622776601683795]
# Factories
# [1016  229    0    0    0    0] Valued at (based on MLE of price) 1441
# [777   0   4   0   0   0] Valued at (based on MLE of price) 784
# [1599    0    0  124    0    0] Valued at (based on MLE of price) 1829
# [1426    0    0    0   30    0] Valued at (based on MLE of price) 1481
# [1260    0    0    0    0    0] Valued at (based on MLE of price) 1260
# [3889    0    0    1    0    0] Valued at (based on MLE of price) 3890
# [17260     0     0     0     0     0] Valued at (based on MLE of price) 17260
# done
# Updating from contract:  Grain 4.088847394420169
# Updating from contract:  Diamonds 120.48026890435314
# New prices:  [1,0.0, 0.3256558964783138,3.4610766148761414, 0.22850453540621074,3.268357904446763, 1.8836880316177826,6.82580833413492, 2.453958693849997,11.516551395269788, 0,3.1622776601683795]
# Factories
# [1007  246    0    0    0    0] Valued at (based on MLE of price) 1610
# [787   1   0   0   0   0] Valued at (based on MLE of price) 789
# [1609    0    0  136    0    0] Valued at (based on MLE of price) 1942
# [1879    0    0    0   37    0] Valued at (based on MLE of price) 1969
# [1288    0    0    0    0    0] Valued at (based on MLE of price) 1288
# [4063    0    0    0    0    0] Valued at (based on MLE of price) 4063
# [18078     0     0     0     0     0] Valued at (based on MLE of price) 18078
# done
# Updating from contract:  Grain 1.7226951091072529
# Updating from contract:  Diamonds 14.248501147983145
# New prices:  [1,0.0, 0.35077182914597943,3.4761269876922416, 0.24299024083729476,3.275117323383, 1.979802169338708,7.048868821686817, 2.911007718617536,13.227950980754379, 0,3.1622776601683795]
# Factories
# [1011  261    0    0    0    0] Valued at (based on MLE of price) 1770
# [767   1   2   0   0   0] Valued at (based on MLE of price) 775
# [1609    0    0  153    0    0] Valued at (based on MLE of price) 2054
# [2150    0    0    0   50    0] Valued at (based on MLE of price) 2295
# [1301    0    0    0    0    0] Valued at (based on MLE of price) 1301
# [4080    0    0    0    0    0] Valued at (based on MLE of price) 4080
# [18560     0     0     0     1     0] Valued at (based on MLE of price) 18562
# done
# Updating from contract:  Food 1.5204417864660122
# Updating from contract:  Diamonds 124.92212644216235
# New prices:  [1,0.0, 0.3695412548345176,3.484377585036211, 0.2846271612561128,3.3088496454845866, 2.037360056312623,7.1328786399113575, 3.5188738116572256,15.547237654527605, 0,3.1622776601683795]
# Factories
# [1009  277    0    0    0    0] Valued at (based on MLE of price) 1983
# [779   0   0   0   0   0] Valued at (based on MLE of price) 779
# [1582    0    0  167    0    0] Valued at (based on MLE of price) 2169
# [2576    0    0    0   63    0] Valued at (based on MLE of price) 2797
# [1325    0    0    0    0    0] Valued at (based on MLE of price) 1325
# [4173    0    0    0    0    0] Valued at (based on MLE of price) 4173
# [19207     0     0     0     0     0] Valued at (based on MLE of price) 19207
# done
# Updating from contract:  Food 2.017991750667418
# Updating from contract:  Fuel 7.038472474116301
# New prices:  [1,0.0, 0.4036362546591461,3.5236934208828985, 0.2967041730740206,3.3107788411048418, 2.1387565624086946,7.2440594094959545, 3.8299328322676454,16.216199222313538, 0,3.1622776601683795]
# Factories
# [1022  292    0    0    0    0] Valued at (based on MLE of price) 1646
# [748   0   1   0   0   0] Valued at (based on MLE of price) 750
# [1594    0    0  181    0    0] Valued at (based on MLE of price) 1981
# [2706    0    0    0   77    0] Valued at (based on MLE of price) 2870
# [1339    0    1    0    0    0] Valued at (based on MLE of price) 1341
# [4295    0    0    0    0    0] Valued at (based on MLE of price) 4295
# [19831     0     0     0     0     0] Valued at (based on MLE of price) 19831
# done
# New prices:  [1,0.0, 0.41685880783411944,3.5292776754950856, 0.3096714525309152,3.3196630466141746, 2.2437648528550946,7.385432670366746, 4.078917655533504,17.15463393157874, 0,3.1622776601683795]
# Factories
# [1014  309    0    0    0    0] Valued at (based on MLE of price) 1707
# [743   0   1   0   0   0] Valued at (based on MLE of price) 745
# [1628    0    0  192    0    0] Valued at (based on MLE of price) 2058
# [2782    0    0    0   93    0] Valued at (based on MLE of price) 2990
# [1363    0    0    0    0    0] Valued at (based on MLE of price) 1363
# [4376    0    0    0    0    0] Valued at (based on MLE of price) 4376
# [19893     0     0     0     0     0] Valued at (based on MLE of price) 19893
# done
# Updating from contract:  Fuel 14.032357686354217
# New prices:  [1,0.0, 0.4402816262652295,3.5396405056354268, 0.32706206121625814,3.339039258432363, 2.3151087945557127,7.459507645862609, 4.128309290896704,17.185022585796457, 0,3.1622776601683795]
# Factories
# [1017  324    0    0    0    0] Valued at (based on MLE of price) 1767
# [728   1   3   0   0   0] Valued at (based on MLE of price) 737
# [1619    0    0  205    0    0] Valued at (based on MLE of price) 2093
# [2639    0    0    0  111    0] Valued at (based on MLE of price) 2895
# [1364    0    0    0    0    0] Valued at (based on MLE of price) 1364
# [4450    0    0    1    0    0] Valued at (based on MLE of price) 4452
# [19994     0     0     0     1     0] Valued at (based on MLE of price) 19996
# done
# Updating from contract:  Grain 4.809801919577002
# New prices:  [1,0.0, 0.47422100716133264,3.5609235269564508, 0.3495315655247099,3.3528831568876707, 2.42535549243072,7.606049941627009, 4.195354701186725,17.306653871473138, 0,3.1622776601683795]
# Factories
# [1032  337    0    0    0    0] Valued at (based on MLE of price) 1191
# [707   6   0   0   0   0] Valued at (based on MLE of price) 709
# [1643    0    0  218    0    0] Valued at (based on MLE of price) 1746
# [2530    0    0    0  128    0] Valued at (based on MLE of price) 2590
# [1386    0    0    0    0    0] Valued at (based on MLE of price) 1386
# [4479    0    0    4    0    0] Valued at (based on MLE of price) 4480
# [20242     0     0     0     0     0] Valued at (based on MLE of price) 20242
# done
# Updating from contract:  Food 1.8480626711372032
# New prices:  [1,0.0, 0.4831740673067373,3.5603456287977986, 0.35221081597236287,3.3500726806128953, 2.4845040144160015,7.677055090878415, 4.5885071593556255,18.188296644476633, 0,3.1622776601683795]
# Factories
# [1021  354    0    0    0    0] Valued at (based on MLE of price) 1145
# [693   5   2   0   0   0] Valued at (based on MLE of price) 695
# [1613    0    0  233    0    0] Valued at (based on MLE of price) 1695
# [2766    0    0    0  140    0] Valued at (based on MLE of price) 2815
# [1392    0    1    0    0    0] Valued at (based on MLE of price) 1392
# [4724    0    0    1    0    0] Valued at (based on MLE of price) 4724
# [20780     0     0     0     0     0] Valued at (based on MLE of price) 20780
# done
# Updating from contract:  Grain 1.7430916927002926
# Updating from contract:  Food 7.134143437289985
# Updating from contract:  Diamonds 105.69769322972874
# New prices:  [1,0.0, 0.5222229853071473,3.627580799351762, 0.38010582687505784,3.3666986527545273, 2.5442250438087513,7.778722492398311, 5.188919270467233,19.899352772024766, 0,3.1622776601683795]
# Factories
# [1041  369    0    0    0    0] Valued at (based on MLE of price) 2955
# [666   0   7   0   0   0] Valued at (based on MLE of price) 702
# [1589    0    0  248    0    0] Valued at (based on MLE of price) 2875
# [3193    0    0    0  154    0] Valued at (based on MLE of price) 3992
# [1409    0    1    0    0    0] Valued at (based on MLE of price) 1414
# [4815    0    0    0    0    0] Valued at (based on MLE of price) 4815
# [20147     0     0     0     6     0] Valued at (based on MLE of price) 20178
# done
# Updating from contract:  Grain 8.72687782021068
# Updating from contract:  Diamonds 94.30476456176933
# New prices:  [1,0.0, 0.5544118133916197,3.647578775859689, 0.4102690198642404,3.386978824854839, 2.6139011667521754,7.826562512546507, 5.604961655548795,21.01970937472626, 0,3.1622776601683795]
# Factories
# [1054  384    0    0    0    0] Valued at (based on MLE of price) 3206
# [653   0   6   0   0   0] Valued at (based on MLE of price) 686
# [1591    0    0  258    0    0] Valued at (based on MLE of price) 3037
# [3429    0    0    0  170    0] Valued at (based on MLE of price) 4381
# [1443    0    0    0    0    0] Valued at (based on MLE of price) 1443
# [4967    0    0    0    0    0] Valued at (based on MLE of price) 4967
# [20667     0     0     0     4     0] Valued at (based on MLE of price) 20689
# done
# Updating from contract:  Grain 1.5150102382822068
# Updating from contract:  Fuel 1.7764334891218372
# New prices:  [1,0.0, 0.5643952700424479,3.6372418279760277, 0.4429374014083429,3.4120601159615207, 2.685405770662678,7.938720246558386, 5.778319770560246,21.461839751969755, 0,3.1622776601683795]
# Factories
# [1044  397    0    0    0    0] Valued at (based on MLE of price) 2110
# [662   1   7   0   0   0] Valued at (based on MLE of price) 683
# [1571    0    0  274    0    0] Valued at (based on MLE of price) 2306
# [3418    0    0    0  187    0] Valued at (based on MLE of price) 3920
# [1456    0    0    0    0    0] Valued at (based on MLE of price) 1456
# [4963    0    0    2    0    0] Valued at (based on MLE of price) 4968
# [20795     0     0     0     5     0] Valued at (based on MLE of price) 20808
# done
# Updating from contract:  Food 6.580400297181471
# New prices:  [1,0.0, 0.5769674041174122,3.6397793205659768, 0.47054013715637466,3.4293895615120555, 2.788138327808557,8.128992410510714, 6.080477050836976,22.162196363692868, 0,3.1622776601683795]
# Factories
# [1036  414    0    0    0    0] Valued at (based on MLE of price) 1230
# [670   0   6   0   0   0] Valued at (based on MLE of price) 672
# [1596    0    0  287    0    0] Valued at (based on MLE of price) 1731
# [3542    0    0    0  203    0] Valued at (based on MLE of price) 3637
# [1464    0    1    0    0    0] Valued at (based on MLE of price) 1464
# [5123    0    0    0    0    0] Valued at (based on MLE of price) 5123
# [21907     0     0     0     0     0] Valued at (based on MLE of price) 21907
# done
# Updating from contract:  Food 3.0600229033323645
# New prices:  [1,0.0, 0.6003110525731209,3.6667221213619, 0.49359632033806045,3.441818142264049, 2.8294471661795755,8.16937565642777, 6.146828460278069,22.2302677174401, 0,3.1622776601683795]
# Factories
# [1040  430    0    0    0    0] Valued at (based on MLE of price) 1252
# [661   0   5   0   0   0] Valued at (based on MLE of price) 663
# [1554    0    0  302    0    0] Valued at (based on MLE of price) 1703
# [3420    0    0    0  221    0] Valued at (based on MLE of price) 3529
# [1476    0    2    0    0    0] Valued at (based on MLE of price) 1476
# [5112    0    0    2    0    0] Valued at (based on MLE of price) 5112
# [22147     0     0     0     0     0] Valued at (based on MLE of price) 22147
# done
# Updating from contract:  Food 5.918566313547642
# Updating from contract:  Fuel 19.711488930232754
# New prices:  [1,0.0, 0.6144237126482752,3.671864314443099, 0.5234283067226398,3.4616715675182173, 2.8980152461688355,8.256656985893246, 6.529787231556073,23.110035093800725, 0,3.1622776601683795]
# Factories
# [1034  447    0    0    0    0] Valued at (based on MLE of price) 2329
# [670   0   3   0   0   0] Valued at (based on MLE of price) 678
# [1533    0    0  317    0    0] Valued at (based on MLE of price) 2451
# [3632    0    0    0  236    0] Valued at (based on MLE of price) 4315
# [1502    0    1    0    0    0] Valued at (based on MLE of price) 1504
# [5308    0    0    0    0    0] Valued at (based on MLE of price) 5308
# [22530     0     0     0     0     0] Valued at (based on MLE of price) 22530
# done
# Updating from contract:  Food 1.323364287607946
# Updating from contract:  Fuel 8.054769591675894
# New prices:  [1,0.0, 0.6431512444400189,3.698717256530752, 0.5437706722102984,3.4651796924772817, 2.9828804656932184,8.393968618445639, 6.6719444898393485,23.531428467290294, 0,3.1622776601683795]
# Factories
# [1042  463    0    0    0    0] Valued at (based on MLE of price) 2423
# [655   0   1   0   0   0] Valued at (based on MLE of price) 657
# [1527    0    0  333    0    0] Valued at (based on MLE of price) 2520
# [3580    0    0    0  255    0] Valued at (based on MLE of price) 4340
# [1545    0    0    0    0    0] Valued at (based on MLE of price) 1545
# [5290    0    0    2    0    0] Valued at (based on MLE of price) 5295
# [22541     0     0     0     0     0] Valued at (based on MLE of price) 22541
# done
# Updating from contract:  Grain 2.154892481966022
# Updating from contract:  Food 3.64543144658564
# New prices:  [1,0.0, 0.6511687914714072,3.6941317476625395, 0.5599999607190022,3.473661336743821, 3.0122775433064226,8.441064769465239, 6.789738605611705,23.812517209282376, 0,3.1622776601683795]
# Factories
# [1032  479    0    0    0    0] Valued at (based on MLE of price) 1300
# [654   1   0   0   0   0] Valued at (based on MLE of price) 654
# [1459    0    0  352    0    0] Valued at (based on MLE of price) 1656
# [3504    0    0    0  274    0] Valued at (based on MLE of price) 3657
# [1565    0    0    0    0    0] Valued at (based on MLE of price) 1565
# [5377    0    0    0    0    0] Valued at (based on MLE of price) 5377
# [22576     0     0     0     0     0] Valued at (based on MLE of price) 22576
# done
# Updating from contract:  Fuel 19.168057553242857
# New prices:  [1,0.0, 0.7018608349131173,3.776865633356028, 0.5678772289502433,3.4756939113134484, 3.029043941437688,8.444043592727908, 6.946591304332494,24.097508723766786, 0,3.1622776601683795]
# Factories
# [1064  494    0    0    0    0] Valued at (based on MLE of price) 2560
# [600   1   3   0   0   0] Valued at (based on MLE of price) 612
# [1394    0    0  367    0    0] Valued at (based on MLE of price) 2505
# [3473    0    0    0  292    0] Valued at (based on MLE of price) 4357
# [1565    0    1    0    0    0] Valued at (based on MLE of price) 1568
# [5349    0    0    3    0    0] Valued at (based on MLE of price) 5358
# [22725     0     0     0     0     0] Valued at (based on MLE of price) 22725
# done
# Updating from contract:  Food 9.119493446377309
# Updating from contract:  Diamonds 54.85378965401609
# New prices:  [1,0.0, 0.7420240870336243,3.8039460174383506, 0.5833701114780725,3.4851139333726415, 3.097551000966425,8.542994718979463, 7.125073967981026,24.3172499505454, 0,3.1622776601683795]
# Factories
# [1085  508    0    0    0    0] Valued at (based on MLE of price) 4704
# [564   2   5   0   0   0] Valued at (based on MLE of price) 613
# [1371    0    0  384    0    0] Valued at (based on MLE of price) 4107
# [3471    0    0    0  309    0] Valued at (based on MLE of price) 5672
# [1586    0    0    0    0    0] Valued at (based on MLE of price) 1586
# [5469    0    0    1    0    0] Valued at (based on MLE of price) 5476
# [22684     0     0     0     2     0] Valued at (based on MLE of price) 22698
# done
# Updating from contract:  Food 8.492853907797288
# New prices:  [1,0.0, 0.7570932054806836,3.822933194088165, 0.6123033501537983,3.494637461565655, 3.2010150661115104,8.68083649638151, 7.32107641618577,24.609391421184363, 0,3.1622776601683795]
# Factories
# [1081  525    0    0    0    0] Valued at (based on MLE of price) 1402
# [570   0   3   0   0   0] Valued at (based on MLE of price) 571
# [1388    0    0  399    0    0] Valued at (based on MLE of price) 1632
# [3488    0    0    0  326    0] Valued at (based on MLE of price) 3687
# [1619    0    0    0    0    0] Valued at (based on MLE of price) 1619
# [5587    0    0    0    0    0] Valued at (based on MLE of price) 5587
# [23104     0     0     0     1     0] Valued at (based on MLE of price) 23104
# done
# Updating from contract:  Food 4.248218887981581
# Updating from contract:  Fuel 9.24230803075999
# New prices:  [1,0.0, 0.7682081020761863,3.818477588939735, 0.6403713215264732,3.506613026378945, 3.3124079701403217,8.82197402549293, 7.332465149155271,24.59971742744931, 0,3.1622776601683795]
# Factories
# [1074  540    0    0    0    0] Valued at (based on MLE of price) 2862
# [577   1   1   0   0   0] Valued at (based on MLE of price) 583
# [1419    0    0  412    0    0] Valued at (based on MLE of price) 2783
# [3306    0    0    0  345    0] Valued at (based on MLE of price) 4448
# [1634    0    1    0    0    0] Valued at (based on MLE of price) 1637
# [5689    0    0    1    0    0] Valued at (based on MLE of price) 5692
# [23405     0     0     0     0     0] Valued at (based on MLE of price) 23405
# done
# Updating from contract:  Grain 12.769419305957081
# New prices:  [1,0.0, 0.8066369387345916,3.8424783995330514, 0.6595099821263916,3.515933292221376, 3.354167605127077,8.848925620816793, 7.401716602456223,24.684649469525645, 0,3.1622776601683795]
# Factories
# [1094  553    0    0    0    0] Valued at (based on MLE of price) 1540
# [542   0   5   0   0   0] Valued at (based on MLE of price) 546
# [1372    0    0  428    0    0] Valued at (based on MLE of price) 1717
# [3182    0    0    0  364    0] Valued at (based on MLE of price) 3475
# [1660    0    0    0    0    0] Valued at (based on MLE of price) 1660
# [5832    0    0    0    0    0] Valued at (based on MLE of price) 5832
# [23328     0     0     0     1     0] Valued at (based on MLE of price) 23328
# done
# Updating from contract:  Grain 2.734113420696578
# Updating from contract:  Fuel 25.366167585632795
# Updating from contract:  Diamonds 89.0629487709063
# New prices:  [1,0.0, 0.8284823828611598,3.8674121164956707, 0.6657382337252518,3.512906572020773, 3.401702786108232,8.871157434282573, 7.6514879512247465,25.17740628953365, 0,3.1622776601683795]
# Factories
# [1096  570    0    0    0    0] Valued at (based on MLE of price) 5457
# [521   1   4   0   0   0] Valued at (based on MLE of price) 559
# [1341    0    0  442    0    0] Valued at (based on MLE of price) 4722
# [3253    0    0    0  381    0] Valued at (based on MLE of price) 6168
# [1681    0    0    0    0    0] Valued at (based on MLE of price) 1681
# [5849    0    0    2    0    0] Valued at (based on MLE of price) 5864
# [23054     0     0     0     4     0] Valued at (based on MLE of price) 23084
# done
# New prices:  [1,0.0, 0.840863826089161,3.8798169389595194, 0.6836060263679659,3.5156567097735696, 3.4041400058838005,8.854481634189494, 7.870941082706719,25.46143473633487, 0,3.1622776601683795]
# Factories
# [1089  588    0    0    0    0] Valued at (based on MLE of price) 5717
# [522   0   2   0   0   0] Valued at (based on MLE of price) 537
# [1255    0    0  458    0    0] Valued at (based on MLE of price) 4859
# [3295    0    0    0  398    0] Valued at (based on MLE of price) 6427
# [1707    0    0    0    0    0] Valued at (based on MLE of price) 1707
# [6071    0    0    0    0    0] Valued at (based on MLE of price) 6071
# [23129     0     0     0     5     0] Valued at (based on MLE of price) 23168
# done
# Updating from contract:  Food 4.488164667440084
# Updating from contract:  Fuel 6.657808276587215
# New prices:  [1,0.0, 0.8507211565330766,3.8824854711875867, 0.7005418412170169,3.5222812849687615, 3.4529580311194694,8.893425004706216, 8.04335561261063,25.72621070593867, 0,3.1622776601683795]
# Factories
# [1079  606    0    0    0    0] Valued at (based on MLE of price) 3171
# [525   0   0   0   0   0] Valued at (based on MLE of price) 525
# [1216    0    0  474    0    0] Valued at (based on MLE of price) 2852
# [3283    0    0    0  416    0] Valued at (based on MLE of price) 4719
# [1706    0    2    0    0    0] Valued at (based on MLE of price) 1712
# [6086    0    0    2    0    0] Valued at (based on MLE of price) 6092
# [23579     0     0     0     3     0] Valued at (based on MLE of price) 23589
# done
# Updating from contract:  Grain 16.66050762362944
# New prices:  [1,0.0, 0.8865448527500506,3.923931223855768, 0.7020532509209599,3.5208437994214723, 3.5145326235197882,8.992553239214134, 8.072801108192202,25.730181684976525, 0,3.1622776601683795]
# Factories
# [1096  622    0    0    0    0] Valued at (based on MLE of price) 1647
# [483   1   2   0   0   0] Valued at (based on MLE of price) 485
# [1183    0    0  492    0    0] Valued at (based on MLE of price) 1619
# [3120    0    0    0  435    0] Valued at (based on MLE of price) 3505
# [1733    0    0    0    0    0] Valued at (based on MLE of price) 1733
# [6177    0    0    0    0    0] Valued at (based on MLE of price) 6177
# [24181     0     0     0     0     0] Valued at (based on MLE of price) 24181
# done
# Updating from contract:  Food 5.735677782630517
# Updating from contract:  Fuel 33.2140247983719
# New prices:  [1,0.0, 0.9004517692013617,3.932311878278935, 0.7171857830276557,3.5224003853394135, 3.5705466551335574,9.070635754803352, 8.330112516334319,26.16552931191232, 0,3.1622776601683795]
# Factories
# [1091  640    0    0    0    0] Valued at (based on MLE of price) 3376
# [479   0   1   0   0   0] Valued at (based on MLE of price) 482
# [1145    0    0  510    0    0] Valued at (based on MLE of price) 2965
# [3221    0    0    0  450    0] Valued at (based on MLE of price) 4827
# [1743    0    1    0    0    0] Valued at (based on MLE of price) 1746
# [6193    0    0    0    0    0] Valued at (based on MLE of price) 6193
# [24377     0     0     0     0     0] Valued at (based on MLE of price) 24377
# done
# New prices:  [1,0.0, 0.9055046558072436,3.9309390155825032, 0.7332153815014298,3.532520523608747, 3.632128083868036,9.111204426725827, 8.449009807622508,26.42106581041278, 0,3.1622776601683795]
# Factories
# [1077  658    0    0    0    0] Valued at (based on MLE of price) 3466
# [486   0   0   0   0   0] Valued at (based on MLE of price) 486
# [1139    0    0  522    0    0] Valued at (based on MLE of price) 3034
# [3148    0    0    0  469    0] Valued at (based on MLE of price) 4851
# [1763    0    0    0    0    0] Valued at (based on MLE of price) 1763
# [6275    0    0    0    0    0] Valued at (based on MLE of price) 6275
# [24409     0     0     0     0     0] Valued at (based on MLE of price) 24409
# done
# Updating from contract:  Grain 6.448986005871347
# Updating from contract:  Diamonds 16.773302117333436
# New prices:  [1,0.0, 0.9127941997441893,3.9313002006706608, 0.7363540810711352,3.532147240988288, 3.696257758292853,9.201810411171552, 8.750530326862604,27.18479396201257, 0,3.1622776601683795]
# Factories
# [1065  676    0    0    0    0] Valued at (based on MLE of price) 6980
# [477   0   1   0   0   0] Valued at (based on MLE of price) 485
# [1113    0    0  539    0    0] Valued at (based on MLE of price) 5829
# [3274    0    0    0  486    0] Valued at (based on MLE of price) 7526
# [1769    0    0    0    0    0] Valued at (based on MLE of price) 1769
# [6278    0    0    1    0    0] Valued at (based on MLE of price) 6286
# [24400     0     0     0     1     0] Valued at (based on MLE of price) 24408
# done
# Updating from contract:  Fuel 29.484910443856023
# New prices:  [1,0.0, 0.9332233470965536,3.9403290350124167, 0.7462066623287957,3.5363096183438922, 3.722046410978416,9.233256797091224, 8.978424881814767,27.49882342048114, 0,3.1622776601683795]
# Factories
# [1068  692    0    0    0    0] Valued at (based on MLE of price) 3643
# [457   1   2   0   0   0] Valued at (based on MLE of price) 468
# [1052    0    0  556    0    0] Valued at (based on MLE of price) 3121
# [3327    0    0    0  503    0] Valued at (based on MLE of price) 5199
# [1777    0    0    0    0    0] Valued at (based on MLE of price) 1777
# [6328    0    0    0    0    0] Valued at (based on MLE of price) 6328
# [24624     0     0     0     1     0] Valued at (based on MLE of price) 24627
# done
# Updating from contract:  Diamonds 58.98836808975767
# New prices:  [1,0.0, 0.957509150299976,3.9557148131113613, 0.7606247449312753,3.5411425914658743, 3.7828701979221977,9.291710149824306, 9.211819015499309,27.86098437060767, 0,3.1622776601683795]
# Factories
# [1074  708    0    0    0    0] Valued at (based on MLE of price) 7595
# [436   0   4   0   0   0] Valued at (based on MLE of price) 472
# [1022    0    0  573    0    0] Valued at (based on MLE of price) 6300
# [3385    0    0    0  520    0] Valued at (based on MLE of price) 8175
# [1780    0    1    0    0    0] Valued at (based on MLE of price) 1789
# [6375    0    0    0    0    0] Valued at (based on MLE of price) 6375
# [24683     0     0     0     2     0] Valued at (based on MLE of price) 24701
# done
# Updating from contract:  Grain 1.1852194300313017
# Updating from contract:  Food 2.528302570457333
# New prices:  [1,0.0, 0.9750373087147782,3.970811338808963, 0.7963586421224627,3.5656412298160824, 3.834800887442573,9.33665761483429, 9.389850435977422,28.16512999317124, 0,3.1622776601683795]
# Factories
# [1074  724    0    0    0    0] Valued at (based on MLE of price) 1650
# [445   1   1   0   0   0] Valued at (based on MLE of price) 446
# [991   0   0 588   0   0] Valued at (based on MLE of price) 1459
# [3389    0    0    0  537    0] Valued at (based on MLE of price) 3816
# [1808    0    0    0    0    0] Valued at (based on MLE of price) 1808
# [6381    0    0    3    0    0] Valued at (based on MLE of price) 6383
# [25276     0     0     0     0     0] Valued at (based on MLE of price) 25276
# done
# Updating from contract:  Grain 7.820705413627327
# New prices:  [1,0.0, 1.0053428825550335,3.9988575566287765, 0.8103308316156568,3.571058895652507, 3.87931392471125,9.34651808995874, 9.531237690040212,28.32123111911652, 0,3.1622776601683795]
# Factories
# [1086  739    0    0    0    0] Valued at (based on MLE of price) 1828
# [416   0   4   0   0   0] Valued at (based on MLE of price) 420
# [952   0   0 603   0   0] Valued at (based on MLE of price) 1558
# [3348    0    0    0  555    0] Valued at (based on MLE of price) 3905
# [1811    0    1    0    0    0] Valued at (based on MLE of price) 1812
# [6595    0    0    1    0    0] Valued at (based on MLE of price) 6596
# [25275     0     0     0     1     0] Valued at (based on MLE of price) 25276
# done
# Updating from contract:  Food 1.0994329835821028
# Updating from contract:  Fuel 8.862631271249509
# Updating from contract:  Diamonds 98.42978057094214
# New prices:  [1,0.0, 1.0078990207125456,3.9932713592190554, 0.8338401147080587,3.5765472269063294, 3.9646258008860125,9.433511563439057, 9.952150793114635,28.939013648935724, 0,3.1622776601683795]
# Factories
# [1070  756    0    0    0    0] Valued at (based on MLE of price) 8593
# [432   0   0   0   0   0] Valued at (based on MLE of price) 432
# [965   0   0 616   0   0] Valued at (based on MLE of price) 7095
# [3615    0    0    0  570    0] Valued at (based on MLE of price) 9287
# [1848    0    1    0    0    0] Valued at (based on MLE of price) 1857
# [6647    0    0    2    0    0] Valued at (based on MLE of price) 6666
# [24803     0     0     0     6     0] Valued at (based on MLE of price) 24862
# done
# Updating from contract:  Grain 19.84808666095362
# New prices:  [1,0.0, 1.0465547812043487,4.0447625461278145, 0.8470978636496845,3.583360664090588, 4.021553220529504,9.473600855968396, 9.950352619296831,28.92459636119344, 0,3.1622776601683795]
# Factories
# [1090  771    0    0    0    0] Valued at (based on MLE of price) 1896
# [398   2   0   0   0   0] Valued at (based on MLE of price) 400
# [936   0   0 632   0   0] Valued at (based on MLE of price) 1597
# [3443    0    0    0  587    0] Valued at (based on MLE of price) 4057
# [1871    0    0    0    0    0] Valued at (based on MLE of price) 1871
# [6812    0    0    0    0    0] Valued at (based on MLE of price) 6812
# [25754     0     0     0     1     0] Valued at (based on MLE of price) 25755
# done
# Updating from contract:  Food 6.953414771826205
# Updating from contract:  Diamonds 50.07160864964396
# New prices:  [1,0.0, 1.0665574126383859,4.058416136215316, 0.8750857289659656,3.5994950733649054, 4.062425776970551,9.493150643084292, 10.071899775698137,28.993170201313387, 0,3.1622776601683795]
# Factories
# [1092  788    0    0    0    0] Valued at (based on MLE of price) 9028
# [398   0   0   0   0   0] Valued at (based on MLE of price) 398
# [888   0   0 649   0   0] Valued at (based on MLE of price) 7424
# [3393    0    0    0  604    0] Valued at (based on MLE of price) 9476
# [1876    0    1    0    0    0] Valued at (based on MLE of price) 1886
# [6797    0    0    2    0    0] Valued at (based on MLE of price) 6817
# [25761     0     0     0     3     0] Valued at (based on MLE of price) 25791
# done
# Updating from contract:  Diamonds 67.71050710320708
# New prices:  [1,0.0, 1.111077778010326,4.154863522740976, 0.893007678938708,3.6097270394880683, 4.1080715173536815,9.550376451634369, 10.196697915702723,29.045770348766162, 0,3.1622776601683795]
# Factories
# [1117  805    0    0    0    0] Valued at (based on MLE of price) 9325
# [366   0   0   0   0   0] Valued at (based on MLE of price) 366
# [841   0   0 667   0   0] Valued at (based on MLE of price) 7642
# [3346    0    0    0  621    0] Valued at (based on MLE of price) 9678
# [1874    0    2    0    0    0] Valued at (based on MLE of price) 1894
# [6902    0    0    0    0    0] Valued at (based on MLE of price) 6902
# [26405     0     0     0     1     0] Valued at (based on MLE of price) 26415
# done
# Updating from contract:  Grain 4.391175547093541
# Updating from contract:  Fuel 19.777813866573705
# Updating from contract:  Diamonds 90.85197777165743
# New prices:  [1,0.0, 1.1297488356803498,4.164155710379284, 0.8938987929299963,3.60803166011234, 4.133526296274223,9.558666113004126, 10.379779690728435,29.307742135712026, 0,3.1622776601683795]
# Factories
# [1117  822    0    0    0    0] Valued at (based on MLE of price) 9649
# [343   2   0   0   0   0] Valued at (based on MLE of price) 363
# [773   0   0 685   0   0] Valued at (based on MLE of price) 7883
# [3348    0    0    0  639    0] Valued at (based on MLE of price) 9980
# [1902    0    0    0    0    0] Valued at (based on MLE of price) 1902
# [6908    0    0    1    0    0] Valued at (based on MLE of price) 6918
# [26201     0     0     0     3     0] Valued at (based on MLE of price) 26232
# done
# Updating from contract:  Grain 1.1220967360245533
# New prices:  [1,0.0, 1.1459355834778917,4.162230292850345, 0.9076136667810832,3.6138175328067317, 4.169621534146901,9.586441616543048, 10.47954104179228,29.462300999467345, 0,3.1622776601683795]
# Factories
# [1118  836    0    0    0    0] Valued at (based on MLE of price) 2076
# [325   3   2   0   0   0] Valued at (based on MLE of price) 330
# [730   0   0 700   0   0] Valued at (based on MLE of price) 1532
# [3258    0    0    0  658    0] Valued at (based on MLE of price) 4012
# [1915    0    0    0    0    0] Valued at (based on MLE of price) 1915
# [7018    0    0    0    0    0] Valued at (based on MLE of price) 7018
# [26570     0     0     0     1     0] Valued at (based on MLE of price) 26571
# done
# Updating from contract:  Grain 1.0839114574656419
# Updating from contract:  Food 7.895270820316033
# New prices:  [1,0.0, 1.180373738562675,4.190693752860174, 0.9397532248323212,3.6304520675089416, 4.202248001594287,9.608558333403549, 10.685678105757297,29.856648012523166, 0,3.1622776601683795]
# Factories
# [1137  850    0    0    0    0] Valued at (based on MLE of price) 1935
# [305   1   4   0   0   0] Valued at (based on MLE of price) 309
# [670   0   0 718   0   0] Valued at (based on MLE of price) 1344
# [3284    0    0    0  676    0] Valued at (based on MLE of price) 3919
# [1936    0    0    0    0    0] Valued at (based on MLE of price) 1936
# [7056    0    0    0    0    0] Valued at (based on MLE of price) 7056
# [26342     0     0     0     3     0] Valued at (based on MLE of price) 26344
# done
# New prices:  [1,0.0, 1.1961609866844747,4.218215284001877, 0.9620290796037553,3.636962759445875, 4.224240364672007,9.61584707077888, 10.78416162859842,30.003621721053722, 0,3.1622776601683795]
# Factories
# [1133  869    0    0    0    0] Valued at (based on MLE of price) 1969
# [310   0   0   0   0   0] Valued at (based on MLE of price) 310
# [599   0   0 736   0   0] Valued at (based on MLE of price) 1307
# [3193    0    0    0  695    0] Valued at (based on MLE of price) 3861
# [1956    0    1    0    0    0] Valued at (based on MLE of price) 1956
# [7105    0    0    0    0    0] Valued at (based on MLE of price) 7105
# [26552     0     0     0     2     0] Valued at (based on MLE of price) 26553
# done
# Updating from contract:  Food 6.7994685409685705
# Updating from contract:  Diamonds 150.913730959339
# New prices:  [1,0.0, 1.2143382039083994,4.2214209220207435, 0.9760710781307302,3.6472341627927127, 4.32436167827094,9.745491804205814, 11.20117208241429,30.73483708741569, 0,3.1622776601683795]
# Factories
# [1135  885    0    0    0    0] Valued at (based on MLE of price) 11048
# [297   2   0   0   0   0] Valued at (based on MLE of price) 319
# [633   0   0 748   0   0] Valued at (based on MLE of price) 9011
# [3452    0    0    0  711    0] Valued at (based on MLE of price) 11416
# [1969    0    0    0    0    0] Valued at (based on MLE of price) 1969
# [7175    0    0    1    0    0] Valued at (based on MLE of price) 7186
# [27049     0     0     0     0     0] Valued at (based on MLE of price) 27049
# done
# Updating from contract:  Food 3.241254380886007
# New prices:  [1,0.0, 1.2340581397845694,4.231127556875957, 0.9826719681428197,3.6415506607442785, 4.364372278829213,9.784814826026025, 11.352879803456213,30.914891156368405, 0,3.1622776601683795]
# Factories
# [1137  902    0    0    0    0] Valued at (based on MLE of price) 2023
# [275   0   1   0   0   0] Valued at (based on MLE of price) 275
# [581   0   0 766   0   0] Valued at (based on MLE of price) 1333
# [3425    0    0    0  729    0] Valued at (based on MLE of price) 4141
# [1997    0    0    0    0    0] Valued at (based on MLE of price) 1997
# [7245    0    0    0    0    0] Valued at (based on MLE of price) 7245
# [27194     0     0     0     0     0] Valued at (based on MLE of price) 27194
# done
# New prices:  [1,0.0, 1.2811447907297706,4.293947325343818, 0.9907880855517752,3.6487581194135736, 4.408491811533769,9.824625072195172, 11.585704174901965,31.321188892480414, 0,3.1622776601683795]
# Factories
# [1167  916    0    0    0    0] Valued at (based on MLE of price) 11779
# [224   2   4   0   0   0] Valued at (based on MLE of price) 293
# [543   0   0 782   0   0] Valued at (based on MLE of price) 9603
# [3480    0    0    0  747    0] Valued at (based on MLE of price) 12134
# [1997    0    0    0    0    0] Valued at (based on MLE of price) 1997
# [7271    0    0    0    0    0] Valued at (based on MLE of price) 7271
# [27097     0     0     0     1     0] Valued at (based on MLE of price) 27108
# done
# Updating from contract:  Food 1.8641855400326683
# New prices:  [1,0.0, 1.2930573830745073,4.30014253503814, 1.0153476974107785,3.656014591839057, 4.4500389509628056,9.857701040944706, 11.620228363628822,31.32453646029643, 0,3.1622776601683795]
# Factories
# [1161  933    0    0    0    0] Valued at (based on MLE of price) 2108
# [232   2   1   0   0   0] Valued at (based on MLE of price) 235
# [496   0   0 799   0   0] Valued at (based on MLE of price) 1307
# [3326    0    0    0  766    0] Valued at (based on MLE of price) 4103
# [2023    0    0    0    0    0] Valued at (based on MLE of price) 2023
# [7335    0    0    0    0    0] Valued at (based on MLE of price) 7335
# [27370     0     0     0     0     0] Valued at (based on MLE of price) 27370
# done
# Updating from contract:  Grain 10.047091945400942
# New prices:  [1,0.0, 1.3276157551134486,4.333279432143, 1.0271703759671758,3.6590673748336244, 4.455303371001584,9.851906015678393, 11.664642858105593,31.34032598012177, 0,3.1622776601683795]
# Factories
# [1179  949    0    0    0    0] Valued at (based on MLE of price) 2438
# [199   1   2   0   0   0] Valued at (based on MLE of price) 202
# [409   0   0 817   0   0] Valued at (based on MLE of price) 1493
# [3182    0    0    0  785    0] Valued at (based on MLE of price) 4224
# [2025    0    2    0    0    0] Valued at (based on MLE of price) 2027
# [7400    0    0    0    0    0] Valued at (based on MLE of price) 7400
# [27473     0     0     0     0     0] Valued at (based on MLE of price) 27473
# done
# Updating from contract:  Food 9.33668426575954
# Updating from contract:  Fuel 27.058468070923265
# Updating from contract:  Diamonds 155.6976654670129
# New prices:  [1,0.0, 1.3423507673155208,4.341448320887863, 1.048739613238832,3.671355699316569, 4.514906174608107,9.88143210852163, 11.953804349755709,31.89644694611857, 0,3.1622776601683795]
# Factories
# [1175  967    0    0    0    0] Valued at (based on MLE of price) 12734
# [202   0   0   0   0   0] Valued at (based on MLE of price) 202
# [384   0   0 833   0   0] Valued at (based on MLE of price) 10341
# [3305    0    0    0  802    0] Valued at (based on MLE of price) 12891
# [2066    0    0    0    0    0] Valued at (based on MLE of price) 2066
# [7441    0    0    1    0    0] Valued at (based on MLE of price) 7452
# ...
# [105341      0      0      0      0      0] Valued at (based on MLE of price) 105341
# done
# Updating from contract:  Grain 7.071407024727799
# New prices:  [1,0.0, 7.1193090900653555,7.966435815621661, 3.91225297593793,3.707544202923102, 14.789225266245127,13.076399231348587, 55.44248942079999,53.20356042601596, 0,3.1622776601683795]
# Factories
# [ -380 11682     0     0     0     0] Valued at (based on MLE of price) 82787
# [-4886     1     0     0     0     0] Valued at (based on MLE of price) -4878
# [-35215      0      0  11287      0      0] Valued at (based on MLE of price) 45140
# [-32402      0      0      0  11457      0] Valued at (based on MLE of price) 49163
# [6162    0    0    0    0    0] Valued at (based on MLE of price) 6162
# [27965     0     0     0     0     0] Valued at (based on MLE of price) 27965
# [105341      0      0      0      0      0] Valued at (based on MLE of price) 105341
# done
# New prices:  [1,0.0, 7.120303783168256,7.962513669047591, 3.91225297593793,3.707544202923102, 14.83754916025003,13.107883958873305, 55.53626059925757,53.25948238612672, 0,3.1622776601683795]
# Factories
# [ -391 11701     0     0     0     0] Valued at (based on MLE of price) 82923
# [-4894     2     0     0     0     0] Valued at (based on MLE of price) -4879
# [-35236      0      0  11305      0      0] Valued at (based on MLE of price) 45259
# [-32452      0      0      0  11476      0] Valued at (based on MLE of price) 49260
# [6162    0    0    0    0    0] Valued at (based on MLE of price) 6162
# [27886     0     0     2     0     0] Valued at (based on MLE of price) 27900
# [105351      0      0      0      0      0] Valued at (based on MLE of price) 105351
# done
# Updating from contract:  Fuel 17.694436202388705
# New prices:  [1,0.0, 7.129406953759777,7.9600192474817595, 3.909893980294389,3.7064399938752373, 14.860278547642476,13.104210211006558, 55.53626059925757,53.25948238612672, 0,3.1622776601683795]
# Factories
# [ -387 11719     0     0     0     0] Valued at (based on MLE of price) 173760
# [-4916     2     1     0     0     0] Valued at (based on MLE of price) -4871
# [-35267      0      0  11322      0      0] Valued at (based on MLE of price) 132981
# [-32652      0      0      0  11496      0] Valued at (based on MLE of price) 138181
# [6170    0    0    0    0    0] Valued at (based on MLE of price) 6170
# [27817     0     0     5     0     0] Valued at (based on MLE of price) 27891
# [105351      0      0      0      0      0] Valued at (based on MLE of price) 105351
# done
# New prices:  [1,0.0, 7.140308471818119,7.963496014109644, 3.907353120364512,3.705456684942322, 14.860278547642476,13.104210211006558, 55.61346199278086,53.28874165037941, 0,3.1622776601683795]
# Factories
# [ -388 11738     0     0     0     0] Valued at (based on MLE of price) 652402
# [-4932     3     0     0     0     0] Valued at (based on MLE of price) -4765
# [-35357      0      0  11340      0      0] Valued at (based on MLE of price) 595299
# [-32699      0      0      0  11513      0] Valued at (based on MLE of price) 607578
# [6178    0    0    0    0    0] Valued at (based on MLE of price) 6178
# [27897     0     0     3     0     0] Valued at (based on MLE of price) 28063
# [105218      0      0      0      1      0] Valued at (based on MLE of price) 105273
# done
# New prices:  [1,0.0, 7.140308471818119,7.963496014109644, 3.9112210168825783,3.702928930286458, 14.883137209718974,13.104879560072662, 55.61346199278086,53.28874165037941, 0,3.1622776601683795]
# Factories
# [ -408 11758     0     0     0     0] Valued at (based on MLE of price) 174587
# [-4918     0     0     0     0     0] Valued at (based on MLE of price) -4918
# [-35403      0      0  11358      0      0] Valued at (based on MLE of price) 133639
# [-32899      0      0      0  11533      0] Valued at (based on MLE of price) 138748
# [6191    0    0    0    0    0] Valued at (based on MLE of price) 6191
# [27923     0     0     3     0     0] Valued at (based on MLE of price) 27967
# [105378      0      0      0      0      0] Valued at (based on MLE of price) 105378
# done
# Updating from contract:  Diamonds 141.8082871034291
# New prices:  [1,0.0, 7.140308471818119,7.963496014109644, 3.9112210168825783,3.702928930286458, 14.88024966297659,13.092680142593156, 55.72111661685819,53.30940244188564, 0,3.1622776601683795]
# Factories
# [ -428 11778     0     0     0     0] Valued at (based on MLE of price) 655855
# [-4918     0     0     0     0     0] Valued at (based on MLE of price) -4918
# [-35475      0      0  11376      0      0] Valued at (based on MLE of price) 598408
# [-32859      0      0      0  11549      0] Valued at (based on MLE of price) 610664
# [6191    0    0    0    0    0] Valued at (based on MLE of price) 6191
# [27975     0     0     3     0     0] Valued at (based on MLE of price) 28142
# [105478      0      0      0      0      0] Valued at (based on MLE of price) 105478
# done
# New prices:  [1,0.0, 7.14095507896065,7.955804441930917, 3.9159171691058146,3.701406553339536, 14.864625722341145,13.085919340481128, 55.76801594772022,53.26908844064013, 0,3.1622776601683795]
# Factories
# [ -432 11796     0     0     0     0] Valued at (based on MLE of price) 657407
# [-4921     0     0     0     0     0] Valued at (based on MLE of price) -4921
# [-35550      0      0  11392      0      0] Valued at (based on MLE of price) 599759
# [-32899      0      0      0  11567      0] Valued at (based on MLE of price) 612169
# [6198    0    0    0    0    0] Valued at (based on MLE of price) 6198
# [28160     0     0     0     0     0] Valued at (based on MLE of price) 28160
# [105318      0      0      0      2      0] Valued at (based on MLE of price) 105429
# done
# Updating from contract:  Diamonds 78.26175824086943
# New prices:  [1,0.0, 7.165303996544254,7.962546741931536, 3.9159171691058146,3.701406553339536, 14.885086191383698,13.095352452807077, 55.8469528564016,53.25046654053567, 0,3.1622776601683795]
# Factories
# [ -405 11813     0     0     0     0] Valued at (based on MLE of price) 659315
# [-4965     3     0     0     0     0] Valued at (based on MLE of price) -4797
# [-35604      0      0  11409      0      0] Valued at (based on MLE of price) 601553
# [-32907      0      0      0  11585      0] Valued at (based on MLE of price) 614079
# [6198    0    0    0    0    0] Valued at (based on MLE of price) 6198
# [28164     0     0     0     0     0] Valued at (based on MLE of price) 28164
# [105446      0      0      0      2      0] Valued at (based on MLE of price) 105557
# done
# New prices:  [1,0.0, 7.165303996544254,7.962546741931536, 3.9179035163727307,3.7000880655088575, 14.873898812296451,13.090540453237216, 55.848171558861814,53.22384858640321, 0,3.1622776601683795]
# Factories
# [ -425 11833     0     0     0     0] Valued at (based on MLE of price) 175577
# [-4961     1     1     0     0     0] Valued at (based on MLE of price) -4931
# [-35658      0      0  11424      0      0] Valued at (based on MLE of price) 134261
# [-33029      0      0      0  11602      0] Valued at (based on MLE of price) 139537
# [6192    0    1    0    0    0] Valued at (based on MLE of price) 6206
# [28248     0     0     0     0     0] Valued at (based on MLE of price) 28248
# [105708      0      0      0      1      0] Valued at (based on MLE of price) 105722
# done
# Updating from contract:  Grain 5.126886306754691
# New prices:  [1,0.0, 7.170769663472227,7.958385680848063, 3.921928954826887,3.700425514913388, 14.873898812296451,13.090540453237216, 55.81568383150809,53.20713934488687, 0,3.1622776601683795]
# Factories
# [ -424 11851     0     0     0     0] Valued at (based on MLE of price) 84556
# [-4974     1     2     0     0     0] Valued at (based on MLE of price) -4952
# [-35748      0      0  11442      0      0] Valued at (based on MLE of price) 46299
# [-33205      0      0      0  11621      0] Valued at (based on MLE of price) 50126
# [6204    0    0    0    0    0] Valued at (based on MLE of price) 6204
# [28248     0     0     0     0     0] Valued at (based on MLE of price) 28248
# [106004      0      0      0      0      0] Valued at (based on MLE of price) 106004
# done
# Updating from contract:  Diamonds 85.81916332810471
# New prices:  [1,0.0, 7.170588361279321,7.950586514212384, 3.928774431585016,3.6977736975440245, 14.87406095695787,13.078208228631313, 55.945860317655345,53.25662820450691, 0,3.1622776601683795]
# Factories
# [ -429 11869     0     0     0     0] Valued at (based on MLE of price) 663592
# [-4965     1     0     0     0     0] Valued at (based on MLE of price) -4909
# [-35817      0      0  11460      0      0] Valued at (based on MLE of price) 605322
# [-33162      0      0      0  11639      0] Valued at (based on MLE of price) 617991
# [6220    0    0    0    0    0] Valued at (based on MLE of price) 6220
# [28297     0     0     0     0     0] Valued at (based on MLE of price) 28297
# [105921      0      0      0      1      0] Valued at (based on MLE of price) 105976
# done
# Updating from contract:  Fuel 14.34076839993334
# New prices:  [1,0.0, 7.168821799205954,7.945580476981378, 3.928774431585016,3.6977736975440245, 14.889223269005752,13.074565979709924, 55.894363129336654,53.254872901075395, 0,3.1622776601683795]
# Factories
# [ -435 11887     0     0     0     0] Valued at (based on MLE of price) 176553
# [-4979     1     2     0     0     0] Valued at (based on MLE of price) -4934
# [-35871      0      0  11478      0      0] Valued at (based on MLE of price) 135027
# [-33357      0      0      0  11658      0] Valued at (based on MLE of price) 140221
# [6220    0    0    0    0    0] Valued at (based on MLE of price) 6220
# [28251     0     0     2     0     0] Valued at (based on MLE of price) 28280
# [106236      0      0      0      0      0] Valued at (based on MLE of price) 106236
# done
# New prices:  [1,0.0, 7.168821799205954,7.945580476981378, 3.9325251812838125,3.6967065116830815, 14.869492922792062,13.067659411687753, 55.941630526054595,53.2240648282215, 0,3.1622776601683795]
# Factories
# [ -455 11907     0     0     0     0] Valued at (based on MLE of price) 665641
# [-4963     0     0     0     0     0] Valued at (based on MLE of price) -4963
# [-35935      0      0  11493      0      0] Valued at (based on MLE of price) 607002
# [-33320      0      0      0  11673      0] Valued at (based on MLE of price) 619686
# [6233    0    0    0    0    0] Valued at (based on MLE of price) 6233
# [28425     0     0     0     0     0] Valued at (based on MLE of price) 28425
# [106179      0      0      0      2      0] Valued at (based on MLE of price) 106290
# done
# New prices:  [1,0.0, 7.179788218155374,7.9491671858944475, 3.9325251812838125,3.6967065116830815, 14.86273663553358,13.062869537259921, 55.89473377287538,53.21809261816117, 0,3.1622776601683795]
# Factories
# [ -456 11926     0     0     0     0] Valued at (based on MLE of price) 176796
# [-4982     0     1     0     0     0] Valued at (based on MLE of price) -4967
# [-36006      0      0  11508      0      0] Valued at (based on MLE of price) 135034
# [-33510      0      0      0  11692      0] Valued at (based on MLE of price) 140265
# [6233    0    0    0    0    0] Valued at (based on MLE of price) 6233
# [28456     0     0     0     0     0] Valued at (based on MLE of price) 28456
# [106489      0      0      0      1      0] Valued at (based on MLE of price) 106503
# done
# New prices:  [1,0.0, 7.179788218155374,7.9491671858944475, 3.932786156700575,3.6948669034955186, 14.852592286836249,13.052174634275218, 55.89473377287538,53.21809261816117, 0,3.1622776601683795]
# Factories
# [ -476 11946     0     0     0     0] Valued at (based on MLE of price) 176953
# [-4977     0     0     0     0     0] Valued at (based on MLE of price) -4977
# [-36085      0      0  11526      0      0] Valued at (based on MLE of price) 135105
# [-33710      0      0      0  11712      0] Valued at (based on MLE of price) 140243
# [6238    0    0    0    0    0] Valued at (based on MLE of price) 6238
# [28515     0     0     0     0     0] Valued at (based on MLE of price) 28515
# [106649      0      0      0      0      0] Valued at (based on MLE of price) 106649
# done
# New prices:  [1,0.0, 7.183034850714627,7.942200106913484, 3.932786156700575,3.6948669034955186, 14.870545157952446,13.057981723707046, 55.968230584883045,53.242178731971336, 0,3.1622776601683795]
# Factories
# [ -469 11963     0     0     0     0] Valued at (based on MLE of price) 85461
# [-5001     3     0     0     0     0] Valued at (based on MLE of price) -4979
# [-36152      0      0  11545      0      0] Valued at (based on MLE of price) 46776
# [-33780      0      0      0  11731      0] Valued at (based on MLE of price) 50484
# [6238    0    0    0    0    0] Valued at (based on MLE of price) 6238
# [28522     0     0     0     0     0] Valued at (based on MLE of price) 28522
# [106519      0      0      0      1      0] Valued at (based on MLE of price) 106526
# done
# Updating from contract:  Grain 1.0295173483561477
# New prices:  [1,0.0, 7.176881333212269,7.940610298181903, 3.9382909873526173,3.6923155959633966, 14.883755362664665,13.04950654639641, 56.07949580217229,53.28286882054738, 0,3.1622776601683795]
# Factories
# [ -487 11982     0     0     0     0] Valued at (based on MLE of price) 85506
# [-4987     1     0     0     0     0] Valued at (based on MLE of price) -4979
# [-36208      0      0  11563      0      0] Valued at (based on MLE of price) 46778
# [-33756      0      0      0  11749      0] Valued at (based on MLE of price) 50565
# [6250    0    0    0    0    0] Valued at (based on MLE of price) 6250
# [28478     0     0     2     0     0] Valued at (based on MLE of price) 28492
# [106775      0      0      0      0      0] Valued at (based on MLE of price) 106775
# done
# Updating from contract:  Grain 2.840179974236544
# New prices:  [1,0.0, 7.181912617736361,7.93938769984399, 3.9426165872617855,3.693000591591337, 14.883755362664665,13.04950654639641, 56.07949580217229,53.28286882054738, 0,3.1622776601683795]
# Factories
# [ -487 12000     0     0     0     0] Valued at (based on MLE of price) 85695
# [-4997     2     0     0     0     0] Valued at (based on MLE of price) -4982
# [-36308      0      0  11583      0      0] Valued at (based on MLE of price) 46880
# [-33936      0      0      0  11767      0] Valued at (based on MLE of price) 50573
# [6251    0    0    0    0    0] Valued at (based on MLE of price) 6251
# [28558     0     0     0     0     0] Valued at (based on MLE of price) 28558
# [106775      0      0      0      0      0] Valued at (based on MLE of price) 106775
# done
# New prices:  [1,0.0, 7.181912617736361,7.93938769984399, 3.9491313134509336,3.692674342564097, 14.873937644232328,13.046670942848207, 56.07949580217229,53.28286882054738, 0,3.1622776601683795]
# Factories
# [ -507 12020     0     0     0     0] Valued at (based on MLE of price) 46961
# [-4984     0     0     0     0     0] Valued at (based on MLE of price) -4984
# [-36402      0      0  11602      0      0] Valued at (based on MLE of price) 9415
# [-34136      0      0      0  11787      0] Valued at (based on MLE of price) 12412
# [6256    0    0    0    0    0] Valued at (based on MLE of price) 6256
# [28592     0     0     0     0     0] Valued at (based on MLE of price) 28592
# [106775      0      0      0      0      0] Valued at (based on MLE of price) 106775
# done
# New prices:  [1,0.0, 7.196151670857504,7.954846018678026, 3.94715204583011,3.691357682377242, 14.862445855076679,13.045203571621586, 56.028757474275906,53.280360820641185, 0,3.1622776601683795]
# Factories
# [ -498 12038     0     0     0     0] Valued at (based on MLE of price) 86129
# [-5010     1     0     0     0     0] Valued at (based on MLE of price) -5002
# [-36498      0      0  11621      0      0] Valued at (based on MLE of price) 47128
# [-34330      0      0      0  11806      0] Valued at (based on MLE of price) 50627
# [6264    0    0    0    0    0] Valued at (based on MLE of price) 6264
# [28628     0     0     0     0     0] Valued at (based on MLE of price) 28628
# [106929      0      0      0      0      0] Valued at (based on MLE of price) 106929
# done
# Updating from contract:
