# %%
### IMPORTS

import math,sys
import numpy
import scipy,scipy.optimize,scipy.spatial,scipy.spatial.distance,scipy.stats
import json
import sqlite3
from collections import *
from enum import Enum
numpy.random.seed(1)

# %%
### CONSTANTS

# Names of goods
Goods = ["Credits","Grain","Food","Fuel","Diamonds","null"]

def createInventory(credits=0,grain=0,food=0,fuel=0,diamonds=0):
    return numpy.array([credits,grain,food,fuel,diamonds,0])

# %%
class BoundedAdaptiveNormalDistribution:
    NumSamples = 100
    MinVariance = 0.5
    
    def __init__(self, mean, variance, lower=None, upper=None):
        self.mean = mean
        self.variance = variance
        self.lower = lower
        self.upper = upper
        
    def __repr__(self):
        return str(self.mean) + str(",") + str(math.sqrt(self.variance))
        
    def draw(self):
        while True:
            value = scipy.stats.norm.rvs(loc=self.mean, scale=self.variance)
            if self.lower and self.lower > value:
                continue
            if self.upper and self.upper < value:
                continue
            return value
        
    def update(self,newValue):
        NumSamples = BoundedAdaptiveNormalDistribution.NumSamples
        oldMean = self.mean;
        self.mean = ((self.mean * (NumSamples - 1)) + newValue) / NumSamples
        self.variance = (self.variance*(NumSamples-1) + ((newValue - oldMean)*(newValue - self.mean))) / NumSamples;
        self.variance = max(self.variance, BoundedAdaptiveNormalDistribution.MinVariance)

class Agent:
    def __init__(self, loc):
        self.loc = numpy.copy(loc)
        
    def __repr__(self):
        return self.__dict__.__repr__()

class Trader(Agent):
    def __init__(self, loc):
        Agent.__init__(self, loc)
        self.inventory = numpy.copy(createInventory(credits=1000))

class Factory(Trader):
    def __init__(self,loc,productionCost,output,capacity):
        Trader.__init__(self,loc)
        self.productionCost = numpy.copy(productionCost)
        self.output = numpy.copy(output)
        self.capacity = capacity
        self.demand = 0

    def getEpochsOfProduction(self):
        epochs = 100
        for i in range(0,len(self.productionCost)):
            if i == 0:
                continue # You can go negative in money with no penalty for now
            if self.productionCost[i] == 0:
                continue
            epochs = min(epochs, self.inventory[i] // self.productionCost[i] // self.capacity)
        return epochs
    
    def getCurrentProduction(self):
        currentProduction = self.capacity
        for i in range(0,len(self.productionCost)):
            if i == 0:
                continue # You can go negative in money with no penalty for now
            if self.productionCost[i] == 0:
                continue
            currentProduction = min(currentProduction, self.inventory[i] // self.productionCost[i])
        return currentProduction
    
    def produce(self):
        production = min(2,self.getCurrentProduction())
        self.inventory -= self.productionCost * production
        self.inventory += self.output * production
        

class Merchant(Trader):
    def __init__(self,loc):
        Trader.__init__(self,loc)

class Contract():
    def __init__(self,source,destination,good,quantity,pricePerUnit):
        self.source = source
        self.destination = destination
        self.good = good
        self.quantity = quantity
        self.pricePerUnit = pricePerUnit

class Need():
    def __init__(self, good, price):
        self.good = good
        self.price = price

# %%
## HELPER FUNCTIONS

def spawnLocation():
    return numpy.array([numpy.random.randint(0,100), numpy.random.randint(0,100)])

# %%
PlanetLocation = spawnLocation()
Factories = [
    # Farm: 1 credit -> 1 grain
    Factory(spawnLocation(), createInventory(credits=1), createInventory(grain=1), 100),
    
    # Bakery: 1 credit + 1 grain -> 1 food
    Factory(spawnLocation(), createInventory(credits=1, grain=1), createInventory(food=1), 100),
    
    # Oil rig: 5 credits -> 1 fuel
    Factory(spawnLocation(), createInventory(credits=5), createInventory(fuel=1), 100),
    
    # Diamond mine:  10 credits -> 1 diamond
    Factory(spawnLocation(), createInventory(credits=10), createInventory(diamonds=1), 100),
    
    # Planet: 1 food -> 10 credits, 1 fuel -> 40 credits, 1 diamond -> 160 credits
    Factory(PlanetLocation, createInventory(food=1), createInventory(credits=10), 100),
    Factory(PlanetLocation, createInventory(fuel=1), createInventory(credits=40), 50),
    Factory(PlanetLocation, createInventory(diamonds=1), createInventory(credits=160), 25),
]
Contracts = []
Needs = []

# Credits are always worth 1 credit with no variance
EstimatedPrices = [BoundedAdaptiveNormalDistribution(1,0)]
for x in range(1,len(Goods)):
    # All other goods have an unknown worth that we model with a normal distribution capped between [0,1000]
    # The mean & variance will change as people buy goods.
    EstimatedPrices.append(BoundedAdaptiveNormalDistribution(0,1,1,1000))

for epoch in range(0,1):
    for turn in range(0,100000):
        Contracts = []
        Needs = []
        for i in range(0,10):
            # First, draw to estimate the prices of items
            prices = [1,]
            for i2 in range(1,len(Goods)):
                prices.append(EstimatedPrices[i2].draw())
            for f in Factories:
                currentProduction = f.getCurrentProduction()
                remainingProduction = f.capacity - currentProduction
                if remainingProduction > 0:
                    # Next, decide if more production makes sense given these prices
                    costValue = numpy.dot(f.productionCost,prices)
                    outputValue = numpy.dot(f.output,prices)
                    if costValue < outputValue:
                        # Try to find suppliers for missing goods
                        for goodToPurchase in range(1,len(Goods)):
                            need = (f.productionCost[goodToPurchase] * f.capacity) - f.inventory[goodToPurchase]
                            if need > 0:
                                foundBuyer = False
                                for supplier in Factories:
                                    if supplier.inventory[goodToPurchase] > 0 and \
                                    supplier.productionCost[goodToPurchase] == 0: # For now, don't buy from someone who needs the good in their production
                                        # Buy goods from supplier
                                        foundBuyer = True
                                        quantityToBuy = 1 # Don't try to max out in case your price estimate is bad
                                        #quantityToBuy = min(need, supplier.inventory[goodToProduce])
                                        f.inventory[goodToPurchase] += quantityToBuy
                                        supplier.inventory[goodToPurchase] -= quantityToBuy
                                        f.inventory[0] -= quantityToBuy * prices[goodToPurchase]
                                        supplier.inventory[0] += quantityToBuy * prices[goodToPurchase]
                                        Contracts.append(Contract(supplier,f,goodToPurchase,quantityToBuy,prices[goodToPurchase]))
                                if foundBuyer == False:
                                    # We could not find a buyer for a good that we need, it must be worth more than we think it is
                                    # Let's estimate the good's worth by assuming it's essential to production and takes the rest of the margin from cost/benefit
                                    maximumPrice = (outputValue - costValue) - prices[goodToPurchase]
                                    if maximumPrice > prices[goodToPurchase]:
                                        Needs.append(Need(goodToPurchase,maximumPrice))

        # Now, Produce when it makes sense
      
        # First, draw to estimate the prices of items
        prices = [1,]
        for i2 in range(1,len(Goods)):
            prices.append(EstimatedPrices[i2].draw())
        for f in Factories:
            # Next, decide if more production makes sense given these prices
            costValue = numpy.dot(f.productionCost,prices)
            outputValue = numpy.dot(f.output,prices)
            if costValue < outputValue:
                # Produce
                f.produce()

        # Based on the contracts, adjust the prices
        for c in Contracts:
            EstimatedPrices[c.good].update(c.pricePerUnit)
        
        # Based on needs, adjust the prices
        for n in Needs:
            EstimatedPrices[n.good].update(n.price)
        
        # Some debug prints
        if turn % 1000 == 0:
            newPrices = [1]
            for x in range(1,len(Goods)):
                newPrices.append(EstimatedPrices[c.good].mean)
            for c in Contracts:
                print("Updating from contract: ",Goods[c.good],c.pricePerUnit)
            print("New prices: ",EstimatedPrices)
            print("Factories")
            for f in Factories:
                print(f.inventory,"Valued at (based on MLE of price)",int(numpy.dot(f.inventory,newPrices)))
            print('done')
            sys.stdout.flush()
# Out:
# New prices:  [1,0.0, 0,1.0, 0.644570090048,2.212149337421796, 3.5508424362,10.964667853574838, 15.0005131886,46.14421076322079, 0,1.0]
# Factories
# [998   2   0   0   0   0] Valued at (based on MLE of price) 999
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# done
# Updating from contract:  Food 3.32775590429
# Updating from contract:  Grain 1.97802181165
# Updating from contract:  Food 3.86740272782
# Updating from contract:  Grain 2.88611529749
# New prices:  [1,0.0, 2.22914018986,1.3539926579137747, 3.86252969073,0.7071067811865476, 19.0024916464,11.304053148465018, 77.3761651789,47.26029439212142, 0,1.0]
# Factories
# [ 367 1530    0    0    0    0] Valued at (based on MLE of price) 3777
# [229 100   0   0   0   0] Valued at (based on MLE of price) 451
# [-373    0    0 1546    0    0] Valued at (based on MLE of price) 3073
# [10568     0     0     0  1619     0] Valued at (based on MLE of price) 14176
# [2906    0    0    0    0    0] Valued at (based on MLE of price) 2906
# [7089    0    0   50    0    0] Valued at (based on MLE of price) 7200
# [26256     0     0     0    23     0] Valued at (based on MLE of price) 26307
# done
# Updating from contract:  Grain 1.37715310325
# Updating from contract:  Food 4.7882351085
# Updating from contract:  Grain 2.33983329635
# Updating from contract:  Food 5.03557993745
# New prices:  [1,0.0, 1.87303339959,0.7100448986574501, 3.89549866521,0.7163400602469467, 18.8013096689,10.981162070060453, 81.3331578296,45.081343595612395, 0,1.0]
# Factories
# [ 828 1780    0    0    0    0] Valued at (based on MLE of price) 7761
# [70 98  2  0  0  0] Valued at (based on MLE of price) 459
# [-453    0    0 3004    0    0] Valued at (based on MLE of price) 11249
# [18254     0     0     0  3257     0] Valued at (based on MLE of price) 30941
# [12852     0     0     0     0     0] Valued at (based on MLE of price) 12852
# [16889     0     0    50     0     0] Valued at (based on MLE of price) 17083
# [51040     0     0     0    25     0] Valued at (based on MLE of price) 51137
# done
# Updating from contract:  Grain 2.23812113617
# Updating from contract:  Food 3.56931156453
# Updating from contract:  Grain 1.2282037684
# Updating from contract:  Food 3.38528402699
# New prices:  [1,0.0, 1.89322811377,0.7071067811865476, 3.830755506,0.7071067811865476, 20.3592669772,11.033367605768055, 77.723956734,47.20307805470685, 0,1.0]
# Factories
# [1381 1942    0    0    0    0] Valued at (based on MLE of price) 8820
# [19 98  2  0  0  0] Valued at (based on MLE of price) 402
# [-1326     0     0  4542     0     0] Valued at (based on MLE of price) 16073
# [23110     0     0     0  4927     0] Valued at (based on MLE of price) 41984
# [23216     0     0     0     0     0] Valued at (based on MLE of price) 23216
# [25342     0     0    48     0     0] Valued at (based on MLE of price) 25525
# [76866     0     0     0    25     0] Valued at (based on MLE of price) 76961
# done
# Updating from contract:  Grain 1.8971085778
# Updating from contract:  Food 3.43944368785
# Updating from contract:  Diamonds 105.729929955
# Updating from contract:  Grain 1.95619686079
# Updating from contract:  Food 3.70878522971
# Updating from contract:  Diamonds 48.9356524094
# New prices:  [1,0.0, 1.87590993158,0.7071067811865476, 3.77464674003,0.7071067811865476, 20.9227201795,11.084734944734747, 81.5853581667,46.46994269707443, 0,1.0]
# Factories
# [1845 2138    0    0    0    0] Valued at (based on MLE of price) 176274
# [ 3 98  2  0  0  0] Valued at (based on MLE of price) 8161
# [-1770     0     0  6070     0     0] Valued at (based on MLE of price) 493453
# [29591     0     0     0  6581     0] Valued at (based on MLE of price) 566504
# [33419     0     0     0     0     0] Valued at (based on MLE of price) 33419
# [33186     0     0    50     0     0] Valued at (based on MLE of price) 37265
# [102419      0      0      0     25      0] Valued at (based on MLE of price) 104458
# done
# Updating from contract:  Grain 1.57227832582
# Updating from contract:  Food 4.18556787863
# Updating from contract:  Grain 1.28691563132
# Updating from contract:  Food 4.0977626431
# New prices:  [1,0.0, 1.84020578844,0.7071067811865476, 3.85127989352,0.7071067811865476, 20.380744457,11.30919502803209, 78.1390580331,45.00294647543663, 0,1.0]
# Factories
# [2384 2306    0    0    0    0] Valued at (based on MLE of price) 11265
# [ 7 98  2  0  0  0] Valued at (based on MLE of price) 392
# [-1514     0     0  7550     0     0] Valued at (based on MLE of price) 27563
# [37638     0     0     0  8205     0] Valued at (based on MLE of price) 69237
# [43804     0     0     0     0     0] Valued at (based on MLE of price) 43804
# [42400     0     0    50     0     0] Valued at (based on MLE of price) 42592
# [131198      0      0      0     23      0] Valued at (based on MLE of price) 131286
# done
# Updating from contract:  Grain 1.42540495749
# Updating from contract:  Food 3.68737593431
# Updating from contract:  Fuel 6.19478776033
# Updating from contract:  Grain 1.6529313166
# Updating from contract:  Food 4.63194438056
# Updating from contract:  Fuel 38.7267748924
# New prices:  [1,0.0, 1.79342683095,0.7071067811865476, 3.92451025009,0.7071067811865476, 21.7511368527,11.494488248351688, 76.6591478503,44.60602196577993, 0,1.0]
# Factories
# [2921 2476    0    0    0    0] Valued at (based on MLE of price) 56776
# [ 41 100   0   0   0   0] Valued at (based on MLE of price) 2216
# [-1710     0     0  9044     0     0] Valued at (based on MLE of price) 195007
# [43020     0     0     0  9857     0] Valued at (based on MLE of price) 257420
# [54115     0     0     0     0     0] Valued at (based on MLE of price) 54115
# [50946     0     0    50     0     0] Valued at (based on MLE of price) 52033
# [157252      0      0      0     25      0] Valued at (based on MLE of price) 157795
# done
# Updating from contract:  Grain 1.45311916945
# Updating from contract:  Food 3.66856524324
# Updating from contract:  Grain 1.0606725009
# Updating from contract:  Food 4.5385579417
# New prices:  [1,0.0, 1.81807463567,0.7076683723251933, 3.87175057945,0.7144763057634216, 21.4076646875,10.892019622883124, 79.162482563,46.34881536601604, 0,1.0]
# Factories
# [3285 2622    0    0    0    0] Valued at (based on MLE of price) 13436
# [114  98   2   0   0   0] Valued at (based on MLE of price) 501
# [-1340     0     0 10530     0     0] Valued at (based on MLE of price) 39429
# [47930     0     0     0 11533     0] Valued at (based on MLE of price) 92582
# [64654     0     0     0     0     0] Valued at (based on MLE of price) 64654
# [59666     0     0    50     0     0] Valued at (based on MLE of price) 59859
# [181176      0      0      0     25      0] Valued at (based on MLE of price) 181272
# done
# Updating from contract:  Grain 1.03166206571
# Updating from contract:  Food 3.92385758119
# Updating from contract:  Grain 2.11386691349
# Updating from contract:  Food 4.39481359491
# New prices:  [1,0.0, 1.80514370483,0.7071067811865476, 3.91845176236,0.7071067811865476, 20.4637425176,10.889372220723432, 80.7412591249,46.106022757365345, 0,1.0]
# Factories
# [3779 2782    0    0    0    0] Valued at (based on MLE of price) 14680
# [133  98   2   0   0   0] Valued at (based on MLE of price) 524
# [-2812     0     0 12094     0     0] Valued at (based on MLE of price) 44577
# [55367     0     0     0 13177     0] Valued at (based on MLE of price) 107000
# [75021     0     0     0     0     0] Valued at (based on MLE of price) 75021
# [67108     0     0    50     0     0] Valued at (based on MLE of price) 67303
# [207363      0      0      0     25      0] Valued at (based on MLE of price) 207460
# done
# Updating from contract:  Grain 1.43462536341
# Updating from contract:  Food 3.98945759367
# Updating from contract:  Fuel 26.8431365624
# Updating from contract:  Grain 1.57443715529
# Updating from contract:  Food 3.20239208323
# Updating from contract:  Diamonds 72.1955005461
# Updating from contract:  Diamonds 17.1115264281
# New prices:  [1,0.0, 1.79236315463,0.7071067811865476, 3.79631582755,0.7071067811865476, 21.8502494578,11.456611927136121, 84.6685362031,46.95709101392134, 0,1.0]
# Factories
# [4270 2954    0    0    0    0] Valued at (based on MLE of price) 254380
# [59 98  2  0  0  0] Valued at (based on MLE of price) 8525
# [-3771     0     0 13646     0     0] Valued at (based on MLE of price) 1151615
# [61801     0     0     0 14847     0] Valued at (based on MLE of price) 1318874
# [85400     0     0     0     0     0] Valued at (based on MLE of price) 85400
# [74797     0     0    50     0     0] Valued at (based on MLE of price) 79030
# [230441      0      0      0     23      0] Valued at (based on MLE of price) 232388
# done
# Updating from contract:  Food 3.19773911736
# Updating from contract:  Grain 2.50423561427
# Updating from contract:  Food 3.73221874649
# Updating from contract:  Grain 2.09268765701
# Updating from contract:  Fuel 9.76469916667
# Updating from contract:  Fuel 27.8858082108
# New prices:  [1,0.0, 1.85830336926,0.7071067811865476, 3.75697333062,0.7071067811865476, 20.4578721942,12.113517800691213, 82.2703979355,45.25511458569502, 0,1.0]
# Factories
# [4692 3142    0    0    0    0] Valued at (based on MLE of price) 68970
# [58 98  2  0  0  0] Valued at (based on MLE of price) 2103
# [-5467     0     0 15202     0     0] Valued at (based on MLE of price) 305533
# [67954     0     0     0 16517     0] Valued at (based on MLE of price) 405856
# [95663     0     0     0     0     0] Valued at (based on MLE of price) 95663
# [82783     0     0    50     0     0] Valued at (based on MLE of price) 83805
# [254054      0      0      0     25      0] Valued at (based on MLE of price) 254565
# done
# Updating from contract:  Grain 2.37780898094
# Updating from contract:  Food 4.2957003143
# Updating from contract:  Grain 2.58977474233
# Updating from contract:  Food 4.06800495119
# Updating from contract:  Fuel 39.0332528253
# Updating from contract:  Fuel 11.1649429141
# New prices:  [1,0.0, 1.81518563256,0.707856262081142, 3.84218628065,0.7071067811865476, 20.3727177531,11.97141960421919, 78.0990954204,45.39854049878983, 0,1.0]
# Factories
# [5193 3308    0    0    0    0] Valued at (based on MLE of price) 72585
# [69 98  2  0  0  0] Valued at (based on MLE of price) 2106
# [-6935     0     0 16746     0     0] Valued at (based on MLE of price) 334226
# [75362     0     0     0 18133     0] Valued at (based on MLE of price) 444780
# [105989      0      0      0      0      0] Valued at (based on MLE of price) 105989
# [90671     0     0    50     0     0] Valued at (based on MLE of price) 91689
# [283232      0      0      0     25      0] Valued at (based on MLE of price) 283741
# done
# Updating from contract:  Grain 2.34808026256
# Updating from contract:  Food 3.82880386115
# Updating from contract:  Grain 1.67105911991
# Updating from contract:  Food 3.36303011121
# Updating from contract:  Diamonds 157.894722611
# Updating from contract:  Diamonds 105.501175668
# New prices:  [1,0.0, 1.81477315241,0.7071067811865476, 3.9960772942,0.7071067811865476, 20.9820912774,11.330638052791999, 77.6122056711,47.332547248223676, 0,1.0]
# Factories
# [5716 3448    0    0    0    0] Valued at (based on MLE of price) 273322
# [21 98  2  0  0  0] Valued at (based on MLE of price) 7782
# [-7255     0     0 18254     0     0] Valued at (based on MLE of price) 1409478
# [79037     0     0     0 19795     0] Valued at (based on MLE of price) 1615370
# [116536      0      0      0      0      0] Valued at (based on MLE of price) 116536
# [99141     0     0    48     0     0] Valued at (based on MLE of price) 102866
# [309127      0      0      0     25      0] Valued at (based on MLE of price) 311067
# done
# Updating from contract:  Grain 1.45154722756
# Updating from contract:  Food 3.62304138977
# Updating from contract:  Grain 2.22960235333
# Updating from contract:  Food 4.66656177559
# Updating from contract:  Fuel 20.3473731568
# Updating from contract:  Fuel 30.2341027663
# New prices:  [1,0.0, 1.7876200504,0.7071067811865476, 3.90717141829,0.7076898946698772, 21.0782311291,11.543662906142202, 83.0913846588,47.499580278897035, 0,1.0]
# Factories
# [6198 3616    0    0    0    0] Valued at (based on MLE of price) 82416
# [89 98  2  0  0  0] Valued at (based on MLE of price) 2196
# [-8711     0     0 19812     0     0] Valued at (based on MLE of price) 408890
# [88565     0     0     0 21425     0] Valued at (based on MLE of price) 540166
# [126810      0      0      0      0      0] Valued at (based on MLE of price) 126810
# [106657      0      0     50      0      0] Valued at (based on MLE of price) 107710
# [336939      0      0      0     25      0] Valued at (based on MLE of price) 337465
# done
# Updating from contract:  Grain 1.99946206655
# Updating from contract:  Food 4.12355507529
# Updating from contract:  Grain 2.70583560883
# Updating from contract:  Food 4.37124076704
# New prices:  [1,0.0, 1.89884948344,0.7082217495468205, 3.92866649208,0.7071067811865476, 20.0187495309,11.006355777591025, 79.7557087957,44.53992297721178, 0,1.0]
# Factories
# [6743 3766    0    0    0    0] Valued at (based on MLE of price) 21538
# [136 100   0   0   0   0] Valued at (based on MLE of price) 528
# [-10619      0      0  21368      0      0] Valued at (based on MLE of price) 73328
# [93312     0     0     0 23085     0] Valued at (based on MLE of price) 184005
# [137170      0      0      0      0      0] Valued at (based on MLE of price) 137170
# [114725      0      0     48      0      0] Valued at (based on MLE of price) 114913
# [363294      0      0      0     23      0] Valued at (based on MLE of price) 363384
# done
# Updating from contract:  Grain 2.11491028183
# Updating from contract:  Food 3.36908480889
# Updating from contract:  Grain 2.30088286482
# Updating from contract:  Food 4.62027957791
# Updating from contract:  Diamonds 99.1439900212
# New prices:  [1,0.0, 1.91979186134,0.7071067811865476, 3.8532406021,0.7071067811865476, 19.4079845391,10.995044111072348, 83.2624448891,45.86729669483256, 0,1.0]
# Factories
# [7221 3918    0    0    0    0] Valued at (based on MLE of price) 333443
# [151  98   2   0   0   0] Valued at (based on MLE of price) 8477
# [-11756      0      0  22930      0      0] Valued at (based on MLE of price) 1897451
# [99540     0     0     0 24739     0] Valued at (based on MLE of price) 2159369
# [147611      0      0      0      0      0] Valued at (based on MLE of price) 147611
# [122192      0      0     48      0      0] Valued at (based on MLE of price) 126188
# [389078      0      0      0     25      0] Valued at (based on MLE of price) 391159
# done
# Updating from contract:  Grain 1.36114697766
# Updating from contract:  Food 3.80121990821
# Updating from contract:  Grain 1.33058143741
# Updating from contract:  Food 4.35419519569
# New prices:  [1,0.0, 1.82435267844,0.7071067811865476, 3.86334575283,0.7071067811865476, 19.550787965,11.35100747759721, 78.5165485918,43.21253364348753, 0,1.0]
# Factories
# [7705 4132    0    0    0    0] Valued at (based on MLE of price) 23668
# [ 6 98  2  0  0  0] Valued at (based on MLE of price) 392
# [-13552      0      0  24504      0      0] Valued at (based on MLE of price) 81115
# [108218      0      0      0  26371      0] Valued at (based on MLE of price) 210098
# [157775      0      0      0      0      0] Valued at (based on MLE of price) 157775
# [129968      0      0     50      0      0] Valued at (based on MLE of price) 130161
# [416230      0      0      0     25      0] Valued at (based on MLE of price) 416326
# done
# Updating from contract:  Grain 1.72932968987
# Updating from contract:  Food 3.82600542207
# Updating from contract:  Grain 1.59952433086
# Updating from contract:  Food 4.10953085435
# Updating from contract:  Diamonds 74.8897291772
# New prices:  [1,0.0, 1.84699326969,0.7071067811865476, 3.91934505989,0.7071067811865476, 20.322163776,10.911079169140185, 81.9596922117,43.981344308734535, 0,1.0]
# Factories
# [8192 4294    0    0    0    0] Valued at (based on MLE of price) 360126
# [85 98  2  0  0  0] Valued at (based on MLE of price) 8280
# [-14486      0      0  26020      0      0] Valued at (based on MLE of price) 2118105
# [113940      0      0      0  28035      0] Valued at (based on MLE of price) 2411679
# [168076      0      0      0      0      0] Valued at (based on MLE of price) 168076
# [138092      0      0     50      0      0] Valued at (based on MLE of price) 142189
# [440974      0      0      0     23      0] Valued at (based on MLE of price) 442859
# done
# Updating from contract:  Grain 1.92039942982
# Updating from contract:  Food 3.16992619233
# Updating from contract:  Grain 1.70843459591
# Updating from contract:  Food 3.27002130366
# New prices:  [1,0.0, 1.91986470224,0.7071067811865476, 3.89009832822,0.7071067811865476, 19.4888789292,10.72595904462015, 76.0119377102,45.83541942100135, 0,1.0]
# Factories
# [8795 4416    0    0    0    0] Valued at (based on MLE of price) 25973
# [175  98   2   0   0   0] Valued at (based on MLE of price) 564
# [-14475      0      0  27508      0      0] Valued at (based on MLE of price) 92533
# [124192      0      0      0  29629      0] Valued at (based on MLE of price) 239451
# [178529      0      0      0      0      0] Valued at (based on MLE of price) 178529
# [147021      0      0     50      0      0] Valued at (based on MLE of price) 147215
# [470486      0      0      0     25      0] Valued at (based on MLE of price) 470583
# done
# Updating from contract:  Food 3.76731536069
# Updating from contract:  Grain 2.2905418114
# Updating from contract:  Food 3.84534122656
# Updating from contract:  Grain 1.38159499411
# New prices:  [1,0.0, 1.85397632013,0.7071067811865476, 3.84011255148,0.7094405531241293, 20.536424266,11.341332808357121, 78.9189998031,45.53629834286779, 0,1.0]
# Factories
# [9325 4580    0    0    0    0] Valued at (based on MLE of price) 17816
# [107  98   2   0   0   0] Valued at (based on MLE of price) 292
# [-14736      0      0  29024      0      0] Valued at (based on MLE of price) 39073
# [127927      0      0      0  31305      0] Valued at (based on MLE of price) 185965
# [188919      0      0      0      0      0] Valued at (based on MLE of price) 188919
# [155312      0      0     50      0      0] Valued at (based on MLE of price) 155404
# [496523      0      0      0     21      0] Valued at (based on MLE of price) 496561
# done
# Updating from contract:  Grain 1.89931927482
# Updating from contract:  Food 3.50318907089
# Updating from contract:  Grain 2.5022178523
# Updating from contract:  Food 3.64359123723
# Updating from contract:  Diamonds 19.6199906245
# New prices:  [1,0.0, 1.75376212288,0.7075722183856681, 3.83941787536,0.7071067811865476, 19.5169919566,11.459126041412683, 82.0000579567,46.23071879872196, 0,1.0]
# Factories
# [9810 4756    0    0    0    0] Valued at (based on MLE of price) 399802
# [191  98   2   0   0   0] Valued at (based on MLE of price) 8391
# [-15395      0      0  30534      0      0] Valued at (based on MLE of price) 2488394
# [138568      0      0      0  32906      0] Valued at (based on MLE of price) 2836861
# [199118      0      0      0      0      0] Valued at (based on MLE of price) 199118
# [163891      0      0     50      0      0] Valued at (based on MLE of price) 167991
# [525863      0      0      0     24      0] Valued at (based on MLE of price) 527831
# done
# Updating from contract:  Grain 2.26021372731
# Updating from contract:  Food 4.78100748207
# Updating from contract:  Grain 1.03241127005
# Updating from contract:  Food 3.00526951505
# New prices:  [1,0.0, 1.77809047519,0.7075426066121042, 3.81395066036,0.7071067811865476, 21.8705375309,11.20972937659745, 77.2171059091,42.750566831207664, 0,1.0]
# Factories
# [10250  4896     0     0     0     0] Valued at (based on MLE of price) 28923
# [269  98   2   0   0   0] Valued at (based on MLE of price) 650
# [-16076      0      0  32060      0      0] Valued at (based on MLE of price) 106199
# [145368      0      0      0  34547      0] Valued at (based on MLE of price) 277128
# [209620      0      0      0      0      0] Valued at (based on MLE of price) 209620
# [171992      0      0     50      0      0] Valued at (based on MLE of price) 172182
# [552706      0      0      0     25      0] Valued at (based on MLE of price) 552801
# done
# Updating from contract:  Grain 1.33926128966
# Updating from contract:  Food 3.22813526765
# Updating from contract:  Grain 2.05782564779
# Updating from contract:  Food 3.76462711011
# New prices:  [1,0.0, 1.90514220743,0.7071067811865476, 3.8196281242,0.7071067811865476, 20.829211898,11.881227539069451, 80.9351015416,47.368098286808035, 0,1.0]
# Factories
# [10747  5052     0     0     0     0] Valued at (based on MLE of price) 30043
# [261 100   0   0   0   0] Valued at (based on MLE of price) 642
# [-17032      0      0  33610      0      0] Valued at (based on MLE of price) 111345
# [154109      0      0      0  36179      0] Valued at (based on MLE of price) 292299
# [220041      0      0      0      0      0] Valued at (based on MLE of price) 220041
# [179898      0      0     50      0      0] Valued at (based on MLE of price) 180088
# [579497      0      0      0     25      0] Valued at (based on MLE of price) 579592
# done
# New prices:  [1,0.0, 1.87656567733,0.7115966076986393, 3.88234823523,0.7071067811865476, 19.5463891906,11.271156560729162, 78.6409153341,44.62118381702198, 0,1.0]
# Factories
# [11324  5196     0     0     0     0] Valued at (based on MLE of price) 21074
# [132  98   2   0   0   0] Valued at (based on MLE of price) 319
# [-18368      0      0  35162      0      0] Valued at (based on MLE of price) 47615
# [159157      0      0      0  37845      0] Valued at (based on MLE of price) 230175
# [230583      0      0      0      0      0] Valued at (based on MLE of price) 230583
# [187964      0      0     50      0      0] Valued at (based on MLE of price) 188057
# [605171      0      0      0     25      0] Valued at (based on MLE of price) 605217
# done
# Updating from contract:  Grain 1.62016358854
# Updating from contract:  Food 3.57607082495
# Updating from contract:  Grain 2.10685859082
# Updating from contract:  Food 3.6242824813
# New prices:  [1,0.0, 1.77282995743,0.7071067811865476, 3.88128977621,0.7071067811865476, 19.8845283564,11.053446045794184, 78.2413477943,47.55058309116437, 0,1.0]
# Factories
# [11814  5354     0     0     0     0] Valued at (based on MLE of price) 32594
# [175  98   2   0   0   0] Valued at (based on MLE of price) 563
# [-20817      0      0  36754      0      0] Valued at (based on MLE of price) 121835
# [161926      0      0      0  39545      0] Valued at (based on MLE of price) 315411
# [240944      0      0      0      0      0] Valued at (based on MLE of price) 240944
# [195193      0      0     50      0      0] Valued at (based on MLE of price) 195387
# [627122      0      0      0     25      0] Valued at (based on MLE of price) 627219
# done
# Updating from contract:  Grain 1.65298546665
# Updating from contract:  Food 3.41154420748
# Updating from contract:  Grain 2.02065741994
# Updating from contract:  Food 3.56164358982
# Updating from contract:  Fuel 36.3048556944
# New prices:  [1,0.0, 1.8769067996,0.7071067811865476, 3.84074611562,0.7071067811865476, 19.7675838561,12.024275779844324, 78.0720562149,47.86019043681712, 0,1.0]
# Factories
# [12382  5528     0     0     0     0] Valued at (based on MLE of price) 121657
# [163  98   2   0   0   0] Valued at (based on MLE of price) 2139
# [-21005      0      0  38264      0      0] Valued at (based on MLE of price) 735381
# [168799      0      0      0  41199      0] Valued at (based on MLE of price) 983203
# [251170      0      0      0      0      0] Valued at (based on MLE of price) 251170
# [203661      0      0     48      0      0] Valued at (based on MLE of price) 204609
# [653773      0      0      0     25      0] Valued at (based on MLE of price) 654267
# done
# Updating from contract:  Grain 1.95953445932
# Updating from contract:  Food 4.91585287482
# Updating from contract:  Grain 1.70862336837
# Updating from contract:  Food 4.03643078606
# New prices:  [1,0.0, 1.80467450075,0.7071067811865476, 3.83500397564,0.7071067811865476, 19.862932463,11.08768475951674, 83.1315722841,45.14108098918419, 0,1.0]
# Factories
# [12867  5712     0     0     0     0] Valued at (based on MLE of price) 34772
# [164  98   2   0   0   0] Valued at (based on MLE of price) 547
# [-21376      0      0  39770      0      0] Valued at (based on MLE of price) 131142
# [179974      0      0      0  42799      0] Valued at (based on MLE of price) 344108
# [261396      0      0      0      0      0] Valued at (based on MLE of price) 261396
# [212532      0      0     48      0      0] Valued at (based on MLE of price) 212716
# [682048      0      0      0     23      0] Valued at (based on MLE of price) 682136
# done
# Updating from contract:  Diamonds 73.880241184
# Updating from contract:  Diamonds 146.811379424
# New prices:  [1,0.0, 1.81386062077,0.7071067811865476, 3.78959685045,0.7148146958245037, 22.2081760013,11.194836336397522, 79.1841555293,45.29202583047177, 0,1.0]
# Factories
# [13344  5850     0     0     0     0] Valued at (based on MLE of price) 476571
# [252  98   2   0   0   0] Valued at (based on MLE of price) 8170
# [-20571      0      0  41234      0      0] Valued at (based on MLE of price) 3244508
# [185568      0      0      0  44459      0] Valued at (based on MLE of price) 3706016
# [271865      0      0      0      0      0] Valued at (based on MLE of price) 271865
# [221617      0      0     50      0      0] Valued at (based on MLE of price) 225576
# [707512      0      0      0     25      0] Valued at (based on MLE of price) 709491
# done
# Updating from contract:  Grain 1.39462167307
# Updating from contract:  Food 3.98310891705
# Updating from contract:  Grain 1.76850060981
# Updating from contract:  Food 4.46246134054
# New prices:  [1,0.0, 1.73193156144,0.7071067811865476, 3.77844440118,0.7071067811865476, 20.5608992396,11.815164768058239, 77.6432243988,48.02813319746112, 0,1.0]
# Factories
# [13732  6006     0     0     0     0] Valued at (based on MLE of price) 36425
# [313  98   2   0   0   0] Valued at (based on MLE of price) 690
# [-21120      0      0  42746      0      0] Valued at (based on MLE of price) 140393
# [194722      0      0      0  46069      0] Valued at (based on MLE of price) 368791
# [282324      0      0      0      0      0] Valued at (based on MLE of price) 282324
# [230076      0      0     50      0      0] Valued at (based on MLE of price) 230264
# [737090      0      0      0     25      0] Valued at (based on MLE of price) 737184
# done
# New prices:  [1,0.0, 1.76394777274,0.7071067811865476, 3.84933301324,0.7071067811865476, 20.5174774811,11.600111277254161, 77.43221313,46.89289661693875, 0,1.0]
# Factories
# [14152  6140     0     0     0     0] Valued at (based on MLE of price) 37786
# [459 100   0   0   0   0] Valued at (based on MLE of price) 843
# [-22447      0      0  44300      0      0] Valued at (based on MLE of price) 148078
# [199101      0      0      0  47747      0] Valued at (based on MLE of price) 382895
# [292822      0      0      0      0      0] Valued at (based on MLE of price) 292822
# [237643      0      0     48      0      0] Valued at (based on MLE of price) 237827
# [763037      0      0      0     23      0] Valued at (based on MLE of price) 763125
# done
# Updating from contract:  Grain 1.42608400173
# Updating from contract:  Food 4.38417718098
# Updating from contract:  Food 2.53724646114
# Updating from contract:  Grain 1.4522609956
# New prices:  [1,0.0, 1.82472505723,0.7071067811865476, 3.81702693703,0.7093312639007752, 20.3134619604,11.227383123189005, 86.8215510354,43.59168748113114, 0,1.0]
# Factories
# [14527  6324     0     0     0     0] Valued at (based on MLE of price) 26066
# [470  98   2   0   0   0] Valued at (based on MLE of price) 652
# [-22234      0      0  45778      0      0] Valued at (based on MLE of price) 61298
# [204041      0      0      0  49441      0] Valued at (based on MLE of price) 294257
# [303146      0      0      0      0      0] Valued at (based on MLE of price) 303146
# [246690      0      0     50      0      0] Valued at (based on MLE of price) 246781
# [784047      0      0      0     25      0] Valued at (based on MLE of price) 784092
# done
# Updating from contract:  Grain 1.951041184
# Updating from contract:  Food 3.51247278079
# Updating from contract:  Grain 1.54752651314
# Updating from contract:  Food 4.24247657032
# Updating from contract:  Diamonds 73.2388184235
# New prices:  [1,0.0, 1.74452358134,0.7071067811865476, 3.82511785165,0.7071067811865476, 18.6244613134,10.904917289037016, 84.8090541632,45.475460667481045, 0,1.0]
# Factories
# [14970  6534     0     0     0     0] Valued at (based on MLE of price) 569112
# [429  98   2   0   0   0] Valued at (based on MLE of price) 8909
# [-22725      0      0  47286      0      0] Valued at (based on MLE of price) 3987555
# [213972      0      0      0  51071      0] Valued at (based on MLE of price) 4545255
# [313274      0      0      0      0      0] Valued at (based on MLE of price) 313274
# [255681      0      0     48      0      0] Valued at (based on MLE of price) 259751
# [809966      0      0      0     25      0] Valued at (based on MLE of price) 812086
# done
# Updating from contract:  Grain 1.91759029388
# Updating from contract:  Food 4.25625964357
# Updating from contract:  Grain 1.45118121707
# Updating from contract:  Food 3.83281118719
# Updating from contract:  Fuel 20.9998627225
# Updating from contract:  Fuel 19.5045388776
# Updating from contract:  Diamonds 5.14644424613
# New prices:  [1,0.0, 1.87812337626,0.7071067811865476, 3.86649015159,0.7071067811865476, 20.9748401201,10.721851757144627, 80.4990650772,44.34995677783969, 0,1.0]
# Factories
# [15451  6694     0     0     0     0] Valued at (based on MLE of price) 554311
# [570  98   2   0   0   0] Valued at (based on MLE of price) 8619
# [-21997      0      0  48770      0      0] Valued at (based on MLE of price) 3903942
# [222095      0      0      0  52713      0] Valued at (based on MLE of price) 4465442
# [323532      0      0      0      0      0] Valued at (based on MLE of price) 323532
# [263833      0      0     50      0      0] Valued at (based on MLE of price) 267857
# [836999      0      0      0     23      0] Valued at (based on MLE of price) 838850
# done
# Updating from contract:  Grain 1.92677555573
# Updating from contract:  Food 3.16186492771
# Updating from contract:  Grain 1.78418611724
# Updating from contract:  Food 3.7952424199
# New prices:  [1,0.0, 1.80796345616,0.7071067811865476, 3.83250987059,0.712150396081108, 21.2612527017,10.669767988563073, 87.5196667946,47.66824873870501, 0,1.0]
# Factories
# [15951  6838     0     0     0     0] Valued at (based on MLE of price) 42157
# [626  98   2   0   0   0] Valued at (based on MLE of price) 1009
# [-22179      0      0  50284      0      0] Valued at (based on MLE of price) 170534
# [232548      0      0      0  54319      0] Valued at (based on MLE of price) 440726
# [333968      0      0      0      0      0] Valued at (based on MLE of price) 333968
# [272195      0      0     50      0      0] Valued at (based on MLE of price) 272386
# [864402      0      0      0     25      0] Valued at (based on MLE of price) 864497
# done
# Updating from contract:  Grain 1.85254903862
# Updating from contract:  Food 3.68024410313
# Updating from contract:  Grain 1.27714766051
# Updating from contract:  Food 3.4225816453
# Updating from contract:  Fuel 25.1695851482
# Updating from contract:  Fuel 18.8833886796
# Updating from contract:  Diamonds 57.9363562569
# New prices:  [1,0.0, 1.8435846975,0.7071067811865476, 3.88325678351,0.7071067811865476, 20.5816820372,11.225823946898236, 79.086769221,45.86379485470271, 0,1.0]
# Factories
# [16357  7012     0     0     0     0] Valued at (based on MLE of price) 570913
# [599  98   2   0   0   0] Valued at (based on MLE of price) 8507
# [-23465      0      0  51824      0      0] Valued at (based on MLE of price) 4075127
# [240157      0      0      0  55974      0] Valued at (based on MLE of price) 4666959
# [344371      0      0      0      0      0] Valued at (based on MLE of price) 344371
# [280131      0      0     50      0      0] Valued at (based on MLE of price) 284085
# [889424      0      0      0     24      0] Valued at (based on MLE of price) 891322
# done
# Updating from contract:  Grain 1.4960042921
# Updating from contract:  Food 4.01393731784
# Updating from contract:  Grain 2.11135778739
# Updating from contract:  Food 3.66983965433
# New prices:  [1,0.0, 1.81389390492,0.7071067811865476, 3.87231923022,0.7071067811865476, 20.8635368305,10.937617077317686, 74.9048102789,43.89912662958162, 0,1.0]
# Factories
# [16792  7156     0     0     0     0] Valued at (based on MLE of price) 44502
# [689  98   2   0   0   0] Valued at (based on MLE of price) 1076
# [-23289      0      0  53304      0      0] Valued at (based on MLE of price) 183121
# [245748      0      0      0  57623      0] Valued at (based on MLE of price) 468882
# [354838      0      0      0      0      0] Valued at (based on MLE of price) 354838
# [288805      0      0     48      0      0] Valued at (based on MLE of price) 288990
# [916800      0      0      0     25      0] Valued at (based on MLE of price) 916896
# done
# Updating from contract:  Grain 1.80376367409
# Updating from contract:  Food 3.20105618689
# Updating from contract:  Fuel 2.74588503684
# Updating from contract:  Grain 1.94792106138
# Updating from contract:  Food 3.06836955592
# Updating from contract:  Fuel 25.9280135826
# New prices:  [1,0.0, 1.76169365182,0.7071067811865476, 3.93829780411,0.7094080509694441, 21.4788088533,10.885388184641375, 77.0380222824,45.26508148594359, 0,1.0]
# Factories
# [17231  7348     0     0     0     0] Valued at (based on MLE of price) 175057
# [708  98   2   0   0   0] Valued at (based on MLE of price) 2855
# [-24292      0      0  54852      0      0] Valued at (based on MLE of price) 1153863
# [256561      0      0      0  59223      0] Valued at (based on MLE of price) 1528600
# [365036      0      0      0      0      0] Valued at (based on MLE of price) 365036
# [296548      0      0     50      0      0] Valued at (based on MLE of price) 297621
# [947225      0      0      0     23      0] Valued at (based on MLE of price) 947719
# done
# Updating from contract:  Grain 2.3814990648
# Updating from contract:  Food 4.56163294046
# Updating from contract:  Grain 1.63284083474
# Updating from contract:  Food 3.96527428883
# Updating from contract:  Fuel 36.687801979
# Updating from contract:  Fuel 28.5552242321
# New prices:  [1,0.0, 1.85768315047,0.7071067811865476, 3.9353463642,0.7282504368747521, 20.4201254884,11.849159229540426, 79.5097490631,45.9039406205247, 0,1.0]
# Factories
# [17720  7462     0     0     0     0] Valued at (based on MLE of price) 170094
# [878 100   0   0   0   0] Valued at (based on MLE of price) 2920
# [-24342      0      0  56328      0      0] Valued at (based on MLE of price) 1125882
# [265693      0      0      0  60855      0] Valued at (based on MLE of price) 1508359
# [375581      0      0      0      0      0] Valued at (based on MLE of price) 375581
# [305598      0      0     50      0      0] Valued at (based on MLE of price) 306619
# [975093      0      0      0     25      0] Valued at (based on MLE of price) 975603
# done
# Updating from contract:  Grain 2.62296500652
# Updating from contract:  Food 4.97506811347
# Updating from contract:  Grain 2.40315617325
# Updating from contract:  Food 3.8473612277
# Updating from contract:  Fuel 19.269845079
# New prices:  [1,0.0, 1.89171375508,0.7071067811865476, 3.82184678777,0.7094798903059935, 21.2272257556,11.188683051943498, 81.2187995659,47.53292754616647, 0,1.0]
# Factories
# [18252  7602     0     0     0     0] Valued at (based on MLE of price) 179621
# [922  98   2   0   0   0] Valued at (based on MLE of price) 3044
# [-24206      0      0  57829      0      0] Valued at (based on MLE of price) 1203343
# [269946      0      0      0  62543      0] Valued at (based on MLE of price) 1597560
# [386023      0      0      0      0      0] Valued at (based on MLE of price) 386023
# [314352      0      0     47      0      0] Valued at (based on MLE of price) 315349
# [998362      0      0      0     25      0] Valued at (based on MLE of price) 998892
# done
# Updating from contract:  Grain 3.12841347902
# Updating from contract:  Food 4.38729756704
# Updating from contract:  Food 3.52535975076
# Updating from contract:  Grain 2.04811786695
# New prices:  [1,0.0, 1.80332238132,0.7129372743756169, 3.89979165502,0.7071067811865476, 20.1535031352,11.234948476561206, 80.1395087385,45.54827862272219, 0,1.0]
# Factories
# [18712  7798     0     0     0     0] Valued at (based on MLE of price) 32774
# [869  98   2   0   0   0] Valued at (based on MLE of price) 1049
# [-24625      0      0  59332      0      0] Valued at (based on MLE of price) 82369
# [275566      0      0      0  64201      0] Valued at (based on MLE of price) 391341
# [396244      0      0      0      0      0] Valued at (based on MLE of price) 396244
# [323131      0      0     50      0      0] Valued at (based on MLE of price) 323221
# [1024438       0       0       0      25       0] Valued at (based on MLE of price) 1024483
# done
# Updating from contract:  Grain 2.19407062612
# Updating from contract:  Food 5.07492980624
# Updating from contract:  Grain 2.14365323905
# Updating from contract:  Food 4.12549984699
# Updating from contract:  Diamonds 138.278469625
# Updating from contract:  Diamonds 91.8122724053
# New prices:  [1,0.0, 1.90109944248,0.7071067811865476, 3.90155043173,0.7095336497538027, 19.6050148891,10.384878249890534, 85.1007077888,45.97026274094143, 0,1.0]
# Factories
# [19290  7938     0     0     0     0] Valued at (based on MLE of price) 694819
# [950  98   2   0   0   0] Valued at (based on MLE of price) 9460
# [-25032      0      0  60812      0      0] Valued at (based on MLE of price) 5150112
# [284055      0      0      0  65839      0] Valued at (based on MLE of price) 5887000
# [406605      0      0      0      0      0] Valued at (based on MLE of price) 406605
# [332378      0      0     50      0      0] Valued at (based on MLE of price) 336633
# [1049335       0       0       0      25       0] Valued at (based on MLE of price) 1051462
# done
# Updating from contract:  Grain 1.97732689902
# Updating from contract:  Food 4.52868301519
# Updating from contract:  Food 3.53151430945
# Updating from contract:  Grain 2.70738558591
# New prices:  [1,0.0, 1.87754297404,0.7084884946669439, 3.84795840389,0.7071067811865476, 20.1493000177,10.912784942158474, 81.2899512187,47.93283284960056, 0,1.0]
# Factories
# [19701  8102     0     0     0     0] Valued at (based on MLE of price) 34912
# [946 100   0   0   0   0] Valued at (based on MLE of price) 1133
# [-25032      0      0  62294      0      0] Valued at (based on MLE of price) 91927
# [293674      0      0      0  67463      0] Valued at (based on MLE of price) 420338
# [417052      0      0      0      0      0] Valued at (based on MLE of price) 417052
# [341348      0      0     50      0      0] Valued at (based on MLE of price) 341441
# [1076520       0       0       0      25       0] Valued at (based on MLE of price) 1076566
# done
# Updating from contract:  Grain 1.71571325524
# Updating from contract:  Food 4.17362211894
# Updating from contract:  Grain 2.05107568869
# Updating from contract:  Food 3.39255178919
# Updating from contract:  Diamonds 148.804996683
# New prices:  [1,0.0, 1.80724274403,0.7071067811865476, 3.79132057695,0.7071067811865476, 19.7976572565,11.290632842165454, 82.6383593353,45.290361157432464, 0,1.0]
# Factories
# [20242  8278     0     0     0     0] Valued at (based on MLE of price) 704322
# [865  98   2   0   0   0] Valued at (based on MLE of price) 9128
# [-24588      0      0  63760      0      0] Valued at (based on MLE of price) 5244433
# [299012      0      0      0  69121      0] Valued at (based on MLE of price) 6011058
# [427358      0      0      0      0      0] Valued at (based on MLE of price) 427358
# [350814      0      0     46      0      0] Valued at (based on MLE of price) 354615
# [1102006       0       0       0      23       0] Valued at (based on MLE of price) 1103906
# done
# Updating from contract:  Grain 2.72230078307
# Updating from contract:  Food 3.85546317612
# Updating from contract:  Grain 1.40898302716
# Updating from contract:  Food 3.8005316014
# New prices:  [1,0.0, 1.85703144243,0.7071067811865476, 3.87820064399,0.7071067811865476, 20.0428098574,11.233697140541734, 87.2901331298,43.56859768188963, 0,1.0]
# Factories
# [20697  8432     0     0     0     0] Valued at (based on MLE of price) 53397
# [911  98   2   0   0   0] Valued at (based on MLE of price) 1298
# [-25768      0      0  65314      0      0] Valued at (based on MLE of price) 227532
# [304543      0      0      0  70801      0] Valued at (based on MLE of price) 579123
# [437779      0      0      0      0      0] Valued at (based on MLE of price) 437779
# [358214      0      0     48      0      0] Valued at (based on MLE of price) 358400
# [1125247       0       0       0      25       0] Valued at (based on MLE of price) 1125343
# done
# Updating from contract:  Grain 1.29225331141
# Updating from contract:  Food 3.74181589537
# Updating from contract:  Grain 1.29099499924
# Updating from contract:  Food 3.29009429757
# New prices:  [1,0.0, 1.82339079018,0.7071067811865476, 3.83473652106,0.7071067811865476, 21.3044453384,11.076453172915885, 79.2320330565,43.85905764290087, 0,1.0]
# Factories
# [21144  8594     0     0     0     0] Valued at (based on MLE of price) 54099
# [911  98   2   0   0   0] Valued at (based on MLE of price) 1294
# [-26038      0      0  66806      0      0] Valued at (based on MLE of price) 230145
# [314690      0      0      0  72393      0] Valued at (based on MLE of price) 592298
# [448198      0      0      0      0      0] Valued at (based on MLE of price) 448198
# [367184      0      0     50      0      0] Valued at (based on MLE of price) 367375
# [1156098       0       0       0      25       0] Valued at (based on MLE of price) 1156193
# done
# Updating from contract:  Grain 1.80369502119
# Updating from contract:  Food 3.94730483638
# Updating from contract:  Grain 1.70738689667
# Updating from contract:  Food 4.91035435303
# New prices:  [1,0.0, 1.78511016567,0.7071067811865476, 3.81284949021,0.7071067811865476, 19.7001917343,11.414575636865521, 85.1759219357,42.821694950870494, 0,1.0]
# Factories
# [21590  8770     0     0     0     0] Valued at (based on MLE of price) 55028
# [911  98   2   0   0   0] Valued at (based on MLE of price) 1292
# [-27056      0      0  68340      0      0] Valued at (based on MLE of price) 233514
# [323422      0      0      0  74031      0] Valued at (based on MLE of price) 605691
# [458520      0      0      0      0      0] Valued at (based on MLE of price) 458520
# [374882      0      0     50      0      0] Valued at (based on MLE of price) 375072
# [1181944       0       0       0      25       0] Valued at (based on MLE of price) 1182039
# done
# Updating from contract:  Food 2.92887903687
# Updating from contract:  Grain 1.06884772992
# Updating from contract:  Food 3.35328479498
# Updating from contract:  Diamonds 27.811024927
# Updating from contract:  Grain 2.20891389777
# New prices:  [1,0.0, 1.97717768081,0.7071067811865476, 3.82372978758,0.7071067811865476, 20.5515311145,11.438931116203976, 77.5082509008,43.38320965511204, 0,1.0]
# Factories
# [22051  8950     0     0     0     0] Valued at (based on MLE of price) 39746
# [875 100   0   0   0   0] Valued at (based on MLE of price) 1072
# [-27796      0      0  69864      0      0] Valued at (based on MLE of price) 110337
# [327450      0      0      0  75713      0] Valued at (based on MLE of price) 477148
# [468837      0      0      0      0      0] Valued at (based on MLE of price) 468837
# [383402      0      0     50      0      0] Valued at (based on MLE of price) 383500
# [1206094       0       0       0      25       0] Valued at (based on MLE of price) 1206143
# done
# Updating from contract:  Grain 2.2195336946
# Updating from contract:  Food 3.70264984088
# Updating from contract:  Grain 1.85204358992
# Updating from contract:  Food 3.39790392531
# Updating from contract:  Fuel 39.377343562
# Updating from contract:  Fuel 22.81275259
# New prices:  [1,0.0, 1.83352814677,0.7071067811865476, 3.84875374242,0.7071067811865476, 20.3766701219,11.567781299492067, 78.7958649141,43.819794570013016, 0,1.0]
# Factories
# [22571  9100     0     0     0     0] Valued at (based on MLE of price) 207998
# [830  98   2   0   0   0] Valued at (based on MLE of price) 2867
# [-27895      0      0  71364      0      0] Valued at (based on MLE of price) 1426265
# [331608      0      0      0  77385      0] Valued at (based on MLE of price) 1908456
# [479310      0      0      0      0      0] Valued at (based on MLE of price) 479310
# [392101      0      0     50      0      0] Valued at (based on MLE of price) 393119
# [1231130       0       0       0      23       0] Valued at (based on MLE of price) 1231598
# done
# Updating from contract:  Grain 2.17132213289
# Updating from contract:  Food 4.69742200458
# Updating from contract:  Grain 2.16038301646
# Updating from contract:  Food 3.53804260993
# New prices:  [1,0.0, 1.81666069662,0.7071067811865476, 3.90119954068,0.7081103324359898, 21.1911202454,11.537464501989783, 81.1848969945,45.3598369276741, 0,1.0]
# Factories
# [23055  9282     0     0     0     0] Valued at (based on MLE of price) 59265
# [761  98   2   0   0   0] Valued at (based on MLE of price) 1151
# [-28674      0      0  72884      0      0] Valued at (based on MLE of price) 255661
# [340574      0      0      0  78999      0] Valued at (based on MLE of price) 648764
# [489621      0      0      0      0      0] Valued at (based on MLE of price) 489621
# [400330      0      0     50      0      0] Valued at (based on MLE of price) 400525
# [1259366       0       0       0      23       0] Valued at (based on MLE of price) 1259455
# done
# Updating from contract:  Food 3.23227590545
# Updating from contract:  Diamonds 50.6168129865
# Updating from contract:  Grain 1.48730610909
# Updating from contract:  Food 4.6852663327
# Updating from contract:  Grain 1.76097555103
# Updating from contract:  Fuel 1.15075207831
# Updating from contract:  Diamonds 10.5911952472
# Updating from contract:  Fuel 18.8718822243
# New prices:  [1,0.0, 1.93457757908,0.7071067811865476, 3.92805148616,0.7083111277173382, 20.25760149,11.320980339918249, 80.4884670988,46.06291512199984, 0,1.0]
# Factories
# [23492  9462     0     0     0     0] Valued at (based on MLE of price) 215169
# [805  98   2   0   0   0] Valued at (based on MLE of price) 2830
# [-28922      0      0  74398      0      0] Valued at (based on MLE of price) 1478203
# [348116      0      0      0  80653      0] Valued at (based on MLE of price) 1981952
# [499880      0      0      0      0      0] Valued at (based on MLE of price) 499880
# [408408      0      0     50      0      0] Valued at (based on MLE of price) 409420
# [1285348       0       0       0      23       0] Valued at (based on MLE of price) 1285813
# done
# Updating from contract:  Grain 1.88906885208
# Updating from contract:  Food 4.04151849448
# Updating from contract:  Grain 1.10222325393
# Updating from contract:  Food 4.04715006391
# New prices:  [1,0.0, 1.83075412844,0.7073621308728764, 3.94001403598,0.7071067811865476, 19.9890957659,11.336753643427464, 77.7607684438,44.157679019975795, 0,1.0]
# Factories
# [23991  9618     0     0     0     0] Valued at (based on MLE of price) 61886
# [787  98   2   0   0   0] Valued at (based on MLE of price) 1181
# [-29641      0      0  75922      0      0] Valued at (based on MLE of price) 269492
# [354667      0      0      0  82297      0] Valued at (based on MLE of price) 678918
# [510307      0      0      0      0      0] Valued at (based on MLE of price) 510307
# [416627      0      0     50      0      0] Valued at (based on MLE of price) 416824
# [1311207       0       0       0      25       0] Valued at (based on MLE of price) 1311305
# done
# New prices:  [1,0.0, 1.94237678174,0.7071067811865476, 3.87857777353,0.7071067811865476, 19.0873565234,10.932032027202075, 82.9349278131,45.53914615665449, 0,1.0]
# Factories
# ...
# [619  98   2   0   0   0] Valued at (based on MLE of price) 8883
# [-41405      0      0 125530      0      0] Valued at (based on MLE of price) 10333539
# [570497      0      0      0 136792      0] Valued at (based on MLE of price) 11876235
# [852915      0      0      0      0      0] Valued at (based on MLE of price) 852915
# [698991      0      0     48      0      0] Valued at (based on MLE of price) 702958
# [2178412       0       0       0      24       0] Valued at (based on MLE of price) 2180395
# done
# Updating from contract:  Grain 1.30789438397
# Updating from contract:  Food 4.01677534766
# Updating from contract:  Grain 1.53366426296
# Updating from contract:  Food 3.300684839
# New prices:  [1,0.0, 1.83586535474,0.7071067811865476, 3.8679613082,0.7071067811865476, 20.9482700487,10.828883657685733, 83.0176667665,47.99973175998282, 0,1.0]
# Factories
# [40645 15130     0     0     0     0] Valued at (based on MLE of price) 99167
# [619  98   2   0   0   0] Valued at (based on MLE of price) 1005
# [-42022      0      0 127042      0      0] Valued at (based on MLE of price) 449371
# [578788      0      0      0 138420      0] Valued at (based on MLE of price) 1114191
# [863237      0      0      0      0      0] Valued at (based on MLE of price) 863237
# [707508      0      0     50      0      0] Valued at (based on MLE of price) 707701
# [2205693       0       0       0      24       0] Valued at (based on MLE of price) 2205785
# done
# Updating from contract:  Grain 1.31076107912
# Updating from contract:  Food 4.98489256595
# Updating from contract:  Grain 2.19847373204
# Updating from contract:  Food 4.22965977458
# Updating from contract:  Fuel 10.6623757277
# New prices:  [1,0.0, 1.86806176966,0.710144440239248, 3.91111296516,0.7089952052492476, 20.0137448612,11.868388960864436, 80.911260777,46.45976311602847, 0,1.0]
# Factories
# [41085 15284     0     0     0     0] Valued at (based on MLE of price) 346975
# [610  98   2   0   0   0] Valued at (based on MLE of price) 2611
# [-42138      0      0 128514      0      0] Valued at (based on MLE of price) 2529908
# [584473      0      0      0 140103      0] Valued at (based on MLE of price) 3388458
# [873728      0      0      0      0      0] Valued at (based on MLE of price) 873728
# [716784      0      0     50      0      0] Valued at (based on MLE of price) 717784
# [2229357       0       0       0      25       0] Valued at (based on MLE of price) 2229857
# done
# Updating from contract:  Grain 1.43930046045
# Updating from contract:  Food 3.37276290172
# Updating from contract:  Grain 2.23241069884
# Updating from contract:  Food 3.44860415741
# Updating from contract:  Fuel 16.4146375088
# New prices:  [1,0.0, 1.91078935586,0.7071067811865476, 3.84531658878,0.7071067811865476, 21.3042972943,11.84001491277098, 77.0273773024,44.73064185197603, 0,1.0]
# Factories
# [41689 15414     0     0     0     0] Valued at (based on MLE of price) 370073
# [571  98   2   0   0   0] Valued at (based on MLE of price) 2701
# [-42862      0      0 130046      0      0] Valued at (based on MLE of price) 2727676
# [588807      0      0      0 141777      0] Valued at (based on MLE of price) 3609266
# [884253      0      0      0      0      0] Valued at (based on MLE of price) 884253
# [724478      0      0     50      0      0] Valued at (based on MLE of price) 725543
# [2255091       0       0       0      23       0] Valued at (based on MLE of price) 2255580
# done
# Updating from contract:  Grain 2.01407340701
# Updating from contract:  Food 3.92907103367
# Updating from contract:  Fuel 6.35975974746
# Updating from contract:  Grain 2.12204044695
# Updating from contract:  Food 4.5095996465
# Updating from contract:  Diamonds 42.2630298884
# New prices:  [1,0.0, 1.92402587865,0.7071067811865476, 3.84370261775,0.7071067811865476, 20.3138422437,11.765456301086672, 85.0993150757,44.64406090039764, 0,1.0]
# Factories
# [42303 15588     0     0     0     0] Valued at (based on MLE of price) 1368831
# [384  98   2   0   0   0] Valued at (based on MLE of price) 8893
# [-44911      0      0 131650      0      0] Valued at (based on MLE of price) 11158413
# [596207      0      0      0 143420      0] Valued at (based on MLE of price) 12801150
# [894608      0      0      0      0      0] Valued at (based on MLE of price) 894608
# [731607      0      0     48      0      0] Valued at (based on MLE of price) 735691
# [2281314       0       0       0      24       0] Valued at (based on MLE of price) 2283356
# done
# Updating from contract:  Grain 1.58748976458
# Updating from contract:  Food 3.68225047459
# Updating from contract:  Fuel 39.3950763411
# Updating from contract:  Grain 1.35198470607
# Updating from contract:  Food 4.04273815455
# Updating from contract:  Fuel 6.55833152729
# New prices:  [1,0.0, 1.87828155328,0.7071067811865476, 3.87159662882,0.7071067811865476, 20.2067484663,10.762183589785506, 83.3146524388,41.369798987044874, 0,1.0]
# Factories
# [42865 15750     0     0     0     0] Valued at (based on MLE of price) 361121
# [404  98   2   0   0   0] Valued at (based on MLE of price) 2424
# [-46710      0      0 133232      0      0] Valued at (based on MLE of price) 2645475
# [605703      0      0      0 145027      0] Valued at (based on MLE of price) 3536227
# [904892      0      0      0      0      0] Valued at (based on MLE of price) 904892
# [739356      0      0     48      0      0] Valued at (based on MLE of price) 740325
# [2310293       0       0       0      23       0] Valued at (based on MLE of price) 2310757
# done
# Updating from contract:  Fuel 18.3233593247
# New prices:  [1,0.0, 1.93144747642,0.7071067811865476, 3.88855944721,0.7071067811865476, 21.1682976735,10.906347829986956, 76.702964759,45.41068600222446, 0,1.0]
# Factories
# [43440 15894     0     0     0     0] Valued at (based on MLE of price) 379888
# [450  98   2   0   0   0] Valued at (based on MLE of price) 2566
# [-47491      0      0 134758      0      0] Valued at (based on MLE of price) 2805106
# [611617      0      0      0 146681      0] Valued at (based on MLE of price) 3716604
# [915263      0      0      0      0      0] Valued at (based on MLE of price) 915263
# [747267      0      0     50      0      0] Valued at (based on MLE of price) 748325
# [2335795       0       0       0      25       0] Valued at (based on MLE of price) 2336324
# done
# Updating from contract:  Grain 1.87715821027
# Updating from contract:  Food 4.02069782605
# Updating from contract:  Grain 1.69699368398
# Updating from contract:  Food 4.18415277756
# New prices:  [1,0.0, 1.8060258207,0.7071067811865476, 3.87304249318,0.7071067811865476, 21.1827694111,11.636163052290968, 85.6872582713,43.23476117008521, 0,1.0]
# Factories
# [43934 16062     0     0     0     0] Valued at (based on MLE of price) 106142
# [515  98   2   0   0   0] Valued at (based on MLE of price) 902
# [-48039      0      0 136282      0      0] Valued at (based on MLE of price) 479786
# [623194      0      0      0 148285      0] Valued at (based on MLE of price) 1197508
# [925528      0      0      0      0      0] Valued at (based on MLE of price) 925528
# [755245      0      0     50      0      0] Valued at (based on MLE of price) 755438
# [2363330       0       0       0      23       0] Valued at (based on MLE of price) 2363419
# done
# Updating from contract:  Grain 1.36427735504
# Updating from contract:  Food 3.24269899172
# Updating from contract:  Grain 1.23999034484
# Updating from contract:  Food 3.77364749865
# Updating from contract:  Fuel 28.364107782
# Updating from contract:  Fuel 27.9272650044
# New prices:  [1,0.0, 1.90419812259,0.7071067811865476, 3.83957768578,0.708143127540848, 21.4659522217,11.181436875952716, 78.1017512499,46.9627436852803, 0,1.0]
# Factories
# [44408 16176     0     0     0     0] Valued at (based on MLE of price) 391641
# [630  98   2   0   0   0] Valued at (based on MLE of price) 2776
# [-49999      0      0 137852      0      0] Valued at (based on MLE of price) 2909125
# [628891      0      0      0 149929      0] Valued at (based on MLE of price) 3847259
# [936141      0      0      0      0      0] Valued at (based on MLE of price) 936141
# [762455      0      0     48      0      0] Valued at (based on MLE of price) 763485
# [2391257       0       0       0      23       0] Valued at (based on MLE of price) 2391750
# done
# Updating from contract:  Grain 2.17597245888
# Updating from contract:  Food 4.0816580264
# Updating from contract:  Grain 2.65804463125
# Updating from contract:  Food 4.18452918823
# New prices:  [1,0.0, 1.8330089304,0.7084317857261743, 3.81204165653,0.7071067811865476, 20.6334677856,10.917261181166957, 85.6504814184,44.447644569028974, 0,1.0]
# Factories
# [44951 16302     0     0     0     0] Valued at (based on MLE of price) 107094
# [607  98   2   0   0   0] Valued at (based on MLE of price) 988
# [-50287      0      0 139362      0      0] Valued at (based on MLE of price) 480966
# [636774      0      0      0 151569      0] Valued at (based on MLE of price) 1214561
# [946739      0      0      0      0      0] Valued at (based on MLE of price) 946739
# [770513      0      0     50      0      0] Valued at (based on MLE of price) 770703
# [2418208       0       0       0      25       0] Valued at (based on MLE of price) 2418303
# done
# Updating from contract:  Diamonds 40.5293069865
# New prices:  [1,0.0, 1.86499198034,0.7071067811865476, 3.87867642202,0.7354494627214992, 20.1511941311,11.047116526005137, 77.8235714874,46.167331561426515, 0,1.0]
# Factories
# [45427 16450     0     0     0     0] Valued at (based on MLE of price) 1325624
# [651  98   2   0   0   0] Valued at (based on MLE of price) 8433
# [-51180      0      0 140910      0      0] Valued at (based on MLE of price) 10914939
# [640441      0      0      0 153242      0] Valued at (based on MLE of price) 12566280
# [957183      0      0      0      0      0] Valued at (based on MLE of price) 957183
# [778376      0      0     48      0      0] Valued at (based on MLE of price) 782111
# [2443416       0       0       0      24       0] Valued at (based on MLE of price) 2445283
# done
# Updating from contract:  Grain 1.63127015257
# Updating from contract:  Food 3.0592238929
# Updating from contract:  Grain 1.88881413431
# Updating from contract:  Food 3.84414773603
# Updating from contract:  Fuel 18.2982927384
# New prices:  [1,0.0, 1.82182658639,0.7071067811865476, 3.82467252078,0.7140559283699803, 20.4364171361,11.335865153444079, 85.5511733498,44.481959795115785, 0,1.0]
# Factories
# [45895 16620     0     0     0     0] Valued at (based on MLE of price) 385548
# [666  98   2   0   0   0] Valued at (based on MLE of price) 2709
# [-51913      0      0 142435      0      0] Valued at (based on MLE of price) 2858948
# [650414      0      0      0 154847      0] Valued at (based on MLE of price) 3814931
# [967510      0      0      0      0      0] Valued at (based on MLE of price) 967510
# [786739      0      0     49      0      0] Valued at (based on MLE of price) 787740
# [2471916       0       0       0      25       0] Valued at (based on MLE of price) 2472426
# done
# Updating from contract:  Grain 1.25984925823
# Updating from contract:  Food 3.62112713055
# Updating from contract:  Grain 1.84147163237
# Updating from contract:  Food 4.34467332904
# Updating from contract:  Diamonds 121.125938242
# Updating from contract:  Fuel 28.4268753769
# Updating from contract:  Fuel 4.74994291075
# Updating from contract:  Diamonds 137.474837911
# New prices:  [1,0.0, 1.82199087979,0.7071067811865476, 3.86115246879,0.7071067811865476, 19.3267849536,11.788731163756307, 79.9256147114,44.387502155990596, 0,1.0]
# Factories
# [46313 16768     0     0     0     0] Valued at (based on MLE of price) 1386505
# [698  98   2   0   0   0] Valued at (based on MLE of price) 8690
# [-53141      0      0 143970      0      0] Valued at (based on MLE of price) 11453749
# [657037      0      0      0 156497      0] Valued at (based on MLE of price) 13165155
# [978024      0      0      0      0      0] Valued at (based on MLE of price) 978024
# [795137      0      0     48      0      0] Valued at (based on MLE of price) 798973
# [2498879       0       0       0      23       0] Valued at (based on MLE of price) 2500717
# done
# Updating from contract:  Grain 2.53456547071
# Updating from contract:  Food 4.29647639507
# Updating from contract:  Grain 1.67969850905
# Updating from contract:  Food 3.89533095225
# Updating from contract:  Fuel 30.0356335351
# Updating from contract:  Fuel 12.3765560871
# New prices:  [1,0.0, 1.87747838652,0.7071067811865476, 3.85667884047,0.7071067811865476, 21.3469175842,10.637790267766196, 77.7596390685,47.846643746598666, 0,1.0]
# Factories
# [46835 16904     0     0     0     0] Valued at (based on MLE of price) 407683
# [787  98   2   0   0   0] Valued at (based on MLE of price) 2921
# [-53149      0      0 145472      0      0] Valued at (based on MLE of price) 3052229
# [668126      0      0      0 158099      0] Valued at (based on MLE of price) 4043052
# [988461      0      0      0      0      0] Valued at (based on MLE of price) 988461
# [803585      0      0     50      0      0] Valued at (based on MLE of price) 804652
# [2527176       0       0       0      25       0] Valued at (based on MLE of price) 2527709
# done
# Updating from contract:  Food 3.00546346755
# Updating from contract:  Grain 2.069016918
# Updating from contract:  Food 4.242465092
# Updating from contract:  Grain 2.14784245895
# New prices:  [1,0.0, 1.85804114033,0.7071067811865476, 3.83769855655,0.7071067811865476, 20.5596330122,11.23725381597447, 73.634268164,46.19453991082612, 0,1.0]
# Factories
# [47356 17028     0     0     0     0] Valued at (based on MLE of price) 78994
# [870  98   2   0   0   0] Valued at (based on MLE of price) 1055
# [-53618      0      0 146978      0      0] Valued at (based on MLE of price) 219473
# [673133      0      0      0 159745      0] Valued at (based on MLE of price) 969945
# [998989      0      0      0      0      0] Valued at (based on MLE of price) 998989
# [812074      0      0     48      0      0] Valued at (based on MLE of price) 812163
# [2553985       0       0       0      25       0] Valued at (based on MLE of price) 2554031
# done
# Updating from contract:  Grain 1.73189439979
# Updating from contract:  Food 3.5524214428
# Updating from contract:  Grain 1.82931980946
# Updating from contract:  Food 2.94361651108
# Updating from contract:  Fuel 21.1682931898
# Updating from contract:  Fuel 23.7094507803
# New prices:  [1,0.0, 1.83293735566,0.7071067811865476, 3.81983712989,0.7090523094266536, 20.7223365332,10.689345941731526, 74.9061216322,46.26560014000011, 0,1.0]
# Factories
# [47854 17222     0     0     0     0] Valued at (based on MLE of price) 404734
# [844 100   0   0   0   0] Valued at (based on MLE of price) 2916
# [-52819      0      0 148444      0      0] Valued at (based on MLE of price) 3023287
# [676621      0      0      0 161417      0] Valued at (based on MLE of price) 4021558
# [1009161       0       0       0       0       0] Valued at (based on MLE of price) 1009161
# [820595      0      0     50      0      0] Valued at (based on MLE of price) 821631
# [2580883       0       0       0      23       0] Valued at (based on MLE of price) 2581359
# done
# Updating from contract:  Food 3.39998145532
# Updating from contract:  Grain 1.81256751339
# Updating from contract:  Food 3.66513175754
# Updating from contract:  Grain 2.63679546657
# New prices:  [1,0.0, 1.8257369122,0.7082687384352597, 3.81523087197,0.7071067811865476, 19.8721046653,11.52569989316159, 67.7406879658,44.813668912012034, 0,1.0]
# Factories
# [48368 17360     0     0     0     0] Valued at (based on MLE of price) 80062
# [855  98   2   0   0   0] Valued at (based on MLE of price) 1037
# [-53358      0      0 149964      0      0] Valued at (based on MLE of price) 220436
# [682851      0      0      0 163031      0] Valued at (based on MLE of price) 980502
# [1019668       0       0       0       0       0] Valued at (based on MLE of price) 1019668
# [829004      0      0     50      0      0] Valued at (based on MLE of price) 829095
# [2611833       0       0       0      25       0] Valued at (based on MLE of price) 2611878
# done
