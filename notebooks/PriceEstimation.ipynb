# %%
### IMPORTS

import math,sys
import numpy
import scipy,scipy.optimize,scipy.spatial,scipy.spatial.distance,scipy.stats
import json
import sqlite3
from collections import *
from enum import Enum
numpy.random.seed(1)

# %%
### CONSTANTS

# Names of goods
Goods = ["Credits","Grain","Food","Fuel","Diamonds","null"]

def createInventory(credits=0,grain=0,food=0,fuel=0,diamonds=0):
    return numpy.array([credits,grain,food,fuel,diamonds,0])

# %%
class BoundedAdaptiveNormalDistribution:
    NumSamples = 100
    MinVariance = 0.5
    
    def __init__(self, mean, variance, lower=None, upper=None):
        self.mean = mean
        self.variance = variance
        self.lower = lower
        self.upper = upper
        
    def __repr__(self):
        return str(self.mean) + str(",") + str(math.sqrt(self.variance))
        
    def draw(self):
        while True:
            value = scipy.stats.norm.rvs(loc=self.mean, scale=self.variance)
            if self.lower and self.lower > value:
                continue
            if self.upper and self.upper < value:
                continue
            return value
        
    def update(self,newValue):
        NumSamples = BoundedAdaptiveNormalDistribution.NumSamples
        oldMean = self.mean;
        self.mean = ((self.mean * (NumSamples - 1)) + newValue) / NumSamples
        self.variance = (self.variance*(NumSamples-1) + ((newValue - oldMean)*(newValue - self.mean))) / NumSamples;
        self.variance = max(self.variance, BoundedAdaptiveNormalDistribution.MinVariance)

class Agent:
    def __init__(self, loc):
        self.loc = numpy.copy(loc)
        
    def __repr__(self):
        return self.__dict__.__repr__()

class Trader(Agent):
    def __init__(self, loc):
        Agent.__init__(self, loc)
        self.inventory = numpy.copy(createInventory(credits=1000))

class Factory(Trader):
    def __init__(self,loc,productionCost,output,capacity):
        Trader.__init__(self,loc)
        self.productionCost = numpy.copy(productionCost)
        self.output = numpy.copy(output)
        self.capacity = capacity
        self.demand = 0

    def getEpochsOfProduction(self):
        epochs = 100
        for i in range(0,len(self.productionCost)):
            if i == 0:
                continue # You can go negative in money with no penalty for now
            if self.productionCost[i] == 0:
                continue
            epochs = min(epochs, self.inventory[i] // self.productionCost[i] // self.capacity)
        return epochs
    
    def getCurrentProduction(self):
        currentProduction = self.capacity
        for i in range(0,len(self.productionCost)):
            if i == 0:
                continue # You can go negative in money with no penalty for now
            if self.productionCost[i] == 0:
                continue
            currentProduction = min(currentProduction, self.inventory[i] // self.productionCost[i])
        return currentProduction

    def isOutputStockFull(self):
        for i in range(0,len(self.productionCost)):
            if i == 0:
                continue # You can go negative in money with no penalty for now
            if self.output[i] and self.inventory[i] >= 1000:
                return True # You can't produce more of a good if you have 1000 or more in stock
        return False
    
    def produceOne(self):
        self.inventory -= self.productionCost
        self.inventory += self.output
        

class Merchant(Trader):
    def __init__(self,loc):
        Trader.__init__(self,loc)

class Contract():
    def __init__(self,source,destination,good,quantity,pricePerUnit):
        self.source = source
        self.destination = destination
        self.good = good
        self.quantity = quantity
        self.pricePerUnit = pricePerUnit

class Need():
    def __init__(self, good, price):
        self.good = good
        self.price = price

# %%
## HELPER FUNCTIONS

def spawnLocation():
    return numpy.array([numpy.random.randint(0,100), numpy.random.randint(0,100)])

# %%
PlanetLocation = spawnLocation()
Factories = [
    # Farm: 1 credit -> 1 grain
    Factory(spawnLocation(), createInventory(credits=1), createInventory(grain=1), 100),
    
    # Bakery: 1 credit + 1 grain -> 1 food
    Factory(spawnLocation(), createInventory(credits=1, grain=1), createInventory(food=1), 100),
    
    # Oil rig: 5 credits -> 1 fuel
    Factory(spawnLocation(), createInventory(credits=5), createInventory(fuel=1), 100),
    
    # Diamond mine:  10 credits -> 1 diamond
    Factory(spawnLocation(), createInventory(credits=10), createInventory(diamonds=1), 100),
    
    # Planet: 1 food -> 10 credits, 1 fuel -> 40 credits, 1 diamond -> 160 credits
    Factory(PlanetLocation, createInventory(food=1), createInventory(credits=10), 100),
    Factory(PlanetLocation, createInventory(fuel=1), createInventory(credits=40), 50),
    Factory(PlanetLocation, createInventory(diamonds=1), createInventory(credits=160), 25),
]
Contracts = []
Needs = []

# Credits are always worth 1 credit with no variance
EstimatedPrices = [BoundedAdaptiveNormalDistribution(1,0)]
for x in range(1,len(Goods)):
    # All other goods have an unknown worth that we model with a normal distribution capped between [0,1000]
    # The mean & variance will change as people buy goods.
    EstimatedPrices.append(BoundedAdaptiveNormalDistribution(0,1,1,1000))

for epoch in range(0,1):
    for turn in range(0,100):
        Contracts = []
        Needs = []
        for i in range(0,100):
            # First, draw to estimate the prices of items
            prices = [1,]
            for i2 in range(1,len(Goods)):
                prices.append(EstimatedPrices[i2].draw())
            for f in Factories:
                currentProduction = f.getCurrentProduction()
                remainingProduction = f.capacity - currentProduction
                if remainingProduction > 0 and f.isOutputStockFull() == False:
                    # Next, decide if more production makes sense given these prices
                    costValue = numpy.dot(f.productionCost,prices)
                    outputValue = numpy.dot(f.output,prices)
                    if costValue < outputValue:
                        # Try to find suppliers for missing goods
                        for goodToPurchase in range(1,len(Goods)):
                            need = (f.productionCost[goodToPurchase] * f.capacity) - f.inventory[goodToPurchase]
                            if need > 0:
                                foundBuyer = False
                                for supplier in Factories:
                                    if supplier.inventory[goodToPurchase] > 0 and \
                                    supplier.productionCost[goodToPurchase] == 0: # For now, don't buy from someone who needs the good in their production
                                        # Buy goods from supplier
                                        foundBuyer = True
                                        quantityToBuy = 1 # Don't try to max out in case your price estimate is bad
                                        #quantityToBuy = min(need, supplier.inventory[goodToProduce])
                                        f.inventory[goodToPurchase] += quantityToBuy
                                        supplier.inventory[goodToPurchase] -= quantityToBuy
                                        f.inventory[0] -= quantityToBuy * prices[goodToPurchase]
                                        supplier.inventory[0] += quantityToBuy * prices[goodToPurchase]
                                        Contracts.append(Contract(supplier,f,goodToPurchase,quantityToBuy,prices[goodToPurchase]))
                                if foundBuyer == False:
                                    # We could not find a buyer for a good that we need, it must be worth more than we think it is
                                    # Let's estimate the good's worth by assuming it's essential to production and takes the rest of the margin from cost/benefit
                                    maximumPrice = (outputValue - costValue) - prices[goodToPurchase]
                                    if maximumPrice > prices[goodToPurchase]:
                                        Needs.append(Need(goodToPurchase,maximumPrice))

        # Now, Produce when it makes sense
      
        for f in Factories:
            if f.isOutputStockFull():
                continue
            for x in range(0,f.getCurrentProduction()):
                if f.isOutputStockFull():
                    break
                # First, draw to estimate the prices of items
                prices = [1,]
                for i2 in range(1,len(Goods)):
                    prices.append(EstimatedPrices[i2].draw())
                # Next, decide if more production makes sense given these prices
                costValue = numpy.dot(f.productionCost,prices)
                outputValue = numpy.dot(f.output,prices)
                if costValue < outputValue:
                    # Produce
                    f.produceOne()

        # Based on the contracts, adjust the prices
        for c in Contracts:
            EstimatedPrices[c.good].update(c.pricePerUnit)
        
        # Based on needs, adjust the prices
        for n in Needs:
            EstimatedPrices[n.good].update(n.price)
        
        # Some debug prints
        if turn % 10 == 0:
            newPrices = [1]
            for x in range(1,len(Goods)):
                newPrices.append(EstimatedPrices[x].mean)
            for c in Contracts:
                print("Updating from contract: ",Goods[c.good],c.pricePerUnit)
            print("New prices: ",EstimatedPrices)
            print("Factories")
            for f in Factories:
                print(f.inventory,"Valued at (based on MLE of price)",int(numpy.dot(f.inventory,newPrices)))
            print('done')
            sys.stdout.flush()
# Out:
# New prices:  [1,0.0, 0,1.0, 4.4648445785,3.501381553662492, 23.4290940052,17.82555538597546, 99.6473291038,75.72087944276774, 0,1.0]
# Factories
# [900 100   0   0   0   0] Valued at (based on MLE of price) 900
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# [1000    0    0    0    0    0] Valued at (based on MLE of price) 1000
# done
# Updating from contract:  Grain 2.132351126202287
# Updating from contract:  Fuel 23.9927102285
# Updating from contract:  Grain 2.4797198580810305
# Updating from contract:  Food 4.28534587157
# Updating from contract:  Diamonds 87.0353706301
# Updating from contract:  Food 2.07409768519
# Updating from contract:  Fuel 14.5612056404
# Updating from contract:  Grain 1.6328575489270498
# Updating from contract:  Food 9.31847249076
# Updating from contract:  Food 2.55896163056
# Updating from contract:  Diamonds 115.820835809
# Updating from contract:  Grain 1.7223053074643666
# Updating from contract:  Food 6.58133416446
# Updating from contract:  Grain 1.6185528890936083
# Updating from contract:  Grain 2.686077912728741
# Updating from contract:  Food 7.30727073485
# Updating from contract:  Grain 2.793129612725515
# Updating from contract:  Food 9.81654730578
# Updating from contract:  Food 1.70626485748
# Updating from contract:  Grain 1.5894255874123837
# Updating from contract:  Food 6.30034490869
# Updating from contract:  Grain 1.2380805828359258
# Updating from contract:  Grain 1.8344005769359029
# Updating from contract:  Food 6.12138164726
# Updating from contract:  Grain 1.3111662104698423
# Updating from contract:  Food 5.77911254467
# Updating from contract:  Grain 1.577556724653998
# Updating from contract:  Food 7.29821430512
# Updating from contract:  Grain 1.9821914952422102
# Updating from contract:  Grain 1.2513712983997238
# Updating from contract:  Food 7.70472649233
# Updating from contract:  Grain 2.045710231836808
# Updating from contract:  Food 6.98799807942
# Updating from contract:  Diamonds 145.181884655
# Updating from contract:  Grain 1.748459784801143
# Updating from contract:  Food 7.9643464482
# Updating from contract:  Food 1.44415989494
# Updating from contract:  Fuel 5.90886835348
# Updating from contract:  Food 2.34202539062
# Updating from contract:  Diamonds 158.193265657
# Updating from contract:  Grain 1.234329726311148
# Updating from contract:  Food 4.80043482486
# Updating from contract:  Grain 1.9235817242544277
# Updating from contract:  Food 3.84332070483
# Updating from contract:  Food 1.73495088589
# Updating from contract:  Grain 1.3390196572380537
# Updating from contract:  Food 9.23640776398
# Updating from contract:  Grain 1.8141784489128743
# Updating from contract:  Grain 1.4909625442962828
# Updating from contract:  Food 2.84339672012
# Updating from contract:  Grain 2.3402875722082603
# Updating from contract:  Food 8.46018477498
# Updating from contract:  Grain 2.2794353435410826
# Updating from contract:  Grain 2.146921661898853
# Updating from contract:  Grain 1.9873268668430586
# Updating from contract:  Fuel 34.9942898066
# Updating from contract:  Grain 1.8822485807553317
# Updating from contract:  Food 4.71829118399
# Updating from contract:  Grain 1.145724460704238
# Updating from contract:  Food 4.43500535948
# Updating from contract:  Grain 1.4439795824493902
# Updating from contract:  Food 1.1755096303
# Updating from contract:  Grain 2.2424425778579873
# Updating from contract:  Grain 2.508932263703694
# Updating from contract:  Grain 1.8992187654240633
# Updating from contract:  Food 8.33134762232
# Updating from contract:  Grain 2.091891314121625
# Updating from contract:  Food 6.10444452034
# Updating from contract:  Grain 1.8042062297497974
# Updating from contract:  Food 3.04836718174
# Updating from contract:  Grain 1.6308456144732253
# Updating from contract:  Food 7.06777454678
# Updating from contract:  Grain 2.359887740327064
# Updating from contract:  Grain 2.0600021321473134
# Updating from contract:  Food 7.20676701884
# Updating from contract:  Grain 2.1348279524401406
# Updating from contract:  Grain 2.402520834541815
# Updating from contract:  Food 6.9430284223
# Updating from contract:  Grain 1.590265594516448
# Updating from contract:  Food 5.30393695837
# Updating from contract:  Grain 3.2050370276457825
# Updating from contract:  Grain 2.4696525459267047
# Updating from contract:  Food 4.53384756416
# Updating from contract:  Grain 1.4591267636213106
# Updating from contract:  Food 2.98938462021
# Updating from contract:  Grain 1.8132556224154786
# Updating from contract:  Food 8.34792314999
# Updating from contract:  Grain 1.488426781517395
# Updating from contract:  Food 5.95725367726
# Updating from contract:  Grain 2.161251239683832
# Updating from contract:  Grain 2.3966058099229883
# Updating from contract:  Food 5.842687138
# Updating from contract:  Grain 2.3629334384808365
# Updating from contract:  Food 1.00136857927
# Updating from contract:  Grain 2.5220952166747637
# Updating from contract:  Food 6.93787867016
# Updating from contract:  Grain 3.0545136957500714
# Updating from contract:  Grain 1.2569587569132636
# Updating from contract:  Grain 1.7133900341704407
# Updating from contract:  Food 5.22863018319
# Updating from contract:  Grain 1.4363709868163212
# Updating from contract:  Grain 1.5070280547956856
# Updating from contract:  Food 7.25802839265
# Updating from contract:  Food 1.24238096812
# Updating from contract:  Grain 1.36555564969215
# Updating from contract:  Food 4.31623344098
# Updating from contract:  Grain 2.1460676272597756
# Updating from contract:  Grain 1.5124971957991618
# Updating from contract:  Food 5.00798451484
# Updating from contract:  Food 2.26665702232
# Updating from contract:  Grain 2.0218586347171077
# Updating from contract:  Grain 1.9061216099010796
# Updating from contract:  Food 7.86253485675
# Updating from contract:  Grain 2.209594008523367
# Updating from contract:  Grain 1.6042296018376188
# Updating from contract:  Food 6.93246005773
# Updating from contract:  Grain 1.5296075073480848
# Updating from contract:  Grain 1.5395731448733163
# Updating from contract:  Grain 1.6300108080490852
# Updating from contract:  Food 7.54749401454
# Updating from contract:  Food 2.15721252933
# Updating from contract:  Fuel 35.6289220245
# Updating from contract:  Grain 2.6246389582170604
# Updating from contract:  Food 7.80757108551
# Updating from contract:  Grain 1.7159692911820201
# Updating from contract:  Food 5.32763120991
# Updating from contract:  Grain 1.9290283742887036
# Updating from contract:  Grain 1.8160732303101996
# Updating from contract:  Food 6.55857748515
# Updating from contract:  Food 1.40716503718
# Updating from contract:  Grain 1.4173742793161268
# Updating from contract:  Food 3.59810778208
# Updating from contract:  Grain 2.1305868189620103
# Updating from contract:  Food 7.46964504074
# Updating from contract:  Grain 1.3543377812665502
# Updating from contract:  Food 8.41861086537
# Updating from contract:  Fuel 13.3134062379
# Updating from contract:  Grain 1.106357875773585
# Updating from contract:  Grain 1.5495143575775236
# Updating from contract:  Grain 2.812544967559904
# Updating from contract:  Food 9.12613781523
# Updating from contract:  Food 2.03764291176
# Updating from contract:  Grain 1.70586537454612
# Updating from contract:  Food 6.59253877139
# Updating from contract:  Grain 1.332042047383361
# Updating from contract:  Food 3.23222540591
# Updating from contract:  Grain 1.612875100963343
# Updating from contract:  Grain 1.92292934030128
# Updating from contract:  Grain 2.185788941727652
# Updating from contract:  Food 7.0156862289
# Updating from contract:  Grain 1.6323190943346095
# Updating from contract:  Food 6.04640936496
# Updating from contract:  Grain 1.9363823509988913
# Updating from contract:  Food 8.52813274629
# Updating from contract:  Food 2.43362799389
# Updating from contract:  Grain 2.260163962637052
# Updating from contract:  Grain 2.1627651213184476
# Updating from contract:  Grain 1.533113577798877
# Updating from contract:  Food 6.23064212662
# Updating from contract:  Food 5.49062770314
# Updating from contract:  Food 3.214014711
# Updating from contract:  Fuel 11.5817551668
# New prices:  [1,0.0, 1.8493566494366767,0.7071067811865476, 5.41002610798,2.4653633309000886, 21.2945607909,14.895977759773652, 92.7711958563,65.21785602600168, 0,1.0]
# Factories
# [1029  229    0    0    0    0] Valued at (based on MLE of price) 1452
# [767  13 322   0   0   0] Valued at (based on MLE of price) 2533
# [-2433     0     0   910     0     0] Valued at (based on MLE of price) 16945
# [-4712     0     0     0   940     0] Valued at (based on MLE of price) 82492
# [2919    0   28    0    0    0] Valued at (based on MLE of price) 3070
# [816   0   0  45   0   0] Valued at (based on MLE of price) 1774
# [1738    0    0    0   21    0] Valued at (based on MLE of price) 3686
# done
# Updating from contract:  Food 3.127413254
# Updating from contract:  Food 1.56094646686
# Updating from contract:  Grain 2.499764553994406
# Updating from contract:  Food 9.51447701425
# Updating from contract:  Food 2.45488224244
# Updating from contract:  Grain 1.9587602342604407
# Updating from contract:  Food 7.43333907089
# Updating from contract:  Fuel 30.3438340785
# Updating from contract:  Grain 2.3460408451324395
# Updating from contract:  Fuel 22.2909201042
# Updating from contract:  Grain 2.429842176224506
# Updating from contract:  Grain 2.5199162026907374
# Updating from contract:  Food 7.90037227576
# Updating from contract:  Fuel 19.5667576371
# Updating from contract:  Grain 2.0744872702420425
# Updating from contract:  Food 7.12496790518
# Updating from contract:  Grain 2.238678143841005
# Updating from contract:  Food 6.51217070933
# Updating from contract:  Grain 2.9426050201448377
# Updating from contract:  Food 9.97815978963
# Updating from contract:  Grain 1.6141877945824454
# Updating from contract:  Grain 1.3485807007097619
# Updating from contract:  Food 5.12463816024
# Updating from contract:  Grain 2.131759729287268
# Updating from contract:  Grain 3.1863040849150597
# Updating from contract:  Grain 2.3849402838636324
# Updating from contract:  Food 7.75702247992
# Updating from contract:  Food 2.54596344701
# Updating from contract:  Grain 2.851106439773971
# Updating from contract:  Food 9.95328699484
# Updating from contract:  Diamonds 98.364361998
# Updating from contract:  Grain 1.7971834233806225
# Updating from contract:  Diamonds 95.0536319016
# Updating from contract:  Food 2.78902378629
# Updating from contract:  Grain 1.9781755092206423
# Updating from contract:  Grain 1.700693150240918
# Updating from contract:  Food 4.67247573289
# Updating from contract:  Grain 2.598132002067534
# Updating from contract:  Food 2.81736271228
# Updating from contract:  Grain 1.6615506802775402
# Updating from contract:  Food 7.31711730305
# Updating from contract:  Grain 3.098117762512438
# Updating from contract:  Food 1.9173627723
# Updating from contract:  Grain 2.2429781273871723
# Updating from contract:  Food 5.22215522985
# Updating from contract:  Grain 2.046746586781014
# Updating from contract:  Food 9.35136043054
# Updating from contract:  Grain 2.442550493629246
# Updating from contract:  Diamonds 62.4418606994
# Updating from contract:  Grain 2.12162400263583
# Updating from contract:  Grain 2.594848154679325
# Updating from contract:  Grain 2.5351636112761176
# Updating from contract:  Grain 2.824809320769032
# Updating from contract:  Food 7.96639938019
# Updating from contract:  Grain 1.607938804034097
# Updating from contract:  Grain 1.6701648046449984
# Updating from contract:  Food 1.21363451996
# Updating from contract:  Grain 1.31276540002166
# Updating from contract:  Grain 1.9975090321554025
# Updating from contract:  Food 4.56820520827
# Updating from contract:  Food 2.40269050438
# Updating from contract:  Grain 2.12198968049054
# Updating from contract:  Grain 2.1812066946283695
# Updating from contract:  Food 6.67290006877
# Updating from contract:  Grain 2.197469953427781
# Updating from contract:  Grain 1.7235103969038224
# Updating from contract:  Food 4.77601362669
# Updating from contract:  Grain 2.6944112382085494
# Updating from contract:  Food 4.9363824551
# Updating from contract:  Grain 1.3485014550672425
# Updating from contract:  Food 7.5561494101
# Updating from contract:  Grain 2.186579083237236
# Updating from contract:  Food 6.43785483379
# Updating from contract:  Grain 1.7429498882707666
# Updating from contract:  Food 4.70017626578
# Updating from contract:  Grain 1.9613819929638385
# Updating from contract:  Food 5.88812933358
# Updating from contract:  Grain 1.832683586151514
# Updating from contract:  Food 4.91732086123
# Updating from contract:  Grain 2.5888213596973095
# Updating from contract:  Food 9.42729624465
# Updating from contract:  Food 1.55737875485
# Updating from contract:  Grain 1.8759317884841205
# Updating from contract:  Food 9.39912744147
# Updating from contract:  Grain 1.3920582849134715
# Updating from contract:  Food 6.15679784371
# Updating from contract:  Grain 2.6711456107167324
# Updating from contract:  Food 6.72087011235
# Updating from contract:  Grain 1.725082242325335
# Updating from contract:  Food 6.14642199374
# Updating from contract:  Grain 2.0218339289416076
# Updating from contract:  Food 7.19183891117
# Updating from contract:  Grain 2.1536246758214213
# Updating from contract:  Grain 2.8587056163238938
# Updating from contract:  Grain 2.474302806762595
# Updating from contract:  Food 7.92579143482
# Updating from contract:  Grain 1.4339455733552908
# Updating from contract:  Food 6.87296730391
# Updating from contract:  Grain 2.2201574870951015
# Updating from contract:  Food 6.34320917821
# Updating from contract:  Grain 2.3458062975403924
# Updating from contract:  Grain 2.5033170330984387
# Updating from contract:  Food 7.4589046636
# Updating from contract:  Food 3.0576425696
# Updating from contract:  Grain 2.455002753586207
# Updating from contract:  Food 5.59997991107
# Updating from contract:  Grain 1.7280483812692262
# Updating from contract:  Food 5.3300625546
# Updating from contract:  Grain 1.4346708264215282
# Updating from contract:  Food 8.48202721945
# Updating from contract:  Grain 3.275530571008072
# Updating from contract:  Food 7.07012142398
# Updating from contract:  Grain 2.5921294176468797
# Updating from contract:  Food 4.51580943671
# Updating from contract:  Food 3.20540333372
# Updating from contract:  Grain 2.465141644642186
# Updating from contract:  Food 7.47989143387
# Updating from contract:  Grain 3.0827217669750806
# Updating from contract:  Grain 1.6759926054937462
# Updating from contract:  Grain 1.88906927873105
# Updating from contract:  Food 1.50517671926
# Updating from contract:  Grain 1.8608332698403123
# Updating from contract:  Food 5.41851481021
# Updating from contract:  Food 1.56677857708
# Updating from contract:  Grain 2.2544202001098776
# Updating from contract:  Food 5.77640290841
# Updating from contract:  Grain 2.7645290071654394
# Updating from contract:  Food 4.33537346439
# Updating from contract:  Grain 1.9564992904974945
# Updating from contract:  Food 5.42826962255
# Updating from contract:  Grain 1.8061344256670244
# Updating from contract:  Grain 1.8406220157851052
# Updating from contract:  Food 5.83225120091
# Updating from contract:  Food 2.6128734193
# Updating from contract:  Grain 2.593513099182961
# Updating from contract:  Food 6.53364965977
# Updating from contract:  Grain 2.026058537013277
# Updating from contract:  Grain 2.003098389571841
# Updating from contract:  Food 7.77347308882
# Updating from contract:  Food 1.04209348721
# Updating from contract:  Grain 2.129952135768045
# Updating from contract:  Food 5.68641970856
# Updating from contract:  Grain 2.1632169701451387
# Updating from contract:  Food 6.67645032249
# Updating from contract:  Grain 2.235165352551048
# Updating from contract:  Food 6.66071067835
# Updating from contract:  Grain 1.680713046525709
# Updating from contract:  Grain 1.7978411139942891
# Updating from contract:  Food 7.09006516212
# Updating from contract:  Grain 2.479897300110256
# Updating from contract:  Food 3.99230152707
# Updating from contract:  Food 2.18965062257
# Updating from contract:  Grain 2.0279335958258224
# Updating from contract:  Grain 2.5493274167696303
# Updating from contract:  Grain 2.0724395134600675
# Updating from contract:  Grain 2.313838625927342
# Updating from contract:  Grain 2.285556604309778
# New prices:  [1,0.0, 2.1536623185092,0.7071067811865476, 5.48162452424,2.4743959293837183, 20.2448731989,12.604697862271935, 89.675788682,59.242325114389814, 0,1.0]
# Factories
# [1280  392    0    0    0    0] Valued at (based on MLE of price) 2124
# [1179   10  507    0    0    0] Valued at (based on MLE of price) 3979
# [-1861     0     0  1000     0     0] Valued at (based on MLE of price) 18383
# [-2836     0     0     0  1000     0] Valued at (based on MLE of price) 86839
# [5474    0   28    0    0    0] Valued at (based on MLE of price) 5627
# [2479    0    0   40    0    0] Valued at (based on MLE of price) 3288
# [4202    0    0    0   22    0] Valued at (based on MLE of price) 6174
# done
# Updating from contract:  Grain 1.8563073717689746
# Updating from contract:  Food 7.06378044157
# Updating from contract:  Grain 2.347002146524627
# Updating from contract:  Fuel 30.7156669137
# Updating from contract:  Grain 2.5019725177727206
# Updating from contract:  Food 9.54298203951
# Updating from contract:  Fuel 25.3322388969
# Updating from contract:  Food 2.81533436279
# Updating from contract:  Grain 1.9909041730063481
# Updating from contract:  Food 3.11453725313
# Updating from contract:  Food 1.88543118442
# Updating from contract:  Fuel 37.3850788793
# Updating from contract:  Grain 2.059493725648465
# Updating from contract:  Food 3.2089813444
# Updating from contract:  Fuel 13.9957184633
# Updating from contract:  Grain 1.883393125883528
# Updating from contract:  Grain 2.2525281570864055
# Updating from contract:  Food 7.13074342414
# Updating from contract:  Fuel 38.5206843322
# Updating from contract:  Diamonds 17.4728287914
# Updating from contract:  Grain 2.992707714048006
# Updating from contract:  Diamonds 142.09564447
# Updating from contract:  Grain 2.1568312362990683
# Updating from contract:  Food 4.82886770022
# Updating from contract:  Grain 1.6072962272410556
# Updating from contract:  Grain 2.5583301050898215
# Updating from contract:  Food 5.04189711996
# Updating from contract:  Grain 1.7894722720816645
# Updating from contract:  Grain 1.1282696785043274
# Updating from contract:  Food 2.76546704789
# Updating from contract:  Food 2.8542289951
# Updating from contract:  Grain 1.6063375630227439
# Updating from contract:  Food 8.48383804665
# Updating from contract:  Fuel 3.98097607194
# Updating from contract:  Grain 1.0115050597157067
# Updating from contract:  Food 7.61307461453
# Updating from contract:  Fuel 8.2181417172
# Updating from contract:  Grain 2.751494854522045
# Updating from contract:  Food 8.5048071476
# Updating from contract:  Grain 2.4685539067694355
# Updating from contract:  Food 4.85154785406
# Updating from contract:  Diamonds 119.558305873
# Updating from contract:  Food 1.13651253889
# Updating from contract:  Diamonds 152.192146281
# Updating from contract:  Grain 2.270159678195718
# Updating from contract:  Food 5.06100456622
# Updating from contract:  Grain 2.372026218131778
# Updating from contract:  Fuel 21.0753893128
# Updating from contract:  Grain 2.9672645261312693
# Updating from contract:  Food 9.58063696584
# Updating from contract:  Grain 1.8295601217365216
# Updating from contract:  Food 7.99105750319
# Updating from contract:  Grain 1.596530240968972
# Updating from contract:  Grain 1.943859263087931
# Updating from contract:  Food 7.75731196427
# Updating from contract:  Grain 1.9071350962202134
# Updating from contract:  Food 4.58626639781
# Updating from contract:  Grain 1.8078677704354233
# Updating from contract:  Grain 1.8835741500771024
# Updating from contract:  Food 5.52611272336
# Updating from contract:  Grain 2.123104238736508
# Updating from contract:  Grain 1.680432682922553
# Updating from contract:  Diamonds 63.7861614082
# Updating from contract:  Grain 2.1664604645710734
# Updating from contract:  Food 5.22488850052
# Updating from contract:  Grain 2.6851014079062394
# Updating from contract:  Grain 2.7457133422896103
# Updating from contract:  Food 7.18136362282
# Updating from contract:  Grain 2.445107361264353
# Updating from contract:  Grain 2.5432384015175993
# Updating from contract:  Grain 1.4249256909434835
# Updating from contract:  Food 5.31363144364
# Updating from contract:  Grain 2.129689095187547
# Updating from contract:  Grain 1.0957629646456049
# Updating from contract:  Food 6.6962226511
# Updating from contract:  Grain 1.437375016364509
# Updating from contract:  Food 2.34156058252
# Updating from contract:  Food 2.45544295443
# Updating from contract:  Grain 2.2687325391409954
# Updating from contract:  Food 8.51020014359
# Updating from contract:  Grain 2.2338469635354556
# Updating from contract:  Grain 1.9899518408732018
# Updating from contract:  Food 5.82071732072
# Updating from contract:  Grain 2.8473433338713554
# Updating from contract:  Grain 2.6252339843878323
# Updating from contract:  Food 1.11288254682
# Updating from contract:  Grain 2.2873955503070955
# Updating from contract:  Food 3.2777564842
# Updating from contract:  Grain 2.51066598958026
# Updating from contract:  Grain 1.1629591926870846
# Updating from contract:  Food 5.01975521367
# Updating from contract:  Grain 2.0714648341866435
# Updating from contract:  Food 9.19185124919
# Updating from contract:  Grain 2.1680059512645413
# Updating from contract:  Food 3.58508207342
# Updating from contract:  Grain 2.0221779522001757
# Updating from contract:  Grain 2.406434177018079
# Updating from contract:  Food 5.96282636905
# Updating from contract:  Grain 2.164146712593911
# Updating from contract:  Grain 2.1549624962799143
# Updating from contract:  Food 9.74055892721
# Updating from contract:  Grain 2.8634041522067903
# Updating from contract:  Food 5.61973256097
# Updating from contract:  Grain 2.754235523357994
# Updating from contract:  Food 5.43918415381
# Updating from contract:  Grain 2.1179628052978856
# Updating from contract:  Food 7.78901572733
# Updating from contract:  Grain 1.8196585781330372
# Updating from contract:  Grain 1.9357040007711075
# Updating from contract:  Grain 1.6185331338568725
# Updating from contract:  Food 4.85057251878
# Updating from contract:  Grain 2.794833887451835
# Updating from contract:  Food 5.76216797038
# Updating from contract:  Grain 2.0215749410229438
# Updating from contract:  Grain 1.9261591240287648
# Updating from contract:  Food 9.47703845113
# Updating from contract:  Grain 2.1777217558680264
# Updating from contract:  Food 3.8221713204
# Updating from contract:  Grain 2.1697821786860305
# Updating from contract:  Food 3.60849078269
# Updating from contract:  Food 2.32119784962
# Updating from contract:  Grain 2.589868844320936
# Updating from contract:  Grain 1.72822499679018
# Updating from contract:  Food 5.99551011385
# Updating from contract:  Grain 2.9477643142548007
# Updating from contract:  Grain 1.4947993168019424
# Updating from contract:  Food 3.37755498637
# Updating from contract:  Grain 1.6482807807549142
# Updating from contract:  Food 8.01941377461
# Updating from contract:  Food 1.46465581822
# Updating from contract:  Grain 2.1138152565152977
# Updating from contract:  Grain 2.5021105537725474
# Updating from contract:  Food 3.99949064455
# Updating from contract:  Grain 2.3916449960043096
# Updating from contract:  Food 5.04325945275
# Updating from contract:  Grain 1.776489509740553
# Updating from contract:  Food 4.08744540283
# Updating from contract:  Grain 1.2460447582534897
# Updating from contract:  Food 6.0520154822
# Updating from contract:  Grain 2.4819107022481783
# Updating from contract:  Food 5.00014631142
# Updating from contract:  Grain 2.5722446446572507
# Updating from contract:  Grain 1.3024753486586138
# Updating from contract:  Food 9.87947743215
# Updating from contract:  Grain 1.8694656213887728
# Updating from contract:  Food 4.11020225046
# Updating from contract:  Grain 2.9541388769250876
# Updating from contract:  Food 8.23770494611
# Updating from contract:  Grain 1.8391269169040068
# Updating from contract:  Food 7.37325400643
# Updating from contract:  Grain 2.10969666479452
# Updating from contract:  Food 4.38774707694
# Updating from contract:  Grain 1.4279143153100822
# Updating from contract:  Food 2.70356619326
# Updating from contract:  Grain 1.651947816653271
# Updating from contract:  Food 6.40937587369
# Updating from contract:  Food 2.28022550187
# Updating from contract:  Food 3.94859094463
# Updating from contract:  Food 1.15352226054
# Updating from contract:  Food 2.93223763162
# Updating from contract:  Food 1.32422134034
# New prices:  [1,0.0, 2.131891616029395,0.7071067811865476, 5.23023482226,2.5125158801336958, 19.4922799132,11.862932651227391, 88.4360492896,56.095557664045614, 0,1.0]
# Factories
# [1672  567    0    0    0    0] Valued at (based on MLE of price) 2880
# [1428   14  651    0    0    0] Valued at (based on MLE of price) 4862
# [-570    0    0 1000    0    0] Valued at (based on MLE of price) 18922
# [ -62    0    0    0 1000    0] Valued at (based on MLE of price) 88374
# [8220    0   34    0    0    0] Valued at (based on MLE of price) 8397
# [4283    0    0   44    0    0] Valued at (based on MLE of price) 5140
# [6978    0    0    0   22    0] Valued at (based on MLE of price) 8923
# done
# Updating from contract:  Grain 1.5014110616525769
# Updating from contract:  Fuel 36.4973393507
# Updating from contract:  Grain 2.017156778269147
# Updating from contract:  Food 7.08161999072
# Updating from contract:  Grain 1.7558642849769583
# Updating from contract:  Fuel 22.4923174953
# Updating from contract:  Food 1.74594535604
# Updating from contract:  Food 1.43646169424
# Updating from contract:  Grain 2.3659134197780425
# Updating from contract:  Food 4.2739402884
# Updating from contract:  Diamonds 85.4873168397
# Updating from contract:  Grain 2.0136938156357265
# Updating from contract:  Food 8.02071216987
# Updating from contract:  Grain 2.8049715126905337
# Updating from contract:  Food 4.30407261136
# Updating from contract:  Grain 1.8863194342163767
# Updating from contract:  Food 2.3233064892
# Updating from contract:  Diamonds 15.6574983606
# Updating from contract:  Grain 2.1634649124230094
# Updating from contract:  Food 8.87628568976
# Updating from contract:  Fuel 31.2794158314
# Updating from contract:  Grain 2.3072244321159565
# Updating from contract:  Diamonds 149.493857316
# Updating from contract:  Food 2.92434722203
# Updating from contract:  Grain 3.231462524026764
# Updating from contract:  Food 8.34226175346
# Updating from contract:  Grain 2.8522425267472014
# Updating from contract:  Food 4.53571139177
# Updating from contract:  Fuel 19.7402573076
# Updating from contract:  Grain 1.8600269120269985
# Updating from contract:  Food 7.91116414525
# Updating from contract:  Grain 1.268795764491223
# Updating from contract:  Fuel 23.6572768741
# Updating from contract:  Food 3.07621298505
# Updating from contract:  Grain 2.767284242551563
# Updating from contract:  Food 5.75832910004
# Updating from contract:  Food 2.88054774906
# Updating from contract:  Grain 3.383025732474594
# Updating from contract:  Grain 2.198995397622416
# Updating from contract:  Food 7.71267494592
# Updating from contract:  Grain 2.646688222859853
# Updating from contract:  Food 3.81620074834
# Updating from contract:  Grain 2.008544222323489
# Updating from contract:  Food 9.49321057906
# Updating from contract:  Grain 2.255055002838434
# Updating from contract:  Food 6.93400341741
# Updating from contract:  Grain 2.0414979486317226
# Updating from contract:  Food 3.83969790763
# Updating from contract:  Grain 1.4599818976206205
# Updating from contract:  Food 7.22921966483
# Updating from contract:  Grain 1.726500574719896
# Updating from contract:  Food 6.29298922545
# Updating from contract:  Grain 1.38996354196936
# Updating from contract:  Grain 1.7204668833698231
# Updating from contract:  Food 4.86631236834
# Updating from contract:  Food 1.59679088955
# Updating from contract:  Food 2.19951730171
# Updating from contract:  Grain 3.0849105355278965
# Updating from contract:  Food 7.4857650312
# Updating from contract:  Grain 3.2548201808744635
# Updating from contract:  Food 8.96084815805
# Updating from contract:  Grain 2.670056592403252
# Updating from contract:  Food 5.68847123117
# Updating from contract:  Fuel 33.1623113255
# Updating from contract:  Grain 2.4491523138157936
# Updating from contract:  Grain 1.8796057284378285
# Updating from contract:  Food 3.8287829964
# Updating from contract:  Grain 1.7513570573648276
# Updating from contract:  Food 7.98476488199
# Updating from contract:  Food 2.65390700295
# Updating from contract:  Grain 2.0210983960437368
# Updating from contract:  Food 3.23340302793
# Updating from contract:  Food 1.79668249547
# Updating from contract:  Grain 2.7358313244975236
# Updating from contract:  Food 5.21269912043
# Updating from contract:  Grain 2.317194980105658
# Updating from contract:  Grain 1.446459411737296
# Updating from contract:  Grain 1.1193779044318233
# Updating from contract:  Food 4.12984941128
# Updating from contract:  Grain 1.983282019285104
# Updating from contract:  Food 6.13180050577
# Updating from contract:  Grain 2.729324431187327
# Updating from contract:  Grain 1.6931619839672631
# Updating from contract:  Grain 2.7777552959871064
# Updating from contract:  Food 5.74479139413
# Updating from contract:  Grain 2.0860968713357613
# Updating from contract:  Grain 2.2688549604242114
# Updating from contract:  Grain 1.3888815364261626
# Updating from contract:  Food 4.27784900966
# Updating from contract:  Grain 3.113228945167937
# Updating from contract:  Grain 2.681129293857501
# Updating from contract:  Food 4.3543549255
# Updating from contract:  Grain 1.8224595074749652
# Updating from contract:  Food 7.7170386709
# Updating from contract:  Grain 1.648889893101184
# Updating from contract:  Grain 2.6359025696964666
# Updating from contract:  Food 8.33763318889
# Updating from contract:  Grain 1.8437406830111835
# Updating from contract:  Food 4.74497908768
# Updating from contract:  Grain 2.2206104417090837
# Updating from contract:  Food 3.48614433017
# Updating from contract:  Grain 2.2068580068350867
# Updating from contract:  Food 6.26179040482
# Updating from contract:  Grain 1.489445364611099
# Updating from contract:  Food 4.93952818275
# Updating from contract:  Grain 2.177028053543379
# Updating from contract:  Food 1.28790978995
# Updating from contract:  Grain 1.5462560539369523
# Updating from contract:  Food 8.72958078604
# Updating from contract:  Grain 2.27657229675295
# Updating from contract:  Food 7.73286536115
# Updating from contract:  Grain 2.619211225829277
# Updating from contract:  Grain 1.2535151764545511
# Updating from contract:  Food 5.77399155059
# Updating from contract:  Food 2.37189885558
# Updating from contract:  Grain 1.6688654290737974
# Updating from contract:  Food 4.43550156396
# Updating from contract:  Grain 2.37708111712886
# Updating from contract:  Food 4.20936267029
# Updating from contract:  Food 2.26407675275
# Updating from contract:  Grain 1.9869457992749138
# Updating from contract:  Food 1.15529037576
# Updating from contract:  Grain 2.805352588057385
# Updating from contract:  Food 6.03049033584
# Updating from contract:  Grain 1.2646164106513849
# Updating from contract:  Grain 1.6320528421279197
# Updating from contract:  Grain 2.430438734608954
# Updating from contract:  Grain 1.4265287841517793
# Updating from contract:  Food 5.18748229494
# Updating from contract:  Grain 2.2688909483859168
# Updating from contract:  Food 8.10652313761
# Updating from contract:  Grain 2.1589884114417526
# Updating from contract:  Food 5.43613130926
# Updating from contract:  Grain 1.9940137972067817
# Updating from contract:  Food 9.62035173194
# Updating from contract:  Grain 1.872609566597388
# Updating from contract:  Food 8.67985467669
# Updating from contract:  Grain 1.7585570526435004
# Updating from contract:  Grain 1.482733213479063
# Updating from contract:  Food 5.58873809982
# Updating from contract:  Grain 1.7883788546956672
# Updating from contract:  Food 8.36884741723
# Updating from contract:  Grain 2.2463321706049975
# Updating from contract:  Food 6.58322372615
# Updating from contract:  Grain 1.5934877423598497
# Updating from contract:  Food 3.97526818921
# Updating from contract:  Grain 2.373283168256304
# Updating from contract:  Food 6.85260707191
# Updating from contract:  Grain 2.2595054756026562
# Updating from contract:  Grain 1.7838813849530228
# Updating from contract:  Food 4.67998829893
# Updating from contract:  Grain 2.4693531512945226
# Updating from contract:  Food 7.51892584164
# Updating from contract:  Grain 1.7007984128131426
# Updating from contract:  Food 5.94106143353
# Updating from contract:  Grain 2.014155164761607
# Updating from contract:  Food 4.21916465186
# New prices:  [1,0.0, 2.0968388821323223,0.7071067811865476, 5.64727061646,2.3459830374452633, 21.3560794637,10.994182734665412, 83.1814805193,52.583525700889496, 0,1.0]
# Factories
# [1987  732    0    0    0    0] Valued at (based on MLE of price) 3521
# [1849   17  806    0    0    0] Valued at (based on MLE of price) 6436
# [1185    0    0 1000    0    0] Valued at (based on MLE of price) 22541
# [2706    0    0    0 1000    0] Valued at (based on MLE of price) 85887
# [10980     0    27     0     0     0] Valued at (based on MLE of price) 11132
# [6493    0    0   34    0    0] Valued at (based on MLE of price) 7219
# [10938     0     0     0    20     0] Valued at (based on MLE of price) 12601
# done
# Updating from contract:  Grain 2.2272802260774274
# Updating from contract:  Grain 2.322436451555477
# Updating from contract:  Grain 2.8922050758035747
# Updating from contract:  Food 7.28255112964
# Updating from contract:  Grain 2.2254877412634233
# Updating from contract:  Food 1.33150462182
# Updating from contract:  Fuel 13.6434563396
# Updating from contract:  Grain 2.272490766752338
# Updating from contract:  Food 6.46796086138
# Updating from contract:  Grain 1.944656546892795
# Updating from contract:  Grain 1.9701413224396296
# Updating from contract:  Food 5.78543164483
# Updating from contract:  Grain 1.077957024112769
# Updating from contract:  Food 6.95427350106
# Updating from contract:  Grain 2.5177293970631194
# Updating from contract:  Food 1.88645875325
# Updating from contract:  Diamonds 20.4431576845
# Updating from contract:  Grain 1.811301385978319
# Updating from contract:  Grain 1.558059949412664
# Updating from contract:  Food 9.31984574489
# Updating from contract:  Grain 1.850895101708928
# Updating from contract:  Grain 1.803319888963706
# Updating from contract:  Food 8.61563860814
# Updating from contract:  Grain 1.7247381162459063
# Updating from contract:  Food 4.81684912123
# Updating from contract:  Diamonds 17.3219957913
# Updating from contract:  Grain 1.2451358776054788
# Updating from contract:  Fuel 36.1699324521
# Updating from contract:  Grain 2.450510265682013
# Updating from contract:  Food 4.00185496621
# Updating from contract:  Grain 1.2075825597043612
# Updating from contract:  Food 7.19442988072
# Updating from contract:  Grain 2.1336420184061153
# Updating from contract:  Food 7.65838823187
# Updating from contract:  Grain 2.02223195265456
# Updating from contract:  Grain 2.9455821851406734
# Updating from contract:  Grain 1.9339199391161148
# Updating from contract:  Food 5.95517655006
# Updating from contract:  Grain 2.004637635155067
# Updating from contract:  Food 4.68427158239
# Updating from contract:  Grain 1.9714198724623213
# Updating from contract:  Food 7.2010173489
# Updating from contract:  Fuel 3.98853809665
# Updating from contract:  Grain 2.7094747670875927
# Updating from contract:  Food 7.26459275394
# Updating from contract:  Fuel 24.0521537878
# Updating from contract:  Grain 1.3170131691842248
# Updating from contract:  Grain 1.1677327105519055
# Updating from contract:  Diamonds 54.1066081114
# Updating from contract:  Food 1.68112805105
# Updating from contract:  Grain 1.7160137038625287
# Updating from contract:  Food 8.15730440241
# Updating from contract:  Grain 2.378921633243245
# Updating from contract:  Food 3.56880944296
# Updating from contract:  Grain 1.5766470539355049
# Updating from contract:  Food 8.19879271345
# Updating from contract:  Grain 2.0702433854870175
# Updating from contract:  Grain 1.7745782875464928
# Updating from contract:  Food 3.03862383686
# Updating from contract:  Food 2.54054562349
# Updating from contract:  Fuel 11.9701652915
# Updating from contract:  Grain 1.6697268951064261
# Updating from contract:  Grain 1.5366787247583087
# Updating from contract:  Diamonds 137.468200255
# Updating from contract:  Food 2.06476612898
# Updating from contract:  Food 1.02072140856
# Updating from contract:  Grain 1.960083041585741
# Updating from contract:  Food 5.29907772551
# Updating from contract:  Fuel 10.3814958857
# Updating from contract:  Grain 2.4397990814633745
# Updating from contract:  Food 9.34988627436
# Updating from contract:  Grain 1.9678306424527316
# Updating from contract:  Grain 2.5375783614028573
# Updating from contract:  Food 6.08991795631
# Updating from contract:  Grain 1.939644633259143
# Updating from contract:  Fuel 27.6488567979
# Updating from contract:  Food 3.09400525325
# Updating from contract:  Grain 1.9780291410771365
# Updating from contract:  Food 5.73025748706
# Updating from contract:  Fuel 33.6018191572
# Updating from contract:  Grain 2.093573131866602
# Updating from contract:  Fuel 12.9243794889
# Updating from contract:  Grain 2.3983156740664864
# Updating from contract:  Grain 1.5228015964533184
# Updating from contract:  Grain 2.484903465580143
# Updating from contract:  Fuel 25.0436240042
# Updating from contract:  Grain 1.4343165049922288
# Updating from contract:  Grain 1.457755566778932
# Updating from contract:  Food 8.33717885813
# Updating from contract:  Food 3.70681551937
# Updating from contract:  Food 1.5882060902
# Updating from contract:  Grain 1.7142522959141744
# Updating from contract:  Food 1.94484264842
# Updating from contract:  Grain 1.7885768046934643
# Updating from contract:  Food 4.53193432905
# Updating from contract:  Grain 1.977093997064654
# Updating from contract:  Food 3.85300612042
# Updating from contract:  Grain 1.1566016770430803
# Updating from contract:  Food 9.03137541321
# Updating from contract:  Grain 2.7740152711456774
# Updating from contract:  Food 4.38982677464
# Updating from contract:  Grain 2.1481592215296406
# Updating from contract:  Food 7.78913950459
# Updating from contract:  Food 1.56361572485
# Updating from contract:  Grain 2.0706649748545054
# Updating from contract:  Grain 1.7711645677396457
# Updating from contract:  Grain 1.3046258311968177
# Updating from contract:  Food 2.67054712766
# Updating from contract:  Grain 2.184990728179223
# Updating from contract:  Food 3.4428356769
# Updating from contract:  Grain 2.3263039015469484
# Updating from contract:  Food 7.91703655567
# Updating from contract:  Grain 1.48235231833665
# Updating from contract:  Food 4.68536965599
# Updating from contract:  Grain 2.2054050949656077
# Updating from contract:  Grain 2.199632715736986
# Updating from contract:  Food 9.20904990603
# Updating from contract:  Food 3.09983018404
# Updating from contract:  Grain 2.5258419973124475
# Updating from contract:  Food 1.52017759268
# Updating from contract:  Grain 2.590634964687567
# Updating from contract:  Grain 1.976912636177279
# Updating from contract:  Grain 1.430357067659392
# Updating from contract:  Food 9.2207580999
# Updating from contract:  Grain 1.3517852695257746
# Updating from contract:  Food 3.94507909995
# Updating from contract:  Grain 2.7669525737394305
# Updating from contract:  Food 2.4538015501
# Updating from contract:  Grain 1.3955776329715321
# Updating from contract:  Food 5.35583390565
# Updating from contract:  Grain 2.9047131593984346
# Updating from contract:  Food 8.33760299589
# Updating from contract:  Food 1.55896301504
# Updating from contract:  Grain 1.766745793635035
# Updating from contract:  Food 4.81083964913
# Updating from contract:  Grain 3.2583522091786534
# Updating from contract:  Food 8.00584339388
# Updating from contract:  Grain 2.1492459452229506
# Updating from contract:  Food 1.25850734745
# Updating from contract:  Grain 1.8382166238233537
# Updating from contract:  Food 6.69518063089
# Updating from contract:  Grain 3.056344836992678
# Updating from contract:  Grain 1.5448663400632903
# Updating from contract:  Food 9.27016895601
# Updating from contract:  Grain 2.0093665871009065
# Updating from contract:  Grain 2.496037779551804
# Updating from contract:  Food 3.90273224075
# Updating from contract:  Grain 1.0760697886645105
# Updating from contract:  Food 9.76359831269
# Updating from contract:  Grain 2.0159286928152254
# Updating from contract:  Food 6.16197272682
# Updating from contract:  Grain 2.061141670562261
# Updating from contract:  Grain 1.62901793394084
# Updating from contract:  Food 8.88244004683
# Updating from contract:  Grain 1.83667845598885
# Updating from contract:  Food 8.68199227376
# Updating from contract:  Grain 2.6556901881377737
# Updating from contract:  Food 8.96610143207
# Updating from contract:  Grain 2.4643227870822813
# Updating from contract:  Food 6.33158206665
# Updating from contract:  Grain 1.7440421639012411
# Updating from contract:  Grain 2.241114036943334
# New prices:  [1,0.0, 2.0027226688054585,0.7071067811865476, 5.35063445136,2.6371862964029953, 20.9470897893,11.222026586119465, 77.7520805035,48.41966400363096, 0,1.0]
# Factories
# [2235  905    0    0    0    0] Valued at (based on MLE of price) 4047
# [2174   16  984    0    0    0] Valued at (based on MLE of price) 7471
# [2739    0    0 1000    0    0] Valued at (based on MLE of price) 23686
# [4989    0    0    0 1000    0] Valued at (based on MLE of price) 82741
# [13502     0    37     0     0     0] Valued at (based on MLE of price) 13699
# [8115    0    0   43    0    0] Valued at (based on MLE of price) 9015
# [14764     0     0     0    20     0] Valued at (based on MLE of price) 16319
# done
# Updating from contract:  Food 2.71222860283
# Updating from contract:  Grain 2.1658091162735373
# Updating from contract:  Food 3.82541241731
# Updating from contract:  Grain 1.8787724672073576
# Updating from contract:  Grain 2.403418859076761
# Updating from contract:  Food 7.04462952191
# Updating from contract:  Diamonds 11.0364890976
# Updating from contract:  Grain 1.3332087506030785
# Updating from contract:  Food 7.8294045314
# Updating from contract:  Fuel 11.2325537123
# Updating from contract:  Grain 2.1177353870665163
# Updating from contract:  Fuel 39.2490707088
# Updating from contract:  Diamonds 42.7696537432
# Updating from contract:  Grain 2.671119342892956
# Updating from contract:  Grain 1.911249872851994
# Updating from contract:  Food 7.41941535957
# Updating from contract:  Diamonds 34.1079358273
# Updating from contract:  Grain 2.1046101009139155
# Updating from contract:  Food 5.74424466537
# Updating from contract:  Food 2.03324029892
# Updating from contract:  Grain 1.8607834060667015
# Updating from contract:  Food 2.43904455763
# Updating from contract:  Grain 1.7954052260711255
# Updating from contract:  Diamonds 137.342767444
# Updating from contract:  Grain 2.036463962315835
# Updating from contract:  Grain 2.167295324281447
# Updating from contract:  Fuel 39.879766969
# Updating from contract:  Grain 1.9220586859305462
# Updating from contract:  Food 6.39926868643
# Updating from contract:  Grain 2.2033558711253938
# Updating from contract:  Fuel 27.0162671677
# Updating from contract:  Grain 2.5697241267966753
# Updating from contract:  Grain 1.3642266382050994
# Updating from contract:  Food 7.27923736666
# Updating from contract:  Grain 2.2155161895643642
# Updating from contract:  Grain 2.5263202405416116
# Updating from contract:  Food 8.76210855284
# Updating from contract:  Grain 1.8593466229161963
# Updating from contract:  Food 8.97107977089
# Updating from contract:  Fuel 25.5997492987
# Updating from contract:  Grain 2.70882370698937
# Updating from contract:  Food 7.37650797014
# Updating from contract:  Grain 1.4063115237974029
# Updating from contract:  Food 9.35681386844
# Updating from contract:  Fuel 5.51505259813
# Updating from contract:  Grain 2.3433799340052928
# Updating from contract:  Food 4.91563007608
# Updating from contract:  Grain 2.150172056514861
# Updating from contract:  Food 2.96272739427
# Updating from contract:  Grain 1.0612585581807565
# Updating from contract:  Grain 1.7009249703241212
# Updating from contract:  Grain 1.5126916353492146
# Updating from contract:  Grain 2.0620706890980363
# Updating from contract:  Grain 3.3319958943636516
# Updating from contract:  Food 9.46823620549
# Updating from contract:  Food 1.49487753287
# Updating from contract:  Grain 2.0105706709639355
# Updating from contract:  Fuel 38.1295397476
# Updating from contract:  Grain 2.769015105724252
# Updating from contract:  Food 4.71502313277
# Updating from contract:  Grain 1.1242970887932313
# Updating from contract:  Food 6.32412533088
# Updating from contract:  Grain 2.2050495797862992
# Updating from contract:  Food 3.39069153486
# Updating from contract:  Grain 2.1957172004968566
# Updating from contract:  Fuel 14.8224005111
# Updating from contract:  Grain 2.092111251612703
# Updating from contract:  Food 5.83484503293
# Updating from contract:  Grain 2.4530879728687967
# Updating from contract:  Food 2.74290625457
# Updating from contract:  Grain 1.4345269967749086
# Updating from contract:  Food 3.8790259879
# Updating from contract:  Grain 1.3910958177217947
# Updating from contract:  Grain 2.0237900728209435
# Updating from contract:  Fuel 28.211649331
# Updating from contract:  Food 3.08696800726
# Updating from contract:  Grain 2.778632458220746
# Updating from contract:  Food 5.54215060302
# Updating from contract:  Grain 1.8373928828717125
# Updating from contract:  Grain 2.6283993592778905
# Updating from contract:  Grain 1.7154727714791271
# Updating from contract:  Food 5.20739776383
# Updating from contract:  Grain 1.382336970681167
# Updating from contract:  Food 3.40097318659
# Updating from contract:  Grain 2.6122486609322433
# Updating from contract:  Food 8.25706936149
# Updating from contract:  Grain 2.201084282884419
# Updating from contract:  Grain 1.4241632682753402
# Updating from contract:  Food 9.63565566725
# Updating from contract:  Grain 1.3451810696352824
# Updating from contract:  Fuel 32.1647349862
# Updating from contract:  Grain 2.2193696532138683
# Updating from contract:  Food 4.51698001718
# Updating from contract:  Grain 2.0581686177638465
# Updating from contract:  Grain 2.587930954113059
# Updating from contract:  Grain 1.7822827921689615
# Updating from contract:  Food 4.41395703948
# Updating from contract:  Grain 2.614711474470414
# Updating from contract:  Food 9.38920009655
# Updating from contract:  Grain 1.9976291430780393
# Updating from contract:  Food 2.68174069262
# Updating from contract:  Fuel 18.0699491147
# Updating from contract:  Grain 2.86229243859652
# Updating from contract:  Food 9.99668663028
# Updating from contract:  Food 3.01402784421
# Updating from contract:  Grain 2.0462899322713666
# Updating from contract:  Food 6.5642816678
# Updating from contract:  Grain 1.8403170718687
# Updating from contract:  Grain 1.4184268536446756
# Updating from contract:  Food 4.74016240238
# Updating from contract:  Grain 1.953032580540755
# Updating from contract:  Fuel 13.1079593081
# Updating from contract:  Grain 2.257835135221696
# Updating from contract:  Food 3.95856084712
# Updating from contract:  Food 1.58802731133
# Updating from contract:  Grain 1.6773437760334846
# Updating from contract:  Food 6.58353534813
# Updating from contract:  Food 2.69194226627
# Updating from contract:  Grain 1.712030349057706
# Updating from contract:  Food 6.77590171716
# Updating from contract:  Food 3.71764687138
# Updating from contract:  Fuel 18.3412434258
# Updating from contract:  Grain 2.1051035870898724
# Updating from contract:  Grain 1.5273266998353503
# Updating from contract:  Grain 2.192769812322652
# Updating from contract:  Food 4.85779777754
# Updating from contract:  Grain 1.7985094788196365
# Updating from contract:  Food 6.98625197145
# Updating from contract:  Food 1.87327215193
# Updating from contract:  Grain 1.964933354405026
# Updating from contract:  Food 8.73575404348
# Updating from contract:  Grain 1.906173727513149
# Updating from contract:  Grain 1.7954222863112321
# Updating from contract:  Grain 2.210376379080977
# Updating from contract:  Food 6.08072353343
# Updating from contract:  Food 7.61246999296
# ...
# Updating from contract:  Fuel 3.52021632824
# Updating from contract:  Food 3.65207896075
# Updating from contract:  Grain 1.6147772759378252
# Updating from contract:  Food 9.62185371574
# Updating from contract:  Grain 3.033451972222826
# Updating from contract:  Food 9.90102606903
# Updating from contract:  Fuel 5.75194115164
# Updating from contract:  Grain 1.6223053409372221
# Updating from contract:  Food 8.15002685363
# Updating from contract:  Fuel 29.12652441
# Updating from contract:  Food 1.45815822095
# Updating from contract:  Grain 1.6153474215677368
# Updating from contract:  Food 3.62990536295
# Updating from contract:  Grain 2.2156102447804695
# Updating from contract:  Food 5.9357872307
# Updating from contract:  Grain 1.34274201677773
# Updating from contract:  Food 3.2266034213
# Updating from contract:  Fuel 9.49247547604
# Updating from contract:  Grain 1.368108111768823
# Updating from contract:  Grain 1.795581584144358
# Updating from contract:  Food 5.02037014781
# Updating from contract:  Grain 1.2541337408391375
# Updating from contract:  Grain 3.065024602315658
# Updating from contract:  Diamonds 56.6097160842
# Updating from contract:  Food 3.05625257641
# Updating from contract:  Grain 2.3491622774469785
# Updating from contract:  Food 3.35475217243
# Updating from contract:  Diamonds 107.227224134
# Updating from contract:  Food 2.31107398819
# Updating from contract:  Grain 1.514703731457048
# Updating from contract:  Fuel 35.9356676251
# Updating from contract:  Grain 2.0153441405143107
# Updating from contract:  Food 4.81104037253
# Updating from contract:  Food 2.3444334087
# Updating from contract:  Grain 1.838467947416383
# Updating from contract:  Food 4.12292383665
# Updating from contract:  Fuel 34.4333941545
# Updating from contract:  Diamonds 10.5051180034
# Updating from contract:  Grain 1.5541135478526578
# Updating from contract:  Food 7.23802945044
# Updating from contract:  Grain 2.2250668361742667
# Updating from contract:  Food 7.90681972605
# Updating from contract:  Food 1.55325066908
# Updating from contract:  Diamonds 90.9727102686
# Updating from contract:  Grain 2.1426567897719746
# Updating from contract:  Grain 2.2783202631165724
# Updating from contract:  Food 8.51347265288
# Updating from contract:  Grain 1.9861668788353921
# Updating from contract:  Food 5.09702835867
# Updating from contract:  Fuel 32.0200649565
# Updating from contract:  Grain 2.8273197390856635
# Updating from contract:  Grain 2.598229534256672
# Updating from contract:  Food 9.59721201364
# Updating from contract:  Fuel 17.000711167
# Updating from contract:  Grain 1.7390052775694886
# Updating from contract:  Grain 2.1910079769960906
# Updating from contract:  Food 9.44920759297
# Updating from contract:  Grain 1.155853374207634
# Updating from contract:  Diamonds 125.779292311
# Updating from contract:  Grain 1.9388120803737074
# Updating from contract:  Grain 2.505276565219151
# Updating from contract:  Food 9.56367913305
# Updating from contract:  Grain 1.9461430858728757
# Updating from contract:  Fuel 39.140336915
# Updating from contract:  Diamonds 117.044609594
# Updating from contract:  Grain 2.6738544723039044
# Updating from contract:  Food 3.80080877101
# Updating from contract:  Grain 2.3264144867063115
# Updating from contract:  Grain 1.7542848826994941
# Updating from contract:  Food 3.36241763677
# Updating from contract:  Grain 2.259555284238028
# Updating from contract:  Grain 1.7929366689269062
# Updating from contract:  Food 8.95899685113
# Updating from contract:  Grain 2.502640631132253
# Updating from contract:  Grain 2.15506681144441
# Updating from contract:  Grain 2.3224459657589662
# Updating from contract:  Food 1.25049621809
# Updating from contract:  Grain 1.709904221007346
# Updating from contract:  Grain 2.418931423293316
# Updating from contract:  Grain 1.884138161994112
# Updating from contract:  Food 7.29627216823
# Updating from contract:  Fuel 26.5495604638
# Updating from contract:  Food 1.06058747461
# Updating from contract:  Food 1.74789963776
# Updating from contract:  Grain 1.9796205275007837
# Updating from contract:  Food 5.4270395992
# Updating from contract:  Grain 1.8068238934341678
# Updating from contract:  Fuel 30.9571183551
# Updating from contract:  Grain 2.7814436617569207
# Updating from contract:  Food 5.25244958949
# Updating from contract:  Grain 2.87293621687908
# Updating from contract:  Food 1.45953626653
# Updating from contract:  Fuel 14.0791236292
# Updating from contract:  Food 1.3993456724
# Updating from contract:  Grain 2.057444990113205
# Updating from contract:  Food 5.46299627823
# Updating from contract:  Grain 1.5689738392635126
# Updating from contract:  Fuel 29.152805419
# Updating from contract:  Grain 2.693819433951402
# Updating from contract:  Food 8.54151988986
# Updating from contract:  Grain 1.8272008023238755
# Updating from contract:  Food 7.26499590657
# Updating from contract:  Grain 1.358689625104102
# Updating from contract:  Food 1.96513632166
# Updating from contract:  Grain 1.6164850331734986
# Updating from contract:  Food 4.6687279412
# Updating from contract:  Grain 1.6434251117099847
# Updating from contract:  Food 6.6777491577
# Updating from contract:  Grain 1.4291418757056529
# Updating from contract:  Food 9.12722510638
# Updating from contract:  Food 3.18113362536
# Updating from contract:  Fuel 26.6183850612
# Updating from contract:  Grain 1.7203217682582872
# Updating from contract:  Grain 3.030581315339901
# Updating from contract:  Grain 2.1978414077714596
# Updating from contract:  Food 9.67100232068
# Updating from contract:  Grain 1.9726352880527949
# Updating from contract:  Food 5.32391369402
# Updating from contract:  Grain 2.175698272146165
# Updating from contract:  Grain 2.7492179145705884
# Updating from contract:  Food 5.45752005298
# Updating from contract:  Grain 2.356655194387452
# Updating from contract:  Food 1.7699294942
# Updating from contract:  Grain 1.3223959767494309
# Updating from contract:  Food 8.87357151143
# Updating from contract:  Grain 1.9482498526140217
# Updating from contract:  Food 9.74457937291
# Updating from contract:  Grain 2.7668049547300857
# Updating from contract:  Food 5.12747716437
# Updating from contract:  Grain 1.448900562843102
# Updating from contract:  Food 5.83711839229
# Updating from contract:  Grain 2.6394519726604138
# Updating from contract:  Grain 1.1770529619970866
# Updating from contract:  Food 4.80109474202
# Updating from contract:  Grain 1.659316004235837
# Updating from contract:  Food 5.28936777932
# Updating from contract:  Grain 2.2411552235602965
# Updating from contract:  Food 4.19337533988
# Updating from contract:  Grain 1.8425864338382996
# Updating from contract:  Food 8.87764459781
# Updating from contract:  Grain 2.2513132322249407
# Updating from contract:  Food 7.90211198358
# Updating from contract:  Grain 2.5252024909534745
# Updating from contract:  Grain 2.3912751965796097
# Updating from contract:  Food 6.68468025937
# Updating from contract:  Grain 2.114872081096295
# Updating from contract:  Food 9.87909482338
# Updating from contract:  Grain 2.1769777019900602
# Updating from contract:  Food 5.25865510441
# Updating from contract:  Food 2.60119089434
# Updating from contract:  Food 6.5918637761
# New prices:  [1,0.0, 2.052488680442671,0.7071067811865476, 5.42363625536,2.617005245555521, 21.6523037389,11.74462425437531, 80.3633920404,44.35258812272727, 0,1.0]
# Factories
# [3241 1000    0    0    0    0] Valued at (based on MLE of price) 5293
# [5119   32 1000    0    0    0] Valued at (based on MLE of price) 10608
# [7798    0    0 1000    0    0] Valued at (based on MLE of price) 29450
# [13529     0     0     0  1000     0] Valued at (based on MLE of price) 93892
# [21620     0    24     0     0     0] Valued at (based on MLE of price) 21750
# [14372     0     0    44     0     0] Valued at (based on MLE of price) 15324
# [23773     0     0     0    23     0] Valued at (based on MLE of price) 25621
# done
# Updating from contract:  Food 8.7826078506
# Updating from contract:  Grain 2.0725440980100203
# Updating from contract:  Food 8.05176852608
# Updating from contract:  Fuel 24.590076629
# Updating from contract:  Grain 2.515130681193137
# Updating from contract:  Food 7.29584957159
# Updating from contract:  Fuel 21.0928878937
# Updating from contract:  Diamonds 139.599770623
# Updating from contract:  Grain 2.2861938175219523
# Updating from contract:  Grain 2.4308489290357014
# Updating from contract:  Grain 2.1545870255059785
# Updating from contract:  Food 9.07547591658
# Updating from contract:  Grain 1.6757752413228684
# Updating from contract:  Food 9.26384442037
# Updating from contract:  Fuel 24.8519653748
# Updating from contract:  Grain 1.5819499064440312
# Updating from contract:  Food 3.09863134869
# Updating from contract:  Grain 1.6802608534758867
# Updating from contract:  Grain 1.749118172108644
# Updating from contract:  Grain 1.5829161723275316
# Updating from contract:  Food 4.96465788025
# Updating from contract:  Grain 1.656751764122371
# Updating from contract:  Food 9.89901755265
# Updating from contract:  Grain 2.7643324921823544
# Updating from contract:  Food 5.18203092271
# Updating from contract:  Food 2.0158434145
# Updating from contract:  Diamonds 51.8506513266
# Updating from contract:  Food 2.96924948261
# Updating from contract:  Fuel 9.16225554571
# Updating from contract:  Grain 1.8847875068340434
# Updating from contract:  Food 9.812584804
# Updating from contract:  Fuel 12.0165386833
# Updating from contract:  Grain 1.5427582833117295
# Updating from contract:  Food 9.33888619973
# Updating from contract:  Fuel 33.8108693617
# Updating from contract:  Grain 2.1807032866345084
# Updating from contract:  Food 4.62431829378
# Updating from contract:  Food 3.36873739584
# Updating from contract:  Grain 2.0529831236720177
# Updating from contract:  Grain 2.389916436209835
# Updating from contract:  Food 8.65978665331
# Updating from contract:  Grain 1.6006870113504972
# Updating from contract:  Food 5.36939175394
# Updating from contract:  Food 1.83628598174
# Updating from contract:  Grain 2.109015782189259
# Updating from contract:  Grain 2.862871899049872
# Updating from contract:  Food 5.86124424732
# Updating from contract:  Diamonds 46.6106540503
# Updating from contract:  Grain 2.5456906138560114
# Updating from contract:  Grain 1.7527558476800236
# Updating from contract:  Food 6.82475615969
# Updating from contract:  Grain 2.384168398037183
# Updating from contract:  Food 6.63257796839
# Updating from contract:  Fuel 35.3499952046
# Updating from contract:  Grain 1.6170244834922785
# Updating from contract:  Food 9.21117627475
# Updating from contract:  Fuel 39.4387244365
# Updating from contract:  Diamonds 115.468495099
# Updating from contract:  Grain 3.0495584344952613
# Updating from contract:  Fuel 36.4583880113
# Updating from contract:  Grain 2.43327158124004
# Updating from contract:  Food 7.90492879553
# Updating from contract:  Grain 2.1362586937424055
# Updating from contract:  Grain 1.6318215976670443
# Updating from contract:  Food 7.82084872849
# Updating from contract:  Grain 2.1188314850710492
# Updating from contract:  Food 6.48463519425
# Updating from contract:  Grain 1.2426940818993222
# Updating from contract:  Food 5.23984094137
# Updating from contract:  Grain 2.4441429608716434
# Updating from contract:  Food 6.62877620964
# Updating from contract:  Grain 2.007376620363357
# Updating from contract:  Food 4.74147457158
# Updating from contract:  Grain 2.3612010671244867
# Updating from contract:  Food 6.43971454903
# Updating from contract:  Grain 2.4485396819305856
# Updating from contract:  Food 8.66570519885
# Updating from contract:  Grain 1.6950015944435157
# Updating from contract:  Food 6.26655161093
# Updating from contract:  Grain 1.8859453901669343
# Updating from contract:  Food 9.96832832037
# Updating from contract:  Grain 2.428796884145121
# Updating from contract:  Food 4.51058039448
# Updating from contract:  Food 1.60984993074
# Updating from contract:  Grain 2.0695828186996206
# Updating from contract:  Grain 2.6015274747677193
# Updating from contract:  Grain 2.408560167173173
# Updating from contract:  Grain 2.4081725485171117
# Updating from contract:  Food 3.61980180157
# Updating from contract:  Grain 2.4537400188193224
# Updating from contract:  Diamonds 79.2256626172
# Updating from contract:  Grain 2.2978255950272897
# Updating from contract:  Food 9.98470278645
# Updating from contract:  Grain 2.241009867893716
# Updating from contract:  Food 8.49170314773
# Updating from contract:  Grain 1.6444810613521617
# Updating from contract:  Food 6.73438428268
# Updating from contract:  Grain 2.713516498447609
# Updating from contract:  Grain 2.50560811407274
# Updating from contract:  Food 9.02658635092
# Updating from contract:  Diamonds 104.982118065
# Updating from contract:  Grain 2.154669761148205
# Updating from contract:  Food 5.19080125687
# Updating from contract:  Diamonds 50.7048408983
# Updating from contract:  Grain 1.951673892227854
# Updating from contract:  Grain 2.2403591786445998
# Updating from contract:  Grain 2.6042381172548277
# Updating from contract:  Food 8.63019068151
# Updating from contract:  Grain 2.2856783057650625
# Updating from contract:  Food 5.87163736104
# Updating from contract:  Grain 1.344587160332017
# Updating from contract:  Food 3.63965704848
# Updating from contract:  Grain 2.1442719683826885
# Updating from contract:  Food 5.89192276144
# Updating from contract:  Grain 2.7597107726453847
# Updating from contract:  Grain 1.9351674005956712
# Updating from contract:  Food 4.28862252379
# Updating from contract:  Food 2.57434073579
# Updating from contract:  Grain 2.4197065333496486
# Updating from contract:  Food 8.11446744343
# Updating from contract:  Grain 1.5940922573178289
# Updating from contract:  Food 9.89628854707
# Updating from contract:  Grain 2.7871728336170776
# Updating from contract:  Food 6.23926538053
# Updating from contract:  Food 2.82012901195
# Updating from contract:  Grain 2.5041773121491238
# Updating from contract:  Food 8.46094560146
# Updating from contract:  Grain 2.4726039694478334
# Updating from contract:  Grain 2.486649135412288
# Updating from contract:  Food 6.69865391059
# Updating from contract:  Food 1.36092729809
# Updating from contract:  Grain 2.5095040742084715
# Updating from contract:  Grain 2.1964152266745685
# Updating from contract:  Food 7.77476493826
# Updating from contract:  Grain 2.295541337484659
# Updating from contract:  Food 9.02579909997
# Updating from contract:  Grain 1.2467714311385223
# Updating from contract:  Food 9.0371452375
# Updating from contract:  Grain 1.4878850375913109
# Updating from contract:  Grain 1.535469458924053
# Updating from contract:  Food 2.38159670965
# Updating from contract:  Grain 2.3368728989821688
# Updating from contract:  Food 6.97305237782
# Updating from contract:  Food 2.23779088237
# Updating from contract:  Grain 2.8045299861320467
# Updating from contract:  Food 8.05907444627
# Updating from contract:  Grain 1.6406092400761616
# Updating from contract:  Grain 1.6235212286722036
# Updating from contract:  Food 2.42982159316
# Updating from contract:  Grain 2.6050129574710463
# Updating from contract:  Food 9.52659792087
# Updating from contract:  Food 4.73828461145
# Updating from contract:  Food 6.45912095391
# Updating from contract:  Food 5.21210354412
# Updating from contract:  Food 3.10464835196
# Updating from contract:  Food 3.9959149442
# Updating from contract:  Food 3.21427241356
# Updating from contract:  Food 4.21154444302
# Updating from contract:  Food 6.83976583322
# Updating from contract:  Food 1.50814996729
# Updating from contract:  Food 9.63442082166
# New prices:  [1,0.0, 2.1417143800382914,0.7071067811865476, 5.71606335564,2.5322211057902133, 21.8245932241,11.318798818090572, 81.8761761427,43.75117689937846, 0,1.0]
# Factories
# [3672 1000    0    0    0    0] Valued at (based on MLE of price) 5813
# [6041   28 1000    0    0    0] Valued at (based on MLE of price) 11817
# [9473    0    0 1000    0    0] Valued at (based on MLE of price) 31297
# [16864     0     0     0  1000     0] Valued at (based on MLE of price) 98740
# [24277     0    27     0     0     0] Valued at (based on MLE of price) 24431
# [16341     0     0    43     0     0] Valued at (based on MLE of price) 17279
# [27463     0     0     0    21     0] Valued at (based on MLE of price) 29182
# done
