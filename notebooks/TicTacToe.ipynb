# %%
### Imports

import math,sys,time
import numpy
import scipy,scipy.optimize,scipy.spatial,scipy.spatial.distance,scipy.stats
import json
import sqlite3
from collections import *
from enum import Enum
import random

from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
from keras import backend as K

import theano,theano.tensor

# %%
### Constants

NUM_PLAYERS=2  # X -> player 0, O -> player 1
SQUARES=9 # 9 Squares
SQUARE_VALUES=3 # -1 -> empty, 0 -> X, 1 -> O
NUM_FEATURES = NUM_PLAYERS*SQUARES*SQUARE_VALUES+1  # Total number of features (inputs to the DNN)
NUM_ACTIONS=SQUARES # Maximum number of actions (outputs from the DNN)
CHANCE_TO_RANDOM_ACTION = 0.1 # Chance to move randomly to handle exploration
DISCOUNT_FACTOR = 0.9 # Discounts future rewards based on time from the current state

# %% [markdown]
# ## Encode State
#
# This function takes data about the game and encodes it as an array that can be entered into a DNN. This is where the "secret sauce" goes, where we describe the state of the board game in a way that is conducive to successful training.
#
# A few items worth noting about the way I encoded Tic Tac Toe:
#
# ### All of the features are binary
#
# Continuous (i.e. floating point) features are only effective if they represent a gradient that (somewhat) relates linearly to the output (or linearly to the odds of the output when using sigmoid/tanh).  Note that, although I'm representing a board square as -1/0/+1 for empty/X/O respectively, trying to cram this information into a single square assumes that "empty" is the opposite of "O".  Even if I re-ordered so "X" could be the opposite of "O", this will still cause strange interactions that will make the network ineffective (try it and see for yourself!).
#
# ### Initiative is encoded by duplicating the entire game state
#
# Obviously, initiative (whose turn it is to move) is incredibly important.  I encoded this by duplicating the entire board state, and only activating one of the copies at a time.  This is similar to having a separate DNN for player X and player O, except that by having a single network, it can learn some common ideas.  I believe having two separate networks would actually perform better, but haven't tried it.

# %%
def EncodeState(currentPlayer, board):
    features = [0]*(NUM_FEATURES)
    playerShift = (currentPlayer)*SQUARES*SQUARE_VALUES
    for x in range(0,SQUARES):
        squareValue = board[x]+1;
        features[playerShift + (x*SQUARE_VALUES) + squareValue] = 1.0
    features[NUM_PLAYERS*SQUARES*SQUARE_VALUES] = 1.0 # Bias term
    return features

# %%
# This contains the encoded state and the action/player so value can be assigned from future rewards.
class TrainingExample:
    def __init__(self,turn,features,action,playerIndex):
        self.turn = turn
        self.features = features
        self.action = action
        self.playerIndex = playerIndex

# Takes an action and updates the state
def TakeAction(board, player, move):
    board[move] = player

# Setermines if the current state is terminal
def GetWinner(board):
    for player in range(1,3):
        if board[0]==player and board[1]==player and board[2]==player:
            return player
        if board[3]==player and board[4]==player and board[5]==player:
            return player
        if board[6]==player and board[7]==player and board[8]==player:
            return player
        if board[0]==player and board[3]==player and board[6]==player:
            return player
        if board[1]==player and board[4]==player and board[7]==player:
            return player
        if board[2]==player and board[5]==player and board[8]==player:
            return player
    return -1
    
# Plays a single match and stores training examples in X_input and Y_input.
# Prints some information about the game ifdebug is set to True
def PlayMatch(models, X_input, Y_input, debug, explore):
    trainingExamples = []
    board = [-1]*9
    for turn in range(0,9):
        currentPlayer = turn%2
        encodedState = EncodeState(currentPlayer, board)
        if models is None or models[currentPlayer] is None or (explore and numpy.random.ranf() < CHANCE_TO_RANDOM_ACTION):
            # Play in a random square
            move = -1
            while move == -1:
                move = numpy.random.randint(9)
                if board[move]>=0:
                    move = -1
        else:
            # Query the model
            model = models[currentPlayer]
            features = numpy.array([encodedState,])
            actionValues = model.predict(features, batch_size=1, verbose=0)[0]
            # Choose the action with the highest expected value
            if debug:
                print(currentPlayer,board,actionValues)
            move = -1000000000
            while move == -1000000000:
                move = numpy.argmax(actionValues)
                if board[move]>=0:
                    actionValues[move] = -1000000000
                    move = -1000000000
        if debug:
            print("player",currentPlayer,"makes move",move)
        trainingExamples.append(TrainingExample(turn, encodedState, move, currentPlayer))
        TakeAction(board,currentPlayer,move)
        winner = GetWinner(board)
        if winner > -1:
            break
    if debug:
        print('winner is',winner)
    playerValues = []
    for pIndex in range(0,NUM_PLAYERS):
        if winner == -1:
            value = 8.0 # 8 Reward for a tie
        elif winner == pIndex:
            value = 32.0 # 32 for a win
        else:
            value = 2.0 # 2 for a loss
        playerValues.append(value)
    for t in trainingExamples:
        discountedValue = playerValues[t.playerIndex] * (DISCOUNT_FACTOR ** (turn - t.turn))
        X_input.append(t.features)
        labels = [0]*SQUARES
        labels[t.action] = discountedValue
        Y_input.append(labels)
    return winner

# Play several matches with a fixed seed
def PlayMatches(X_input, Y_input, model, numMatches):
    timeSeed = int(time.time())
    random.seed(timeSeed)
    numpy.random.seed(timeSeed)
    for x in range(0,numMatches):
        PlayMatch([model, model], X_input, Y_input, False, True)
    return X_input,Y_input

# This plays against a pure-random opponent and returns (win, lose, tie)
def TestModel(model):
    random.seed(1)
    numpy.random.seed(1)
    winCount=0
    loseCount=0
    tieCount=0
    for x in range(0,1000):
        winner = PlayMatch([model, None], [], [], False, False)
        if winner == -1:
            tieCount = tieCount+1
        elif winner == 0:
            winCount = winCount+1
        elif winner == 1:
            loseCount = loseCount+1
        else:
            print(winner)
    for x in range(0,1000):
        winner = PlayMatch([None, model], [], [], False, False)
        if winner == -1:
            tieCount = tieCount+1
        elif winner == 0:
            loseCount = loseCount+1
        elif winner == 1:
            winCount = winCount+1
        else:
            print(winner)
    return (winCount,loseCount,tieCount)

# Play a match with no model (pure random) and debug just to show what happens.
PlayMatch(None, [], [], True, True)
# Out:
# player 0 makes move 1
# player 1 makes move 7
# player 0 makes move 4
# player 1 makes move 3
# player 0 makes move 0
# player 1 makes move 6
# player 0 makes move 8
# player 1 makes move 5
# player 0 makes move 2
# winner is -1
# -1

# %%
model = Sequential()
model.add(Dense(512, input_dim=NUM_FEATURES, init='he_normal', activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(256, init='he_normal', activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(128, init='he_normal', activation='relu'))
model.add(Dropout(0.1))
# Although the values can never be negative, using a relu instead of linear here
#    results in significantly worse performance.  Maybe a leaky relu would help?
model.add(Dense(NUM_ACTIONS, init='he_normal', activation='linear'))

# This is a special loss function that does not consider zero outputs.  The reason why we need this is because there
#     is one output for each action, but the network wants to propagate error for all outputs simulatenously.  This
#     isn't possible here because we only know the value from taking a single action.  This loss function fixes
#     the issue by ignoring all zero outputs and only propagating error for the action that was actually taken.
def non_zero_mean_squared_error(y_true, y_pred):
    total = theano.tensor.sum(theano.tensor.square(abs(theano.tensor.sgn(y_true))*(y_pred - y_true)), axis=-1)
    count = theano.tensor.sum(abs(theano.tensor.sgn(y_true)))
    return total/count

model.compile(loss=non_zero_mean_squared_error, optimizer='sgd')

# Print a model to the console
def DumpModel(model):
    print("LAYERS:",len(model.layers))
    for layer in model.layers:
        print("NUM WEIGHT ARRAYS",len(layer.get_weights()))
        print(layer.get_weights()[1])
        weights = layer.get_weights()[0] # list of numpy arrays
        for x in range(0,NUM_FEATURES):
            print(weights[x])

# This keeps a ring buffer of training examples & labels
X_train = []
Y_train = []
for simulation in range(0,500):
    simulationModel = model
    if simulation == 0:
        # For the first iteration, use a pure-random player
        simulationModel = None
    PlayMatches(X_train, Y_train, simulationModel, 200)
    
    
    print("# Training Examples",len(X_train))
    # Trim the ring buffer
    X_train = X_train[-64000:]
    Y_train = Y_train[-64000:]
    history = model.fit(numpy.array(X_train), numpy.array(Y_train), nb_epoch=20, shuffle=True, batch_size=1024, verbose=0)
    model = history.model
    #DumpModel(model)
    print('Finished epoch',simulation)
    sys.stdout.flush()
    results = TestModel(model)
    print('MODEL TEST (W/L/T):',results)
    sys.stdout.flush()
# Out:
# # Training Examples 1720
# Finished epoch 0
# MODEL TEST (W/L/T): (164, 230, 1606)
# # Training Examples 3489
# Finished epoch 1
# MODEL TEST (W/L/T): (169, 230, 1601)
# # Training Examples 5264
# Finished epoch 2
# MODEL TEST (W/L/T): (208, 252, 1540)
# # Training Examples 7027
# Finished epoch 3
# MODEL TEST (W/L/T): (205, 240, 1555)
# # Training Examples 8786
# Finished epoch 4
# MODEL TEST (W/L/T): (188, 259, 1553)
# # Training Examples 10537
# Finished epoch 5
# MODEL TEST (W/L/T): (247, 280, 1473)
# # Training Examples 12308
# Finished epoch 6
# MODEL TEST (W/L/T): (340, 375, 1285)
# # Training Examples 14072
# Finished epoch 7
# MODEL TEST (W/L/T): (359, 343, 1298)
# # Training Examples 15839
# Finished epoch 8
# MODEL TEST (W/L/T): (377, 362, 1261)
# # Training Examples 17606
# Finished epoch 9
# MODEL TEST (W/L/T): (355, 284, 1361)
# # Training Examples 19376
# Finished epoch 10
# MODEL TEST (W/L/T): (298, 207, 1495)
# # Training Examples 21148
# Finished epoch 11
# MODEL TEST (W/L/T): (405, 176, 1419)
# # Training Examples 22536
# Finished epoch 12
# MODEL TEST (W/L/T): (295, 223, 1482)
# # Training Examples 24301
# Finished epoch 13
# MODEL TEST (W/L/T): (260, 235, 1505)
# # Training Examples 26070
# Finished epoch 14
# MODEL TEST (W/L/T): (302, 223, 1475)
# # Training Examples 27827
# Finished epoch 15
# MODEL TEST (W/L/T): (322, 223, 1455)
# # Training Examples 29603
# Finished epoch 16
# MODEL TEST (W/L/T): (411, 251, 1338)
# # Training Examples 31343
# Finished epoch 17
# MODEL TEST (W/L/T): (465, 264, 1271)
# # Training Examples 33105
# Finished epoch 18
# MODEL TEST (W/L/T): (412, 236, 1352)
# # Training Examples 34827
# Finished epoch 19
# MODEL TEST (W/L/T): (192, 182, 1626)
# # Training Examples 36464
# Finished epoch 20
# MODEL TEST (W/L/T): (225, 151, 1624)
# # Training Examples 38105
# Finished epoch 21
# MODEL TEST (W/L/T): (384, 337, 1279)
# # Training Examples 39894
# Finished epoch 22
# MODEL TEST (W/L/T): (516, 315, 1169)
# # Training Examples 41684
# Finished epoch 23
# MODEL TEST (W/L/T): (542, 315, 1143)
# # Training Examples 43464
# Finished epoch 24
# MODEL TEST (W/L/T): (544, 303, 1153)
# # Training Examples 45253
# Finished epoch 25
# MODEL TEST (W/L/T): (549, 302, 1149)
# # Training Examples 47025
# Finished epoch 26
# MODEL TEST (W/L/T): (567, 301, 1132)
# # Training Examples 48766
# Finished epoch 27
# MODEL TEST (W/L/T): (576, 310, 1114)
# # Training Examples 50516
# Finished epoch 28
# MODEL TEST (W/L/T): (561, 273, 1166)
# # Training Examples 52242
# Finished epoch 29
# MODEL TEST (W/L/T): (586, 362, 1052)
# # Training Examples 53992
# Finished epoch 30
# MODEL TEST (W/L/T): (576, 350, 1074)
# # Training Examples 55709
# Finished epoch 31
# MODEL TEST (W/L/T): (526, 326, 1148)
# # Training Examples 57081
# Finished epoch 32
# MODEL TEST (W/L/T): (523, 330, 1147)
# # Training Examples 58732
# Finished epoch 33
# MODEL TEST (W/L/T): (525, 341, 1134)
# # Training Examples 60375
# Finished epoch 34
# MODEL TEST (W/L/T): (545, 272, 1183)
# # Training Examples 62110
# Finished epoch 35
# MODEL TEST (W/L/T): (577, 281, 1142)
# # Training Examples 63475
# Finished epoch 36
# MODEL TEST (W/L/T): (576, 294, 1130)
# # Training Examples 64824
# Finished epoch 37
# MODEL TEST (W/L/T): (550, 350, 1100)
# # Training Examples 65368
# Finished epoch 38
# MODEL TEST (W/L/T): (560, 288, 1152)
# # Training Examples 65355
# Finished epoch 39
# MODEL TEST (W/L/T): (558, 313, 1129)
# # Training Examples 65757
# Finished epoch 40
# MODEL TEST (W/L/T): (558, 324, 1118)
# # Training Examples 65761
# Finished epoch 41
# MODEL TEST (W/L/T): (547, 308, 1145)
# # Training Examples 65754
# Finished epoch 42
# MODEL TEST (W/L/T): (552, 336, 1112)
# # Training Examples 65640
# Finished epoch 43
# MODEL TEST (W/L/T): (553, 324, 1123)
# # Training Examples 65638
# Finished epoch 44
# MODEL TEST (W/L/T): (569, 243, 1188)
# # Training Examples 65760
# Finished epoch 45
# MODEL TEST (W/L/T): (574, 248, 1178)
# # Training Examples 65735
# Finished epoch 46
# MODEL TEST (W/L/T): (572, 259, 1169)
# # Training Examples 65696
# Finished epoch 47
# MODEL TEST (W/L/T): (581, 250, 1169)
# # Training Examples 65712
# Finished epoch 48
# MODEL TEST (W/L/T): (617, 284, 1099)
# # Training Examples 65722
# Finished epoch 49
# MODEL TEST (W/L/T): (650, 272, 1078)
# # Training Examples 65408
# Finished epoch 50
# MODEL TEST (W/L/T): (627, 264, 1109)
# # Training Examples 65378
# Finished epoch 51
# MODEL TEST (W/L/T): (640, 255, 1105)
# # Training Examples 65705
# Finished epoch 52
# MODEL TEST (W/L/T): (661, 255, 1084)
# # Training Examples 65734
# Finished epoch 53
# MODEL TEST (W/L/T): (668, 263, 1069)
# # Training Examples 65703
# Finished epoch 54
# MODEL TEST (W/L/T): (674, 268, 1058)
# # Training Examples 65729
# Finished epoch 55
# MODEL TEST (W/L/T): (675, 274, 1051)
# # Training Examples 65725
# Finished epoch 56
# MODEL TEST (W/L/T): (673, 269, 1058)
# # Training Examples 65719
# Finished epoch 57
# MODEL TEST (W/L/T): (672, 284, 1044)
# # Training Examples 65705
# Finished epoch 58
# MODEL TEST (W/L/T): (709, 278, 1013)
# # Training Examples 65350
# Finished epoch 59
# MODEL TEST (W/L/T): (692, 294, 1014)
# # Training Examples 65405
# Finished epoch 60
# MODEL TEST (W/L/T): (703, 277, 1020)
# # Training Examples 65697
# Finished epoch 61
# MODEL TEST (W/L/T): (720, 282, 998)
# # Training Examples 65734
# Finished epoch 62
# MODEL TEST (W/L/T): (714, 282, 1004)
# # Training Examples 65740
# Finished epoch 63
# MODEL TEST (W/L/T): (715, 281, 1004)
# # Training Examples 65721
# Finished epoch 64
# MODEL TEST (W/L/T): (703, 265, 1032)
# # Training Examples 65711
# Finished epoch 65
# MODEL TEST (W/L/T): (704, 289, 1007)
# # Training Examples 65707
# Finished epoch 66
# MODEL TEST (W/L/T): (695, 282, 1023)
# # Training Examples 65713
# Finished epoch 67
# MODEL TEST (W/L/T): (703, 253, 1044)
# # Training Examples 65694
# Finished epoch 68
# MODEL TEST (W/L/T): (700, 263, 1037)
# # Training Examples 65712
# Finished epoch 69
# MODEL TEST (W/L/T): (699, 236, 1065)
# # Training Examples 65693
# Finished epoch 70
# MODEL TEST (W/L/T): (709, 203, 1088)
# # Training Examples 65709
# Finished epoch 71
# MODEL TEST (W/L/T): (686, 192, 1122)
# # Training Examples 65755
# Finished epoch 72
# MODEL TEST (W/L/T): (686, 188, 1126)
# # Training Examples 65750
# Finished epoch 73
# MODEL TEST (W/L/T): (691, 190, 1119)
# # Training Examples 65732
# Finished epoch 74
# MODEL TEST (W/L/T): (686, 212, 1102)
# # Training Examples 65752
# Finished epoch 75
# MODEL TEST (W/L/T): (714, 263, 1023)
# # Training Examples 65720
# Finished epoch 76
# MODEL TEST (W/L/T): (713, 226, 1061)
# # Training Examples 65693
# Finished epoch 77
# MODEL TEST (W/L/T): (713, 230, 1057)
# # Training Examples 65712
# Finished epoch 78
# MODEL TEST (W/L/T): (714, 224, 1062)
# # Training Examples 65683
# Finished epoch 79
# MODEL TEST (W/L/T): (717, 216, 1067)
# # Training Examples 65709
# Finished epoch 80
# MODEL TEST (W/L/T): (718, 220, 1062)
# # Training Examples 65732
# Finished epoch 81
# MODEL TEST (W/L/T): (714, 207, 1079)
# # Training Examples 65726
# Finished epoch 82
# MODEL TEST (W/L/T): (710, 203, 1087)
# # Training Examples 65696
# Finished epoch 83
# MODEL TEST (W/L/T): (710, 169, 1121)
# # Training Examples 65687
# Finished epoch 84
# MODEL TEST (W/L/T): (689, 145, 1166)
# # Training Examples 65621
# Finished epoch 85
# MODEL TEST (W/L/T): (677, 159, 1164)
# # Training Examples 65637
# Finished epoch 86
# MODEL TEST (W/L/T): (671, 245, 1084)
# # Training Examples 65730
# Finished epoch 87
# MODEL TEST (W/L/T): (662, 239, 1099)
# # Training Examples 65729
# Finished epoch 88
# MODEL TEST (W/L/T): (636, 165, 1199)
# # Training Examples 65608
# Finished epoch 89
# MODEL TEST (W/L/T): (639, 143, 1218)
# # Training Examples 65718
# Finished epoch 90
# MODEL TEST (W/L/T): (664, 148, 1188)
# # Training Examples 65721
# Finished epoch 91
# MODEL TEST (W/L/T): (672, 98, 1230)
# # Training Examples 65725
# Finished epoch 92
# MODEL TEST (W/L/T): (676, 103, 1221)
# # Training Examples 65609
# Finished epoch 93
# MODEL TEST (W/L/T): (683, 93, 1224)
# # Training Examples 65627
# Finished epoch 94
# MODEL TEST (W/L/T): (676, 94, 1230)
# # Training Examples 65611
# Finished epoch 95
# MODEL TEST (W/L/T): (656, 115, 1229)
# # Training Examples 65634
# Finished epoch 96
# MODEL TEST (W/L/T): (619, 129, 1252)
# # Training Examples 65726
# Finished epoch 97
# MODEL TEST (W/L/T): (592, 117, 1291)
# # Training Examples 65746
# Finished epoch 98
# MODEL TEST (W/L/T): (597, 117, 1286)
# # Training Examples 65394
# Finished epoch 99
# MODEL TEST (W/L/T): (583, 119, 1298)
# # Training Examples 65731
# Finished epoch 100
# MODEL TEST (W/L/T): (579, 105, 1316)
# # Training Examples 65736
# Finished epoch 101
# MODEL TEST (W/L/T): (575, 104, 1321)
# # Training Examples 65738
# Finished epoch 102
# MODEL TEST (W/L/T): (578, 107, 1315)
# # Training Examples 65728
# Finished epoch 103
# MODEL TEST (W/L/T): (585, 113, 1302)
# # Training Examples 65619
# Finished epoch 104
# MODEL TEST (W/L/T): (588, 116, 1296)
# # Training Examples 65600
# Finished epoch 105
# MODEL TEST (W/L/T): (587, 117, 1296)
# # Training Examples 65600
# Finished epoch 106
# MODEL TEST (W/L/T): (609, 124, 1267)
# # Training Examples 65606
# Finished epoch 107
# MODEL TEST (W/L/T): (615, 120, 1265)
# # Training Examples 65586
# Finished epoch 108
# MODEL TEST (W/L/T): (627, 141, 1232)
# # Training Examples 65581
# Finished epoch 109
# MODEL TEST (W/L/T): (630, 103, 1267)
# # Training Examples 65612
# Finished epoch 110
# MODEL TEST (W/L/T): (623, 100, 1277)
# # Training Examples 65608
# Finished epoch 111
# MODEL TEST (W/L/T): (602, 146, 1252)
# # Training Examples 65582
# Finished epoch 112
# MODEL TEST (W/L/T): (604, 146, 1250)
# # Training Examples 65594
# Finished epoch 113
# MODEL TEST (W/L/T): (602, 122, 1276)
# # Training Examples 65699
# Finished epoch 114
# MODEL TEST (W/L/T): (630, 124, 1246)
# # Training Examples 65706
# Finished epoch 115
# MODEL TEST (W/L/T): (659, 130, 1211)
# # Training Examples 65714
# Finished epoch 116
# MODEL TEST (W/L/T): (663, 195, 1142)
# # Training Examples 65304
# Finished epoch 117
# MODEL TEST (W/L/T): (662, 214, 1124)
# # Training Examples 65303
# Finished epoch 118
# MODEL TEST (W/L/T): (666, 189, 1145)
# # Training Examples 65696
# Finished epoch 119
# MODEL TEST (W/L/T): (666, 186, 1148)
# # Training Examples 65694
# Finished epoch 120
# MODEL TEST (W/L/T): (685, 151, 1164)
# # Training Examples 65694
# Finished epoch 121
# MODEL TEST (W/L/T): (691, 154, 1155)
# # Training Examples 65716
# Finished epoch 122
# MODEL TEST (W/L/T): (690, 164, 1146)
# # Training Examples 65693
# Finished epoch 123
# MODEL TEST (W/L/T): (693, 186, 1121)
# # Training Examples 65729
# Finished epoch 124
# MODEL TEST (W/L/T): (647, 203, 1150)
# # Training Examples 65730
# Finished epoch 125
# MODEL TEST (W/L/T): (652, 191, 1157)
# # Training Examples 65744
# Finished epoch 126
# MODEL TEST (W/L/T): (653, 271, 1076)
# # Training Examples 65751
# Finished epoch 127
# MODEL TEST (W/L/T): (671, 306, 1023)
# # Training Examples 65733
# Finished epoch 128
# MODEL TEST (W/L/T): (672, 304, 1024)
# # Training Examples 65725
# Finished epoch 129
# MODEL TEST (W/L/T): (626, 356, 1018)
# # Training Examples 65707
# Finished epoch 130
# MODEL TEST (W/L/T): (643, 333, 1024)
# # Training Examples 65704
# Finished epoch 131
# MODEL TEST (W/L/T): (640, 306, 1054)
# # Training Examples 65726
# Finished epoch 132
# MODEL TEST (W/L/T): (657, 305, 1038)
# # Training Examples 65685
# Finished epoch 133
# MODEL TEST (W/L/T): (668, 307, 1025)
# # Training Examples 65710
# Finished epoch 134
# MODEL TEST (W/L/T): (673, 314, 1013)
# # Training Examples 65716
# Finished epoch 135
# MODEL TEST (W/L/T): (689, 336, 975)
# # Training Examples 65677
# Finished epoch 136
# MODEL TEST (W/L/T): (673, 321, 1006)
# # Training Examples 65721
# Finished epoch 137
# MODEL TEST (W/L/T): (673, 318, 1009)
# # Training Examples 65702
# Finished epoch 138
# MODEL TEST (W/L/T): (692, 268, 1040)
# # Training Examples 65411
# Finished epoch 139
# MODEL TEST (W/L/T): (692, 250, 1058)
# # Training Examples 65364
# Finished epoch 140
# MODEL TEST (W/L/T): (690, 233, 1077)
# # Training Examples 65397
# Finished epoch 141
# MODEL TEST (W/L/T): (688, 233, 1079)
# # Training Examples 65591
# Finished epoch 142
# MODEL TEST (W/L/T): (684, 233, 1083)
# # Training Examples 65591
# Finished epoch 143
# MODEL TEST (W/L/T): (708, 238, 1054)
# # Training Examples 65390
# Finished epoch 144
# MODEL TEST (W/L/T): (718, 250, 1032)
# # Training Examples 65693
# Finished epoch 145
# MODEL TEST (W/L/T): (698, 240, 1062)
# # Training Examples 65673
# Finished epoch 146
# MODEL TEST (W/L/T): (694, 224, 1082)
# # Training Examples 65376
# Finished epoch 147
# MODEL TEST (W/L/T): (670, 219, 1111)
# # Training Examples 65363
# Finished epoch 148
# MODEL TEST (W/L/T): (650, 285, 1065)
# # Training Examples 65696
# Finished epoch 149
# MODEL TEST (W/L/T): (600, 284, 1116)
# # Training Examples 65718
# Finished epoch 150
# MODEL TEST (W/L/T): (599, 272, 1129)
# # Training Examples 65723
# Finished epoch 151
# MODEL TEST (W/L/T): (606, 277, 1117)
# # Training Examples 65714
# Finished epoch 152
# MODEL TEST (W/L/T): (667, 295, 1038)
# # Training Examples 65656
# Finished epoch 153
# MODEL TEST (W/L/T): (667, 285, 1048)
# # Training Examples 65709
# Finished epoch 154
# MODEL TEST (W/L/T): (670, 285, 1045)
# # Training Examples 65686
# Finished epoch 155
# MODEL TEST (W/L/T): (671, 296, 1033)
# # Training Examples 65687
# Finished epoch 156
# MODEL TEST (W/L/T): (657, 282, 1061)
# # Training Examples 65320
# Finished epoch 157
# MODEL TEST (W/L/T): (644, 257, 1099)
# # Training Examples 65719
# Finished epoch 158
# MODEL TEST (W/L/T): (638, 260, 1102)
# # Training Examples 65600
# Finished epoch 159
# MODEL TEST (W/L/T): (655, 245, 1100)
# # Training Examples 65690
# Finished epoch 160
# MODEL TEST (W/L/T): (659, 254, 1087)
# # Training Examples 65706
# Finished epoch 161
# MODEL TEST (W/L/T): (656, 272, 1072)
# # Training Examples 65700
# Finished epoch 162
# MODEL TEST (W/L/T): (642, 268, 1090)
# # Training Examples 65713
# Finished epoch 163
# MODEL TEST (W/L/T): (639, 257, 1104)
# # Training Examples 65699
# Finished epoch 164
# MODEL TEST (W/L/T): (656, 264, 1080)
# # Training Examples 65696
# Finished epoch 165
# MODEL TEST (W/L/T): (651, 252, 1097)
# # Training Examples 65742
# Finished epoch 166
# MODEL TEST (W/L/T): (663, 231, 1106)
# # Training Examples 65732
# Finished epoch 167
# MODEL TEST (W/L/T): (664, 233, 1103)
# # Training Examples 65716
# Finished epoch 168
# MODEL TEST (W/L/T): (674, 214, 1112)
# # Training Examples 65346
# Finished epoch 169
# MODEL TEST (W/L/T): (677, 221, 1102)
# # Training Examples 65364
# Finished epoch 170
# MODEL TEST (W/L/T): (717, 220, 1063)
# # Training Examples 65340
# Finished epoch 171
# MODEL TEST (W/L/T): (700, 213, 1087)
# # Training Examples 65332
# Finished epoch 172
# MODEL TEST (W/L/T): (691, 212, 1097)
# # Training Examples 65305
# Finished epoch 173
# MODEL TEST (W/L/T): (739, 223, 1038)
# # Training Examples 65295
# Finished epoch 174
# MODEL TEST (W/L/T): (713, 267, 1020)
# # Training Examples 65737
# Finished epoch 175
# MODEL TEST (W/L/T): (725, 246, 1029)
# # Training Examples 65744
# Finished epoch 176
# MODEL TEST (W/L/T): (724, 235, 1041)
# # Training Examples 65742
# Finished epoch 177
# MODEL TEST (W/L/T): (766, 256, 978)
# # Training Examples 65724
# Finished epoch 178
# MODEL TEST (W/L/T): (768, 257, 975)
# # Training Examples 65721
# Finished epoch 179
# MODEL TEST (W/L/T): (768, 246, 986)
# # Training Examples 65730
# Finished epoch 180
# MODEL TEST (W/L/T): (770, 247, 983)
# # Training Examples 65717
# Finished epoch 181
# MODEL TEST (W/L/T): (768, 210, 1022)
# # Training Examples 65745
# Finished epoch 182
# MODEL TEST (W/L/T): (759, 215, 1026)
# # Training Examples 65750
# Finished epoch 183
# MODEL TEST (W/L/T): (784, 227, 989)
# # Training Examples 65739
# Finished epoch 184
# MODEL TEST (W/L/T): (784, 226, 990)
# # Training Examples 65731
# Finished epoch 185
# MODEL TEST (W/L/T): (793, 213, 994)
# # Training Examples 65703
# Finished epoch 186
# MODEL TEST (W/L/T): (793, 201, 1006)
# # Training Examples 65726
# Finished epoch 187
# MODEL TEST (W/L/T): (783, 205, 1012)
# # Training Examples 65709
# Finished epoch 188
# MODEL TEST (W/L/T): (781, 201, 1018)
# # Training Examples 65743
# Finished epoch 189
# MODEL TEST (W/L/T): (780, 205, 1015)
# # Training Examples 65701
# Finished epoch 190
# MODEL TEST (W/L/T): (796, 204, 1000)
# # Training Examples 65558
# Finished epoch 191
# MODEL TEST (W/L/T): (791, 197, 1012)
# # Training Examples 65547
# Finished epoch 192
# MODEL TEST (W/L/T): (778, 185, 1037)
# # Training Examples 65360
# Finished epoch 193
# MODEL TEST (W/L/T): (810, 174, 1016)
# # Training Examples 65339
# Finished epoch 194
# MODEL TEST (W/L/T): (801, 136, 1063)
# # Training Examples 65680
# Finished epoch 195
# MODEL TEST (W/L/T): (799, 144, 1057)
# # Training Examples 65684
# Finished epoch 196
# MODEL TEST (W/L/T): (806, 151, 1043)
# # Training Examples 65699
# Finished epoch 197
# MODEL TEST (W/L/T): (788, 148, 1064)
# # Training Examples 65673
# Finished epoch 198
# MODEL TEST (W/L/T): (811, 143, 1046)
# # Training Examples 65676
# Finished epoch 199
# MODEL TEST (W/L/T): (817, 112, 1071)
# # Training Examples 65686
# Finished epoch 200
# MODEL TEST (W/L/T): (803, 116, 1081)
# # Training Examples 65694
# Finished epoch 201
# MODEL TEST (W/L/T): (816, 118, 1066)
# # Training Examples 65306
# Finished epoch 202
# MODEL TEST (W/L/T): (821, 118, 1061)
# # Training Examples 65355
# Finished epoch 203
# MODEL TEST (W/L/T): (806, 226, 968)
# # Training Examples 65303
# Finished epoch 204
# MODEL TEST (W/L/T): (801, 102, 1097)
# # Training Examples 65333
# Finished epoch 205
# MODEL TEST (W/L/T): (803, 99, 1098)
# # Training Examples 65352
# Finished epoch 206
# MODEL TEST (W/L/T): (806, 85, 1109)
# # Training Examples 65346
# Finished epoch 207
# MODEL TEST (W/L/T): (818, 254, 928)
# # Training Examples 65335
# Finished epoch 208
# MODEL TEST (W/L/T): (827, 253, 920)
# # Training Examples 65324
# Finished epoch 209
# MODEL TEST (W/L/T): (827, 100, 1073)
# # Training Examples 65305
# Finished epoch 210
# MODEL TEST (W/L/T): (834, 253, 913)
# # Training Examples 65330
# Finished epoch 211
# MODEL TEST (W/L/T): (834, 254, 912)
# # Training Examples 65324
# Finished epoch 212
# MODEL TEST (W/L/T): (843, 254, 903)
# # Training Examples 65311
# Finished epoch 213
# MODEL TEST (W/L/T): (842, 255, 903)
# # Training Examples 65300
# Finished epoch 214
# MODEL TEST (W/L/T): (839, 246, 915)
# # Training Examples 65666
# Finished epoch 215
# MODEL TEST (W/L/T): (841, 229, 930)
# # Training Examples 65657
# Finished epoch 216
# MODEL TEST (W/L/T): (838, 229, 933)
# # Training Examples 65318
# Finished epoch 217
# MODEL TEST (W/L/T): (839, 251, 910)
# # Training Examples 65315
# Finished epoch 218
# MODEL TEST (W/L/T): (830, 257, 913)
# # Training Examples 65314
# Finished epoch 219
# MODEL TEST (W/L/T): (828, 266, 906)
# # Training Examples 65326
# Finished epoch 220
# MODEL TEST (W/L/T): (829, 255, 916)
# # Training Examples 65328
# Finished epoch 221
# MODEL TEST (W/L/T): (831, 253, 916)
# # Training Examples 65326
# Finished epoch 222
# MODEL TEST (W/L/T): (825, 243, 932)
# # Training Examples 65333
# Finished epoch 223
# MODEL TEST (W/L/T): (823, 243, 934)
# # Training Examples 65326
# Finished epoch 224
# MODEL TEST (W/L/T): (822, 261, 917)
# # Training Examples 65318
# Finished epoch 225
# MODEL TEST (W/L/T): (825, 224, 951)
# # Training Examples 65358
# Finished epoch 226
# MODEL TEST (W/L/T): (831, 230, 939)
# # Training Examples 65321
# Finished epoch 227
# MODEL TEST (W/L/T): (833, 214, 953)
# # Training Examples 65330
# Finished epoch 228
# MODEL TEST (W/L/T): (835, 218, 947)
# # Training Examples 65346
# Finished epoch 229
# MODEL TEST (W/L/T): (825, 213, 962)
# # Training Examples 65344
# Finished epoch 230
# MODEL TEST (W/L/T): (830, 77, 1093)
# # Training Examples 65718
# Finished epoch 231
# MODEL TEST (W/L/T): (842, 69, 1089)
# # Training Examples 65709
# Finished epoch 232
# MODEL TEST (W/L/T): (830, 70, 1100)
# # Training Examples 65704
# Finished epoch 233
# MODEL TEST (W/L/T): (826, 71, 1103)
# # Training Examples 65671
# Finished epoch 234
# MODEL TEST (W/L/T): (826, 91, 1083)
# # Training Examples 65717
# Finished epoch 235
# MODEL TEST (W/L/T): (834, 97, 1069)
# # Training Examples 65707
# Finished epoch 236
# MODEL TEST (W/L/T): (834, 90, 1076)
# # Training Examples 65697
# Finished epoch 237
# MODEL TEST (W/L/T): (816, 96, 1088)
# # Training Examples 65713
# Finished epoch 238
# MODEL TEST (W/L/T): (840, 84, 1076)
# # Training Examples 65704
# Finished epoch 239
# MODEL TEST (W/L/T): (840, 83, 1077)
# # Training Examples 65691
# Finished epoch 240
# MODEL TEST (W/L/T): (837, 107, 1056)
# # Training Examples 65701
# Finished epoch 241
# MODEL TEST (W/L/T): (836, 85, 1079)
# # Training Examples 65709
# Finished epoch 242
# MODEL TEST (W/L/T): (834, 80, 1086)
# # Training Examples 65707
# Finished epoch 243
# MODEL TEST (W/L/T): (830, 87, 1083)
# # Training Examples 65717
# Finished epoch 244
# MODEL TEST (W/L/T): (825, 87, 1088)
# # Training Examples 65726
# Finished epoch 245
# MODEL TEST (W/L/T): (833, 91, 1076)
# # Training Examples 65719
# Finished epoch 246
# MODEL TEST (W/L/T): (835, 75, 1090)
# # Training Examples 65702
# Finished epoch 247
# MODEL TEST (W/L/T): (835, 69, 1096)
# # Training Examples 65706
# Finished epoch 248
# MODEL TEST (W/L/T): (796, 73, 1131)
# # Training Examples 65731
# Finished epoch 249
# MODEL TEST (W/L/T): (806, 72, 1122)
# # Training Examples 65739
# Finished epoch 250
# MODEL TEST (W/L/T): (807, 75, 1118)
# # Training Examples 65742
# Finished epoch 251
# MODEL TEST (W/L/T): (826, 62, 1112)
# # Training Examples 65601
# Finished epoch 252
# MODEL TEST (W/L/T): (818, 65, 1117)
# # Training Examples 65599
# Finished epoch 253
# MODEL TEST (W/L/T): (820, 45, 1135)
# # Training Examples 65688
# Finished epoch 254
# MODEL TEST (W/L/T): (822, 48, 1130)
# # Training Examples 65718
# Finished epoch 255
# MODEL TEST (W/L/T): (818, 55, 1127)
# # Training Examples 65716
# Finished epoch 256
# MODEL TEST (W/L/T): (825, 70, 1105)
# # Training Examples 65696
# Finished epoch 257
# MODEL TEST (W/L/T): (824, 71, 1105)
# # Training Examples 65668
# Finished epoch 258
# MODEL TEST (W/L/T): (826, 71, 1103)
# # Training Examples 65688
# Finished epoch 259
# MODEL TEST (W/L/T): (826, 81, 1093)
# # Training Examples 65706
# Finished epoch 260
# MODEL TEST (W/L/T): (837, 83, 1080)
# # Training Examples 65704
# Finished epoch 261
# MODEL TEST (W/L/T): (848, 80, 1072)
# # Training Examples 65361
# Finished epoch 262
# MODEL TEST (W/L/T): (845, 97, 1058)
# # Training Examples 65356
# Finished epoch 263
# MODEL TEST (W/L/T): (850, 123, 1027)
# # Training Examples 65363
# Finished epoch 264
# MODEL TEST (W/L/T): (763, 138, 1099)
# # Training Examples 65315
# Finished epoch 265
# MODEL TEST (W/L/T): (758, 81, 1161)
# # Training Examples 65354
# Finished epoch 266
# MODEL TEST (W/L/T): (753, 77, 1170)
# # Training Examples 65357
# Finished epoch 267
# MODEL TEST (W/L/T): (752, 122, 1126)
# # Training Examples 65373
# Finished epoch 268
# MODEL TEST (W/L/T): (750, 68, 1182)
# # Training Examples 65359
# Finished epoch 269
# MODEL TEST (W/L/T): (715, 65, 1220)
# # Training Examples 65728
# Finished epoch 270
# MODEL TEST (W/L/T): (711, 57, 1232)
# # Training Examples 65702
# Finished epoch 271
# MODEL TEST (W/L/T): (741, 31, 1228)
# # Training Examples 65695
# Finished epoch 272
# MODEL TEST (W/L/T): (753, 30, 1217)
# # Training Examples 65715
# Finished epoch 273
# MODEL TEST (W/L/T): (745, 14, 1241)
# # Training Examples 65721
# Finished epoch 274
# MODEL TEST (W/L/T): (757, 15, 1228)
# # Training Examples 65690
# Finished epoch 275
# MODEL TEST (W/L/T): (758, 14, 1228)
# # Training Examples 65690
# Finished epoch 276
# MODEL TEST (W/L/T): (757, 14, 1229)
# # Training Examples 65714
# Finished epoch 277
# MODEL TEST (W/L/T): (750, 14, 1236)
# # Training Examples 65711
# Finished epoch 278
# MODEL TEST (W/L/T): (749, 15, 1236)
# # Training Examples 65706
# Finished epoch 279
# MODEL TEST (W/L/T): (765, 15, 1220)
# # Training Examples 65711
# Finished epoch 280
# MODEL TEST (W/L/T): (767, 8, 1225)
# # Training Examples 65684
# Finished epoch 281
# MODEL TEST (W/L/T): (761, 9, 1230)
# # Training Examples 65714
# Finished epoch 282
# MODEL TEST (W/L/T): (753, 9, 1238)
# # Training Examples 65580
# Finished epoch 283
# MODEL TEST (W/L/T): (751, 7, 1242)
# # Training Examples 65668
# Finished epoch 284
# MODEL TEST (W/L/T): (712, 7, 1281)
# # Training Examples 65688
# Finished epoch 285
# MODEL TEST (W/L/T): (713, 7, 1280)
# # Training Examples 65705
# Finished epoch 286
# MODEL TEST (W/L/T): (713, 7, 1280)
# # Training Examples 65673
# Finished epoch 287
# MODEL TEST (W/L/T): (700, 7, 1293)
# # Training Examples 65687
# Finished epoch 288
# MODEL TEST (W/L/T): (713, 11, 1276)
# # Training Examples 65666
# Finished epoch 289
# MODEL TEST (W/L/T): (723, 11, 1266)
# # Training Examples 65677
# Finished epoch 290
# MODEL TEST (W/L/T): (720, 11, 1269)
# # Training Examples 65700
# Finished epoch 291
# MODEL TEST (W/L/T): (722, 9, 1269)
# # Training Examples 65680
# Finished epoch 292
# MODEL TEST (W/L/T): (726, 9, 1265)
# # Training Examples 65721
# Finished epoch 293
# MODEL TEST (W/L/T): (727, 9, 1264)
# # Training Examples 65707
# Finished epoch 294
# MODEL TEST (W/L/T): (740, 9, 1251)
# # Training Examples 65700
# Finished epoch 295
# MODEL TEST (W/L/T): (743, 9, 1248)
# # Training Examples 65694
# Finished epoch 296
# MODEL TEST (W/L/T): (743, 9, 1248)
# # Training Examples 65669
# Finished epoch 297
# MODEL TEST (W/L/T): (743, 9, 1248)
# # Training Examples 65669
# Finished epoch 298
# MODEL TEST (W/L/T): (748, 9, 1243)
# # Training Examples 65685
# Finished epoch 299
# MODEL TEST (W/L/T): (755, 9, 1236)
# # Training Examples 65703
# Finished epoch 300
# MODEL TEST (W/L/T): (754, 9, 1237)
# # Training Examples 65656
# Finished epoch 301
# MODEL TEST (W/L/T): (755, 16, 1229)
# # Training Examples 65696
# Finished epoch 302
# MODEL TEST (W/L/T): (740, 14, 1246)
# # Training Examples 65704
# Finished epoch 303
# MODEL TEST (W/L/T): (762, 15, 1223)
# # Training Examples 65672
# Finished epoch 304
# MODEL TEST (W/L/T): (764, 14, 1222)
# # Training Examples 65694
# Finished epoch 305
# MODEL TEST (W/L/T): (765, 15, 1220)
# # Training Examples 65676
# Finished epoch 306
# MODEL TEST (W/L/T): (759, 15, 1226)
# # Training Examples 65662
# Finished epoch 307
# MODEL TEST (W/L/T): (758, 15, 1227)
# # Training Examples 65699
# Finished epoch 308
# MODEL TEST (W/L/T): (757, 17, 1226)
# # Training Examples 65692
# Finished epoch 309
# MODEL TEST (W/L/T): (755, 16, 1229)
# # Training Examples 65664
# Finished epoch 310
# MODEL TEST (W/L/T): (737, 16, 1247)
# # Training Examples 65667
# Finished epoch 311
# MODEL TEST (W/L/T): (750, 16, 1234)
# # Training Examples 65676
# Finished epoch 312
# MODEL TEST (W/L/T): (766, 16, 1218)
# # Training Examples 65714
# Finished epoch 313
# MODEL TEST (W/L/T): (768, 14, 1218)
# # Training Examples 65684
# Finished epoch 314
# MODEL TEST (W/L/T): (761, 26, 1213)
# # Training Examples 65683
# Finished epoch 315
# MODEL TEST (W/L/T): (760, 26, 1214)
# # Training Examples 65681
# Finished epoch 316
# MODEL TEST (W/L/T): (768, 24, 1208)
# # Training Examples 65657
# Finished epoch 317
# MODEL TEST (W/L/T): (773, 23, 1204)
# # Training Examples 65686
# Finished epoch 318
# MODEL TEST (W/L/T): (770, 23, 1207)
# # Training Examples 65666
# Finished epoch 319
# MODEL TEST (W/L/T): (767, 28, 1205)
# # Training Examples 65703
# Finished epoch 320
# MODEL TEST (W/L/T): (768, 28, 1204)
# # Training Examples 65683
# Finished epoch 321
# MODEL TEST (W/L/T): (803, 31, 1166)
# # Training Examples 65698
# Finished epoch 322
# MODEL TEST (W/L/T): (798, 30, 1172)
# # Training Examples 65689
# Finished epoch 323
# MODEL TEST (W/L/T): (798, 30, 1172)
# # Training Examples 65706
# Finished epoch 324
# MODEL TEST (W/L/T): (788, 30, 1182)
# # Training Examples 65708
# Finished epoch 325
# MODEL TEST (W/L/T): (790, 29, 1181)
# # Training Examples 65684
# Finished epoch 326
# MODEL TEST (W/L/T): (792, 37, 1171)
# # Training Examples 65690
# Finished epoch 327
# MODEL TEST (W/L/T): (822, 34, 1144)
# # Training Examples 65697
# Finished epoch 328
# MODEL TEST (W/L/T): (824, 34, 1142)
# # Training Examples 65665
# Finished epoch 329
# MODEL TEST (W/L/T): (826, 34, 1140)
# # Training Examples 65705
# Finished epoch 330
# MODEL TEST (W/L/T): (824, 34, 1142)
# # Training Examples 65671
# Finished epoch 331
# MODEL TEST (W/L/T): (822, 34, 1144)
# # Training Examples 65698
# Finished epoch 332
# MODEL TEST (W/L/T): (816, 33, 1151)
# # Training Examples 65692
# Finished epoch 333
# MODEL TEST (W/L/T): (816, 33, 1151)
# # Training Examples 65684
# Finished epoch 334
# MODEL TEST (W/L/T): (819, 34, 1147)
# # Training Examples 65689
# Finished epoch 335
# MODEL TEST (W/L/T): (817, 33, 1150)
# # Training Examples 65698
# Finished epoch 336
# MODEL TEST (W/L/T): (817, 32, 1151)
# # Training Examples 65688
# Finished epoch 337
# MODEL TEST (W/L/T): (820, 32, 1148)
# # Training Examples 65707
# Finished epoch 338
# MODEL TEST (W/L/T): (825, 32, 1143)
# # Training Examples 65672
# Finished epoch 339
# MODEL TEST (W/L/T): (825, 32, 1143)
# # Training Examples 65685
# Finished epoch 340
# MODEL TEST (W/L/T): (822, 33, 1145)
# # Training Examples 65697
# Finished epoch 341
# MODEL TEST (W/L/T): (828, 21, 1151)
# # Training Examples 65684
# Finished epoch 342
# MODEL TEST (W/L/T): (829, 17, 1154)
# # Training Examples 65678
# Finished epoch 343
# MODEL TEST (W/L/T): (831, 17, 1152)
# # Training Examples 65693
# Finished epoch 344
# MODEL TEST (W/L/T): (836, 24, 1140)
# # Training Examples 65702
# Finished epoch 345
# MODEL TEST (W/L/T): (835, 24, 1141)
# # Training Examples 65708
# Finished epoch 346
# MODEL TEST (W/L/T): (835, 24, 1141)
# # Training Examples 65725
# Finished epoch 347
# MODEL TEST (W/L/T): (835, 24, 1141)
# # Training Examples 65664
# Finished epoch 348
# MODEL TEST (W/L/T): (840, 24, 1136)
# # Training Examples 65685
# Finished epoch 349
# MODEL TEST (W/L/T): (838, 27, 1135)
# # Training Examples 65685
# Finished epoch 350
# MODEL TEST (W/L/T): (838, 19, 1143)
# # Training Examples 65666
# Finished epoch 351
# MODEL TEST (W/L/T): (839, 19, 1142)
# # Training Examples 65690
# Finished epoch 352
# MODEL TEST (W/L/T): (836, 19, 1145)
# # Training Examples 65674
# Finished epoch 353
# MODEL TEST (W/L/T): (843, 19, 1138)
# # Training Examples 65665
# Finished epoch 354
# MODEL TEST (W/L/T): (847, 19, 1134)
# # Training Examples 65690
# Finished epoch 355
# MODEL TEST (W/L/T): (858, 19, 1123)
# # Training Examples 65691
# Finished epoch 356
# MODEL TEST (W/L/T): (858, 19, 1123)
# # Training Examples 65643
# Finished epoch 357
# MODEL TEST (W/L/T): (856, 19, 1125)
# # Training Examples 65677
# Finished epoch 358
# MODEL TEST (W/L/T): (858, 19, 1123)
# # Training Examples 65641
# Finished epoch 359
# MODEL TEST (W/L/T): (857, 23, 1120)
# # Training Examples 65671
# Finished epoch 360
# MODEL TEST (W/L/T): (856, 14, 1130)
# # Training Examples 65669
# Finished epoch 361
# MODEL TEST (W/L/T): (856, 14, 1130)
# # Training Examples 65672
# Finished epoch 362
# MODEL TEST (W/L/T): (858, 15, 1127)
# # Training Examples 65692
# Finished epoch 363
# MODEL TEST (W/L/T): (850, 15, 1135)
# # Training Examples 65647
# Finished epoch 364
# MODEL TEST (W/L/T): (853, 15, 1132)
# # Training Examples 65674
# Finished epoch 365
# MODEL TEST (W/L/T): (852, 15, 1133)
# # Training Examples 65665
# Finished epoch 366
# MODEL TEST (W/L/T): (852, 15, 1133)
# # Training Examples 65688
# Finished epoch 367
# MODEL TEST (W/L/T): (851, 15, 1134)
# # Training Examples 65698
# Finished epoch 368
# MODEL TEST (W/L/T): (830, 15, 1155)
# # Training Examples 65382
# Finished epoch 369
# MODEL TEST (W/L/T): (827, 13, 1160)
# # Training Examples 65375
# Finished epoch 370
# MODEL TEST (W/L/T): (820, 17, 1163)
# # Training Examples 65598
# Finished epoch 371
# MODEL TEST (W/L/T): (840, 5, 1155)
# # Training Examples 65714
# Finished epoch 372
# MODEL TEST (W/L/T): (822, 9, 1169)
# # Training Examples 65692
# Finished epoch 373
# MODEL TEST (W/L/T): (784, 14, 1202)
# # Training Examples 65695
# Finished epoch 374
# MODEL TEST (W/L/T): (794, 20, 1186)
# # Training Examples 65699
# Finished epoch 375
# MODEL TEST (W/L/T): (793, 20, 1187)
# # Training Examples 65708
# Finished epoch 376
# MODEL TEST (W/L/T): (781, 20, 1199)
# # Training Examples 65696
# Finished epoch 377
# MODEL TEST (W/L/T): (765, 21, 1214)
# # Training Examples 65703
# Finished epoch 378
# MODEL TEST (W/L/T): (774, 22, 1204)
# # Training Examples 65701
# Finished epoch 379
# MODEL TEST (W/L/T): (774, 22, 1204)
# # Training Examples 65704
# Finished epoch 380
# MODEL TEST (W/L/T): (774, 24, 1202)
# # Training Examples 65694
# Finished epoch 381
# MODEL TEST (W/L/T): (798, 22, 1180)
# # Training Examples 65735
# Finished epoch 382
# MODEL TEST (W/L/T): (797, 21, 1182)
# # Training Examples 65705
# Finished epoch 383
# MODEL TEST (W/L/T): (803, 15, 1182)
# # Training Examples 65701
# Finished epoch 384
# MODEL TEST (W/L/T): (791, 15, 1194)
# # Training Examples 65703
# Finished epoch 385
# MODEL TEST (W/L/T): (787, 16, 1197)
# # Training Examples 65705
# Finished epoch 386
# MODEL TEST (W/L/T): (788, 15, 1197)
# # Training Examples 65695
# Finished epoch 387
# MODEL TEST (W/L/T): (790, 15, 1195)
# # Training Examples 65689
# Finished epoch 388
# MODEL TEST (W/L/T): (783, 15, 1202)
# # Training Examples 65732
# Finished epoch 389
# MODEL TEST (W/L/T): (794, 15, 1191)
# # Training Examples 65711
# Finished epoch 390
# MODEL TEST (W/L/T): (803, 16, 1181)
# # Training Examples 65689
# Finished epoch 391
# MODEL TEST (W/L/T): (799, 16, 1185)
# # Training Examples 65692
# Finished epoch 392
# MODEL TEST (W/L/T): (756, 15, 1229)
# # Training Examples 65694
# Finished epoch 393
# MODEL TEST (W/L/T): (762, 17, 1221)
# # Training Examples 65726
# Finished epoch 394
# MODEL TEST (W/L/T): (766, 17, 1217)
# # Training Examples 65691
# Finished epoch 395
# MODEL TEST (W/L/T): (766, 17, 1217)
# # Training Examples 65704
# Finished epoch 396
# MODEL TEST (W/L/T): (766, 17, 1217)
# # Training Examples 65702
# Finished epoch 397
# MODEL TEST (W/L/T): (768, 17, 1215)
# # Training Examples 65712
# Finished epoch 398
# MODEL TEST (W/L/T): (771, 17, 1212)
# # Training Examples 65688
# Finished epoch 399
# MODEL TEST (W/L/T): (771, 17, 1212)
# # Training Examples 65714
# Finished epoch 400
# MODEL TEST (W/L/T): (771, 17, 1212)
# # Training Examples 65706
# Finished epoch 401
# MODEL TEST (W/L/T): (772, 16, 1212)
# # Training Examples 65692
# Finished epoch 402
# MODEL TEST (W/L/T): (773, 14, 1213)
# # Training Examples 65690
# Finished epoch 403
# MODEL TEST (W/L/T): (781, 14, 1205)
# # Training Examples 65701
# Finished epoch 404
# MODEL TEST (W/L/T): (801, 17, 1182)
# # Training Examples 65700
# Finished epoch 405
# MODEL TEST (W/L/T): (803, 17, 1180)
# # Training Examples 65691
# Finished epoch 406
# MODEL TEST (W/L/T): (804, 17, 1179)
# # Training Examples 65671
# Finished epoch 407
# MODEL TEST (W/L/T): (809, 17, 1174)
# # Training Examples 65705
# Finished epoch 408
# MODEL TEST (W/L/T): (809, 17, 1174)
# # Training Examples 65691
# Finished epoch 409
# MODEL TEST (W/L/T): (806, 22, 1172)
# # Training Examples 65697
# Finished epoch 410
# MODEL TEST (W/L/T): (812, 13, 1175)
# # Training Examples 65664
# Finished epoch 411
# MODEL TEST (W/L/T): (810, 13, 1177)
# # Training Examples 65694
# Finished epoch 412
# MODEL TEST (W/L/T): (816, 13, 1171)
# # Training Examples 65692
# Finished epoch 413
# MODEL TEST (W/L/T): (833, 13, 1154)
# # Training Examples 65664
# Finished epoch 414
# MODEL TEST (W/L/T): (837, 8, 1155)
# # Training Examples 65682
# Finished epoch 415
# MODEL TEST (W/L/T): (836, 7, 1157)
# # Training Examples 65681
# Finished epoch 416
# MODEL TEST (W/L/T): (835, 6, 1159)
# # Training Examples 65685
# Finished epoch 417
# MODEL TEST (W/L/T): (834, 6, 1160)
# # Training Examples 65654
# Finished epoch 418
# MODEL TEST (W/L/T): (835, 6, 1159)
# # Training Examples 65685
# Finished epoch 419
# MODEL TEST (W/L/T): (840, 6, 1154)
# # Training Examples 65691
# Finished epoch 420
# MODEL TEST (W/L/T): (823, 6, 1171)
# # Training Examples 65669
# Finished epoch 421
# MODEL TEST (W/L/T): (827, 6, 1167)
# # Training Examples 65656
# Finished epoch 422
# MODEL TEST (W/L/T): (831, 6, 1163)
# # Training Examples 65683
# Finished epoch 423
# MODEL TEST (W/L/T): (829, 6, 1165)
# # Training Examples 65691
# Finished epoch 424
# MODEL TEST (W/L/T): (826, 6, 1168)
# # Training Examples 65654
# Finished epoch 425
# MODEL TEST (W/L/T): (826, 6, 1168)
# # Training Examples 65658
# Finished epoch 426
# MODEL TEST (W/L/T): (824, 4, 1172)
# # Training Examples 65662
# Finished epoch 427
# MODEL TEST (W/L/T): (818, 4, 1178)
# # Training Examples 65686
# Finished epoch 428
# MODEL TEST (W/L/T): (815, 4, 1181)
# # Training Examples 65664
# Finished epoch 429
# MODEL TEST (W/L/T): (816, 4, 1180)
# # Training Examples 65657
# Finished epoch 430
# MODEL TEST (W/L/T): (818, 0, 1182)
# # Training Examples 65693
# Finished epoch 431
# MODEL TEST (W/L/T): (815, 0, 1185)
# # Training Examples 65669
# Finished epoch 432
# MODEL TEST (W/L/T): (814, 0, 1186)
# # Training Examples 65699
# Finished epoch 433
# MODEL TEST (W/L/T): (814, 0, 1186)
# # Training Examples 65695
# Finished epoch 434
# MODEL TEST (W/L/T): (817, 0, 1183)
# # Training Examples 65675
# Finished epoch 435
# MODEL TEST (W/L/T): (817, 0, 1183)
# # Training Examples 65671
# Finished epoch 436
# MODEL TEST (W/L/T): (816, 0, 1184)
# # Training Examples 65691
# Finished epoch 437
# MODEL TEST (W/L/T): (816, 0, 1184)
# # Training Examples 65680
# Finished epoch 438
# MODEL TEST (W/L/T): (814, 0, 1186)
# # Training Examples 65645
# Finished epoch 439
# MODEL TEST (W/L/T): (813, 0, 1187)
# # Training Examples 65673
# Finished epoch 440
# MODEL TEST (W/L/T): (812, 0, 1188)
# # Training Examples 65684
# Finished epoch 441
# MODEL TEST (W/L/T): (812, 0, 1188)
# # Training Examples 65688
# Finished epoch 442
# MODEL TEST (W/L/T): (813, 0, 1187)
# # Training Examples 65672
# Finished epoch 443
# MODEL TEST (W/L/T): (813, 0, 1187)
# # Training Examples 65653
# Finished epoch 444
# MODEL TEST (W/L/T): (813, 0, 1187)
# # Training Examples 65694
# Finished epoch 445
# MODEL TEST (W/L/T): (813, 0, 1187)
# # Training Examples 65686
# Finished epoch 446
# MODEL TEST (W/L/T): (812, 0, 1188)
# # Training Examples 65649
# Finished epoch 447
# MODEL TEST (W/L/T): (813, 0, 1187)
# # Training Examples 65684
# Finished epoch 448
# MODEL TEST (W/L/T): (813, 0, 1187)
# # Training Examples 65680
# Finished epoch 449
# MODEL TEST (W/L/T): (809, 0, 1191)
# # Training Examples 65678
# Finished epoch 450
# MODEL TEST (W/L/T): (796, 0, 1204)
# # Training Examples 65668
# Finished epoch 451
# MODEL TEST (W/L/T): (793, 5, 1202)
# # Training Examples 65698
# Finished epoch 452
# MODEL TEST (W/L/T): (794, 5, 1201)
# # Training Examples 65689
# Finished epoch 453
# MODEL TEST (W/L/T): (791, 5, 1204)
# # Training Examples 65646
# Finished epoch 454
# MODEL TEST (W/L/T): (794, 5, 1201)
# # Training Examples 65681
# Finished epoch 455
# MODEL TEST (W/L/T): (794, 5, 1201)
# # Training Examples 65686
# Finished epoch 456
# MODEL TEST (W/L/T): (794, 5, 1201)
# # Training Examples 65718
# Finished epoch 457
# MODEL TEST (W/L/T): (792, 5, 1203)
# # Training Examples 65678
# Finished epoch 458
# MODEL TEST (W/L/T): (792, 5, 1203)
# # Training Examples 65691
# Finished epoch 459
# MODEL TEST (W/L/T): (792, 5, 1203)
# # Training Examples 65693
# Finished epoch 460
# MODEL TEST (W/L/T): (791, 5, 1204)
# # Training Examples 65688
# Finished epoch 461
# MODEL TEST (W/L/T): (791, 5, 1204)
# # Training Examples 65705
# Finished epoch 462
# MODEL TEST (W/L/T): (794, 5, 1201)
# # Training Examples 65679
# Finished epoch 463
# MODEL TEST (W/L/T): (783, 5, 1212)
# # Training Examples 65709
# Finished epoch 464
# MODEL TEST (W/L/T): (791, 5, 1204)
# # Training Examples 65690
# Finished epoch 465
# MODEL TEST (W/L/T): (792, 5, 1203)
# # Training Examples 65691
# Finished epoch 466
# MODEL TEST (W/L/T): (793, 5, 1202)
# # Training Examples 65685
# Finished epoch 467
# MODEL TEST (W/L/T): (793, 5, 1202)
# # Training Examples 65681
# Finished epoch 468
# MODEL TEST (W/L/T): (793, 5, 1202)
# # Training Examples 65689
# Finished epoch 469
# MODEL TEST (W/L/T): (794, 5, 1201)
# # Training Examples 65708
# Finished epoch 470
# MODEL TEST (W/L/T): (795, 5, 1200)
# # Training Examples 65692
# Finished epoch 471
# MODEL TEST (W/L/T): (795, 6, 1199)
# # Training Examples 65716
# Finished epoch 472
# MODEL TEST (W/L/T): (804, 6, 1190)
# # Training Examples 65663
# Finished epoch 473
# MODEL TEST (W/L/T): (804, 6, 1190)
# # Training Examples 65666
# Finished epoch 474
# MODEL TEST (W/L/T): (804, 6, 1190)
# # Training Examples 65667
# Finished epoch 475
# MODEL TEST (W/L/T): (805, 6, 1189)
# # Training Examples 65714
# Finished epoch 476
# MODEL TEST (W/L/T): (807, 6, 1187)
# # Training Examples 65716
# Finished epoch 477
# MODEL TEST (W/L/T): (809, 6, 1185)
# # Training Examples 65702
# Finished epoch 478
# MODEL TEST (W/L/T): (810, 0, 1190)
# # Training Examples 65698
# Finished epoch 479
# MODEL TEST (W/L/T): (810, 0, 1190)
# # Training Examples 65678
# Finished epoch 480
# MODEL TEST (W/L/T): (809, 0, 1191)
# # Training Examples 65699
# Finished epoch 481
# MODEL TEST (W/L/T): (807, 0, 1193)
# # Training Examples 65698
# Finished epoch 482
# MODEL TEST (W/L/T): (805, 0, 1195)
# # Training Examples 65683
# Finished epoch 483
# MODEL TEST (W/L/T): (805, 0, 1195)
# # Training Examples 65698
# Finished epoch 484
# MODEL TEST (W/L/T): (807, 0, 1193)
# # Training Examples 65682
# Finished epoch 485
# MODEL TEST (W/L/T): (806, 0, 1194)
# # Training Examples 65689
# Finished epoch 486
# MODEL TEST (W/L/T): (795, 0, 1205)
# # Training Examples 65685
# Finished epoch 487
# MODEL TEST (W/L/T): (795, 0, 1205)
# # Training Examples 65701
# Finished epoch 488
# MODEL TEST (W/L/T): (794, 0, 1206)
# # Training Examples 65700
# Finished epoch 489
# MODEL TEST (W/L/T): (794, 0, 1206)
# # Training Examples 65700
# Finished epoch 490
# MODEL TEST (W/L/T): (794, 0, 1206)
# # Training Examples 65715
# Finished epoch 491
# MODEL TEST (W/L/T): (790, 0, 1210)
# # Training Examples 65698
# Finished epoch 492
# MODEL TEST (W/L/T): (781, 7, 1212)
# # Training Examples 65715
# Finished epoch 493
# MODEL TEST (W/L/T): (783, 7, 1210)
# # Training Examples 65687
# Finished epoch 494
# MODEL TEST (W/L/T): (783, 7, 1210)
# # Training Examples 65705
# Finished epoch 495
# MODEL TEST (W/L/T): (783, 7, 1210)
# # Training Examples 65703
# Finished epoch 496
# MODEL TEST (W/L/T): (780, 7, 1213)
# # Training Examples 65698
# Finished epoch 497
# MODEL TEST (W/L/T): (780, 7, 1213)
# # Training Examples 65703
# Finished epoch 498
# MODEL TEST (W/L/T): (794, 7, 1199)
# # Training Examples 65674
# Finished epoch 499
# MODEL TEST (W/L/T): (796, 0, 1204)
