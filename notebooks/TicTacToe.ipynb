# %%
### Imports

import math,sys
import numpy
import scipy,scipy.optimize,scipy.spatial,scipy.spatial.distance,scipy.stats
import json
import sqlite3
from collections import *
from enum import Enum
import random

from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
from keras import backend as K

import theano,theano.tensor

# %%
### Constants

NUM_PLAYERS=2  # X -> player 0, O -> player 1
SQUARES=9 # 9 Squares
SQUARE_VALUES=3 # -1 -> empty, 0 -> X, 1 -> O
NUM_FEATURES = NUM_PLAYERS*SQUARES*SQUARE_VALUES+1  # Total number of features (inputs to the DNN)
NUM_ACTIONS=SQUARES # Maximum number of actions (outputs from the DNN)
CHANCE_TO_RANDOM_ACTION = 0.1 # Chance to move randomly to handle exploration
DISCOUNT_FACTOR = 0.9 # Discounts future rewards based on time from the current state

# %% [markdown]
# ## Encode State
#
# This function takes data about the game and encodes it as an array that can be entered into a DNN. This is where the "secret sauce" goes, where we describe the state of the board game in a way that is conducive to successful training.
#
# A few items worth noting about the way I encoded Tic Tac Toe:
#
# ### All of the features are binary
#
# Continuous (i.e. floating point) features are only effective if they represent a gradient that (somewhat) relates linearly to the output (or linearly to the odds of the output when using sigmoid/tanh).  Note that, although I'm representing a board square as -1/0/+1 for empty/X/O respectively, trying to cram this information into a single square assumes that "empty" is the opposite of "O".  Even if I re-ordered so "X" could be the opposite of "O", this will still cause strange interactions that will make the network ineffective (try it and see for yourself!).
#
# ### Initiative is encoded by duplicating the entire game state
#
# Obviously, initiative (whose turn it is to move) is incredibly important.  I encoded this by duplicating the entire board state, and only activating one of the copies at a time.  This is similar to having a separate DNN for player X and player O, except that by having a single network, it can learn some common ideas.  I believe having two separate networks would actually perform better, but haven't tried it.

# %%
def EncodeState(currentPlayer, board):
    features = [0]*(NUM_FEATURES)
    playerShift = (currentPlayer)*SQUARES*SQUARE_VALUES
    for x in range(0,SQUARES):
        squareValue = board[x]+1;
        features[playerShift + (x*SQUARE_VALUES) + squareValue] = 1.0
    features[NUM_PLAYERS*SQUARES*SQUARE_VALUES] = 1.0 # Bias term
    return features

# %%
# This contains the encoded state and the action/player so value can be assigned from future rewards.
class TrainingExample:
    def __init__(self,turn,features,action,playerIndex):
        self.turn = turn
        self.features = features
        self.action = action
        self.playerIndex = playerIndex

# Takes an action and updates the state
def TakeAction(board, player, move):
    board[move] = player

# Setermines if the current state is terminal
def GetWinner(board):
    for player in range(1,3):
        if board[0]==player and board[1]==player and board[2]==player:
            return player
        if board[3]==player and board[4]==player and board[5]==player:
            return player
        if board[6]==player and board[7]==player and board[8]==player:
            return player
        if board[0]==player and board[3]==player and board[6]==player:
            return player
        if board[1]==player and board[4]==player and board[7]==player:
            return player
        if board[2]==player and board[5]==player and board[8]==player:
            return player
    return -1
    
# Plays a single match and stores training examples in X_input and Y_input.
# Prints some information about the game ifdebug is set to True
def PlayMatch(models, X_input, Y_input, debug):
    trainingExamples = []
    board = [-1]*9
    for turn in range(0,9):
        currentPlayer = turn%2
        encodedState = EncodeState(currentPlayer, board)
        if models is None or models[currentPlayer] is None or numpy.random.ranf() < CHANCE_TO_RANDOM_ACTION:
            # Play in a random square
            move = -1
            while move == -1:
                move = numpy.random.randint(9)
                if board[move]>=0:
                    move = -1
        else:
            # Query the model
            model = models[currentPlayer]
            features = numpy.array([encodedState,])
            actionValues = model.predict(features, batch_size=1, verbose=0)[0]
            # Choose the action with the highest expected value
            if debug:
                print(currentPlayer,board,actionValues)
            move = -1000000000
            while move == -1000000000:
                move = numpy.argmax(actionValues)
                if board[move]>=0:
                    actionValues[move] = -1000000000
                    move = -1000000000
        if debug:
            print("player",currentPlayer,"makes move",move)
        trainingExamples.append(TrainingExample(turn, encodedState, move, currentPlayer))
        TakeAction(board,currentPlayer,move)
        winner = GetWinner(board)
        if winner > -1:
            break
    if debug:
        print('winner is',winner)
    playerValues = []
    for pIndex in range(0,NUM_PLAYERS):
        if winner == -1:
            value = 8.0 # 8 Reward for a tie
        elif winner == pIndex:
            value = 32.0 # 32 for a win
        else:
            value = 2.0 # 2 for a loss
        playerValues.append(value)
    for t in trainingExamples:
        discountedValue = playerValues[t.playerIndex] * (DISCOUNT_FACTOR ** (turn - t.turn))
        X_input.append(t.features)
        labels = [0]*SQUARES
        labels[t.action] = discountedValue
        Y_input.append(labels)
    return winner

# Play several matches with a fixed seed
def PlayMatches(X_input, Y_input, model, numMatches):
    random.seed(1)
    numpy.random.seed(1)
    for x in range(0,numMatches):
        PlayMatch([model, model], X_input, Y_input, False)
    return X_input,Y_input

# This plays against a pure-random opponent and returns (win, lose, tie)
def TestModel(model):
    random.seed(1)
    numpy.random.seed(1)
    winCount=0
    loseCount=0
    tieCount=0
    for x in range(0,1000):
        winner = PlayMatch([model, None], [], [], False)
        if winner == -1:
            tieCount = tieCount+1
        elif winner == 0:
            winCount = winCount+1
        elif winner == 1:
            loseCount = loseCount+1
        else:
            print(winner)
    for x in range(0,1000):
        winner = PlayMatch([None, model], [], [], False)
        if winner == -1:
            tieCount = tieCount+1
        elif winner == 0:
            loseCount = loseCount+1
        elif winner == 1:
            winCount = winCount+1
        else:
            print(winner)
    return (winCount,loseCount,tieCount)

# Play a match with no model (pure random) and debug just to show what happens.
PlayMatch(None, [], [], True)
# Out:
# player 0 makes move 3
# player 1 makes move 7
# player 0 makes move 0
# player 1 makes move 6
# player 0 makes move 2
# player 1 makes move 5
# player 0 makes move 4
# player 1 makes move 1
# player 0 makes move 8
# winner is -1
# -1

# %%
model = Sequential()
model.add(Dense(512, input_dim=NUM_FEATURES, init='he_normal', activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(256, init='he_normal', activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(128, init='he_normal', activation='relu'))
model.add(Dropout(0.1))
# Although the values can never be negative, using a relu instead of linear here
#    results in significantly worse performance.  Maybe a leaky relu would help?
model.add(Dense(NUM_ACTIONS, init='he_normal', activation='linear'))

# This is a special loss function that does not consider zero outputs.  The reason why we need this is because there
#     is one output for each action, but the network wants to propagate error for all outputs simulatenously.  This
#     isn't possible here because we only know the value from taking a single action.  This loss function fixes
#     the issue by ignoring all zero outputs and only propagating error for the action that was actually taken.
def non_zero_mean_squared_error(y_true, y_pred):
    total = theano.tensor.sum(theano.tensor.square(abs(theano.tensor.sgn(y_true))*(y_pred - y_true)), axis=-1)
    count = theano.tensor.sum(abs(theano.tensor.sgn(y_true)))
    return total/count

model.compile(loss=non_zero_mean_squared_error, optimizer='sgd')

# Print a model to the console
def DumpModel(model):
    print("LAYERS:",len(model.layers))
    for layer in model.layers:
        print("NUM WEIGHT ARRAYS",len(layer.get_weights()))
        print(layer.get_weights()[1])
        weights = layer.get_weights()[0] # list of numpy arrays
        for x in range(0,NUM_FEATURES):
            print(weights[x])

# This keeps a ring buffer of training examples & labels
X_train = []
Y_train = []
for simulation in range(0,500):
    simulationModel = model
    if simulation == 0:
        # For the first iteration, use a pure-random player
        simulationModel = None
    PlayMatches(X_train, Y_train, simulationModel, 200)
    
    
    print("# Training Examples",len(X_train))
    # Trim the ring buffer
    X_train = X_train[-640000:]
    Y_train = Y_train[-640000:]
    history = model.fit(numpy.array(X_train), numpy.array(Y_train), nb_epoch=50, shuffle=True, batch_size=1024, verbose=0)
    model = history.model
    #DumpModel(model)
    print('Finished epoch',simulation)
    sys.stdout.flush()
    results = TestModel(model)
    print('MODEL TEST (W/L/T):',results)
    sys.stdout.flush()
# Out:
# # Training Examples 1735
# Finished epoch 0
# MODEL TEST (W/L/T): (245, 228, 1527)
# # Training Examples 3359
# Finished epoch 1
# MODEL TEST (W/L/T): (271, 329, 1400)
# # Training Examples 4971
# Finished epoch 2
# MODEL TEST (W/L/T): (419, 315, 1266)
# # Training Examples 6310
# Finished epoch 3
# MODEL TEST (W/L/T): (405, 307, 1288)
# # Training Examples 7969
# Finished epoch 4
# MODEL TEST (W/L/T): (415, 266, 1319)
# # Training Examples 9760
# Finished epoch 5
# MODEL TEST (W/L/T): (370, 279, 1351)
# # Training Examples 11436
# Finished epoch 6
# MODEL TEST (W/L/T): (368, 277, 1355)
# # Training Examples 13067
# Finished epoch 7
# MODEL TEST (W/L/T): (347, 176, 1477)
# # Training Examples 14830
# Finished epoch 8
# MODEL TEST (W/L/T): (274, 124, 1602)
# # Training Examples 16614
# Finished epoch 9
# MODEL TEST (W/L/T): (326, 223, 1451)
# # Training Examples 18335
# Finished epoch 10
# MODEL TEST (W/L/T): (319, 289, 1392)
# # Training Examples 20107
# Finished epoch 11
# MODEL TEST (W/L/T): (464, 292, 1244)
# # Training Examples 21728
# Finished epoch 12
# MODEL TEST (W/L/T): (548, 276, 1176)
# # Training Examples 23422
# Finished epoch 13
# MODEL TEST (W/L/T): (564, 251, 1185)
# # Training Examples 25022
# Finished epoch 14
# MODEL TEST (W/L/T): (559, 261, 1180)
# # Training Examples 26750
# Finished epoch 15
# MODEL TEST (W/L/T): (566, 290, 1144)
# # Training Examples 28478
# Finished epoch 16
# MODEL TEST (W/L/T): (580, 283, 1137)
# # Training Examples 30213
# Finished epoch 17
# MODEL TEST (W/L/T): (577, 296, 1127)
# # Training Examples 31904
# Finished epoch 18
# MODEL TEST (W/L/T): (559, 303, 1138)
# # Training Examples 33263
# Finished epoch 19
# MODEL TEST (W/L/T): (540, 325, 1135)
# # Training Examples 34901
# Finished epoch 20
# MODEL TEST (W/L/T): (565, 263, 1172)
# # Training Examples 36256
# Finished epoch 21
# MODEL TEST (W/L/T): (576, 286, 1138)
# # Training Examples 37593
# Finished epoch 22
# MODEL TEST (W/L/T): (582, 274, 1144)
# # Training Examples 38968
# Finished epoch 23
# MODEL TEST (W/L/T): (572, 235, 1193)
# # Training Examples 40732
# Finished epoch 24
# MODEL TEST (W/L/T): (575, 230, 1195)
# # Training Examples 42471
# Finished epoch 25
# MODEL TEST (W/L/T): (606, 253, 1141)
# # Training Examples 44192
# Finished epoch 26
# MODEL TEST (W/L/T): (632, 219, 1149)
# # Training Examples 45550
# Finished epoch 27
# MODEL TEST (W/L/T): (637, 182, 1181)
# # Training Examples 47171
# Finished epoch 28
# MODEL TEST (W/L/T): (623, 173, 1204)
# # Training Examples 48870
# Finished epoch 29
# MODEL TEST (W/L/T): (641, 128, 1231)
# # Training Examples 50473
# Finished epoch 30
# MODEL TEST (W/L/T): (621, 125, 1254)
# # Training Examples 52063
# Finished epoch 31
# MODEL TEST (W/L/T): (621, 122, 1257)
# # Training Examples 53463
# Finished epoch 32
# MODEL TEST (W/L/T): (620, 259, 1121)
# # Training Examples 55090
# Finished epoch 33
# MODEL TEST (W/L/T): (632, 270, 1098)
# # Training Examples 56711
# Finished epoch 34
# MODEL TEST (W/L/T): (644, 278, 1078)
# # Training Examples 58332
# Finished epoch 35
# MODEL TEST (W/L/T): (647, 259, 1094)
# # Training Examples 59946
# Finished epoch 36
# MODEL TEST (W/L/T): (659, 180, 1161)
# # Training Examples 61330
# Finished epoch 37
# MODEL TEST (W/L/T): (659, 184, 1157)
# # Training Examples 62707
# Finished epoch 38
# MODEL TEST (W/L/T): (647, 177, 1176)
# # Training Examples 64321
# Finished epoch 39
# MODEL TEST (W/L/T): (634, 188, 1178)
# # Training Examples 66043
# Finished epoch 40
# MODEL TEST (W/L/T): (649, 189, 1162)
# # Training Examples 67763
# Finished epoch 41
# MODEL TEST (W/L/T): (669, 203, 1128)
# # Training Examples 69479
# Finished epoch 42
# MODEL TEST (W/L/T): (666, 170, 1164)
# # Training Examples 71196
# Finished epoch 43
# MODEL TEST (W/L/T): (657, 168, 1175)
# # Training Examples 72776
# Finished epoch 44
# MODEL TEST (W/L/T): (673, 171, 1156)
# # Training Examples 74346
# Finished epoch 45
# MODEL TEST (W/L/T): (678, 174, 1148)
# # Training Examples 75933
# Finished epoch 46
# MODEL TEST (W/L/T): (682, 154, 1164)
# # Training Examples 77517
# Finished epoch 47
# MODEL TEST (W/L/T): (691, 143, 1166)
# # Training Examples 79122
# Finished epoch 48
# MODEL TEST (W/L/T): (683, 178, 1139)
# # Training Examples 80734
# Finished epoch 49
# MODEL TEST (W/L/T): (694, 180, 1126)
# # Training Examples 82332
# Finished epoch 50
# MODEL TEST (W/L/T): (687, 156, 1157)
# # Training Examples 84026
# Finished epoch 51
# MODEL TEST (W/L/T): (682, 205, 1113)
# # Training Examples 85393
# Finished epoch 52
# MODEL TEST (W/L/T): (697, 201, 1102)
# # Training Examples 87095
# Finished epoch 53
# MODEL TEST (W/L/T): (706, 206, 1088)
# # Training Examples 88476
# Finished epoch 54
# MODEL TEST (W/L/T): (695, 219, 1086)
# # Training Examples 90178
# Finished epoch 55
# MODEL TEST (W/L/T): (690, 221, 1089)
# # Training Examples 91880
# Finished epoch 56
# MODEL TEST (W/L/T): (701, 215, 1084)
# # Training Examples 93577
# Finished epoch 57
# MODEL TEST (W/L/T): (710, 215, 1075)
# # Training Examples 95274
# Finished epoch 58
# MODEL TEST (W/L/T): (709, 198, 1093)
# # Training Examples 96967
# Finished epoch 59
# MODEL TEST (W/L/T): (713, 200, 1087)
# # Training Examples 98662
# Finished epoch 60
# MODEL TEST (W/L/T): (709, 198, 1093)
# # Training Examples 100357
# Finished epoch 61
# MODEL TEST (W/L/T): (593, 213, 1194)
# # Training Examples 102113
# Finished epoch 62
# MODEL TEST (W/L/T): (679, 184, 1137)
# # Training Examples 103822
# Finished epoch 63
# MODEL TEST (W/L/T): (700, 152, 1148)
# # Training Examples 105523
# Finished epoch 64
# MODEL TEST (W/L/T): (712, 126, 1162)
# # Training Examples 107211
# Finished epoch 65
# MODEL TEST (W/L/T): (716, 137, 1147)
# # Training Examples 108900
# Finished epoch 66
# MODEL TEST (W/L/T): (722, 138, 1140)
# # Training Examples 110583
# Finished epoch 67
# MODEL TEST (W/L/T): (728, 132, 1140)
# # Training Examples 112261
# Finished epoch 68
# MODEL TEST (W/L/T): (717, 142, 1141)
# # Training Examples 113946
# Finished epoch 69
# MODEL TEST (W/L/T): (721, 133, 1146)
# # Training Examples 115639
# Finished epoch 70
# MODEL TEST (W/L/T): (726, 132, 1142)
# # Training Examples 117317
# Finished epoch 71
# MODEL TEST (W/L/T): (745, 132, 1123)
# # Training Examples 118999
# Finished epoch 72
# MODEL TEST (W/L/T): (747, 142, 1111)
# # Training Examples 120688
# Finished epoch 73
# MODEL TEST (W/L/T): (752, 137, 1111)
# # Training Examples 122392
# Finished epoch 74
# MODEL TEST (W/L/T): (750, 140, 1110)
# # Training Examples 124088
# Finished epoch 75
# MODEL TEST (W/L/T): (753, 153, 1094)
# # Training Examples 125787
# Finished epoch 76
# MODEL TEST (W/L/T): (755, 128, 1117)
# # Training Examples 127484
# Finished epoch 77
# MODEL TEST (W/L/T): (750, 126, 1124)
# # Training Examples 129181
# Finished epoch 78
# MODEL TEST (W/L/T): (729, 132, 1139)
# # Training Examples 130880
# Finished epoch 79
# MODEL TEST (W/L/T): (729, 128, 1143)
# # Training Examples 132568
# Finished epoch 80
# MODEL TEST (W/L/T): (735, 143, 1122)
# # Training Examples 134271
# Finished epoch 81
# MODEL TEST (W/L/T): (734, 137, 1129)
# # Training Examples 135978
# Finished epoch 82
# MODEL TEST (W/L/T): (738, 151, 1111)
# # Training Examples 137689
# Finished epoch 83
# MODEL TEST (W/L/T): (742, 143, 1115)
# # Training Examples 139401
# Finished epoch 84
# MODEL TEST (W/L/T): (713, 140, 1147)
# # Training Examples 141146
# Finished epoch 85
# MODEL TEST (W/L/T): (713, 136, 1151)
# # Training Examples 142891
# Finished epoch 86
# MODEL TEST (W/L/T): (718, 148, 1134)
# # Training Examples 144627
# Finished epoch 87
# MODEL TEST (W/L/T): (754, 158, 1088)
# # Training Examples 146336
# Finished epoch 88
# MODEL TEST (W/L/T): (755, 158, 1087)
# # Training Examples 148045
# Finished epoch 89
# MODEL TEST (W/L/T): (747, 170, 1083)
# # Training Examples 149424
# Finished epoch 90
# MODEL TEST (W/L/T): (749, 168, 1083)
# # Training Examples 150797
# Finished epoch 91
# MODEL TEST (W/L/T): (745, 188, 1067)
# # Training Examples 152141
# Finished epoch 92
# MODEL TEST (W/L/T): (745, 195, 1060)
# # Training Examples 153485
# Finished epoch 93
# MODEL TEST (W/L/T): (734, 187, 1079)
# # Training Examples 154836
# Finished epoch 94
# MODEL TEST (W/L/T): (735, 181, 1084)
# # Training Examples 156194
# Finished epoch 95
# MODEL TEST (W/L/T): (724, 177, 1099)
# # Training Examples 157549
# Finished epoch 96
# MODEL TEST (W/L/T): (722, 178, 1100)
# # Training Examples 158900
# Finished epoch 97
# MODEL TEST (W/L/T): (734, 164, 1102)
# # Training Examples 160261
# Finished epoch 98
# MODEL TEST (W/L/T): (733, 191, 1076)
# # Training Examples 161993
# Finished epoch 99
# MODEL TEST (W/L/T): (726, 200, 1074)
# # Training Examples 163731
# Finished epoch 100
# MODEL TEST (W/L/T): (726, 225, 1049)
# # Training Examples 165467
# Finished epoch 101
# MODEL TEST (W/L/T): (741, 231, 1028)
# # Training Examples 167204
# Finished epoch 102
# MODEL TEST (W/L/T): (743, 225, 1032)
# # Training Examples 168932
# Finished epoch 103
# MODEL TEST (W/L/T): (743, 253, 1004)
# # Training Examples 170665
# Finished epoch 104
# MODEL TEST (W/L/T): (741, 249, 1010)
# # Training Examples 172290
# Finished epoch 105
# MODEL TEST (W/L/T): (744, 244, 1012)
# # Training Examples 173913
# Finished epoch 106
# MODEL TEST (W/L/T): (742, 230, 1028)
# # Training Examples 175519
# Finished epoch 107
# MODEL TEST (W/L/T): (765, 214, 1021)
# # Training Examples 177126
# Finished epoch 108
# MODEL TEST (W/L/T): (758, 215, 1027)
# # Training Examples 178734
# Finished epoch 109
# MODEL TEST (W/L/T): (761, 195, 1044)
# # Training Examples 180342
# Finished epoch 110
# MODEL TEST (W/L/T): (761, 207, 1032)
# # Training Examples 181949
# Finished epoch 111
# MODEL TEST (W/L/T): (765, 177, 1058)
# # Training Examples 183667
# Finished epoch 112
# MODEL TEST (W/L/T): (767, 178, 1055)
# # Training Examples 185383
# Finished epoch 113
# MODEL TEST (W/L/T): (769, 180, 1051)
# # Training Examples 187090
# Finished epoch 114
# MODEL TEST (W/L/T): (781, 198, 1021)
# # Training Examples 188796
# Finished epoch 115
# MODEL TEST (W/L/T): (770, 194, 1036)
# # Training Examples 190503
# Finished epoch 116
# MODEL TEST (W/L/T): (781, 195, 1024)
# # Training Examples 191830
# Finished epoch 117
# MODEL TEST (W/L/T): (789, 190, 1021)
# # Training Examples 193155
# Finished epoch 118
# MODEL TEST (W/L/T): (789, 194, 1017)
# # Training Examples 194476
# Finished epoch 119
# MODEL TEST (W/L/T): (790, 201, 1009)
# # Training Examples 195805
# Finished epoch 120
# MODEL TEST (W/L/T): (788, 176, 1036)
# # Training Examples 197147
# Finished epoch 121
# MODEL TEST (W/L/T): (782, 191, 1027)
# # Training Examples 198483
# Finished epoch 122
# MODEL TEST (W/L/T): (777, 186, 1037)
# # Training Examples 199860
# Finished epoch 123
# MODEL TEST (W/L/T): (773, 175, 1052)
# # Training Examples 201581
# Finished epoch 124
# MODEL TEST (W/L/T): (778, 178, 1044)
# # Training Examples 202969
# Finished epoch 125
# MODEL TEST (W/L/T): (785, 172, 1043)
# # Training Examples 204347
# Finished epoch 126
# MODEL TEST (W/L/T): (787, 164, 1049)
# # Training Examples 205718
# Finished epoch 127
# MODEL TEST (W/L/T): (772, 160, 1068)
# # Training Examples 207067
# Finished epoch 128
# MODEL TEST (W/L/T): (772, 163, 1065)
# # Training Examples 208417
# Finished epoch 129
# MODEL TEST (W/L/T): (768, 174, 1058)
# # Training Examples 210026
# Finished epoch 130
# MODEL TEST (W/L/T): (763, 171, 1066)
# # Training Examples 211630
# Finished epoch 131
# MODEL TEST (W/L/T): (778, 162, 1060)
# # Training Examples 213014
# Finished epoch 132
# MODEL TEST (W/L/T): (766, 172, 1062)
# # Training Examples 214391
# Finished epoch 133
# MODEL TEST (W/L/T): (777, 162, 1061)
# # Training Examples 215741
# Finished epoch 134
# MODEL TEST (W/L/T): (776, 156, 1068)
# # Training Examples 217091
# Finished epoch 135
# MODEL TEST (W/L/T): (711, 267, 1022)
# # Training Examples 218800
# Finished epoch 136
# MODEL TEST (W/L/T): (729, 261, 1010)
# # Training Examples 220541
# Finished epoch 137
# MODEL TEST (W/L/T): (759, 251, 990)
# # Training Examples 222297
# Finished epoch 138
# MODEL TEST (W/L/T): (775, 259, 966)
# # Training Examples 223968
# Finished epoch 139
# MODEL TEST (W/L/T): (778, 253, 969)
# # Training Examples 225639
# Finished epoch 140
# MODEL TEST (W/L/T): (780, 238, 982)
# # Training Examples 227341
# Finished epoch 141
# MODEL TEST (W/L/T): (796, 238, 966)
# # Training Examples 228691
# Finished epoch 142
# MODEL TEST (W/L/T): (782, 231, 987)
# # Training Examples 230032
# Finished epoch 143
# MODEL TEST (W/L/T): (779, 224, 997)
# # Training Examples 231730
# Finished epoch 144
# MODEL TEST (W/L/T): (779, 198, 1023)
# # Training Examples 233438
# Finished epoch 145
# MODEL TEST (W/L/T): (777, 177, 1046)
# # Training Examples 235153
# Finished epoch 146
# MODEL TEST (W/L/T): (785, 176, 1039)
# # Training Examples 236883
# Finished epoch 147
# MODEL TEST (W/L/T): (789, 171, 1040)
# # Training Examples 238495
# Finished epoch 148
# MODEL TEST (W/L/T): (793, 172, 1035)
# # Training Examples 240116
# Finished epoch 149
# MODEL TEST (W/L/T): (800, 172, 1028)
# # Training Examples 241737
# Finished epoch 150
# MODEL TEST (W/L/T): (807, 172, 1021)
# # Training Examples 243358
# Finished epoch 151
# MODEL TEST (W/L/T): (809, 172, 1019)
# # Training Examples 244976
# Finished epoch 152
# MODEL TEST (W/L/T): (807, 178, 1015)
# # Training Examples 246693
# Finished epoch 153
# MODEL TEST (W/L/T): (803, 192, 1005)
# # Training Examples 248432
# Finished epoch 154
# MODEL TEST (W/L/T): (802, 194, 1004)
# # Training Examples 250171
# Finished epoch 155
# MODEL TEST (W/L/T): (800, 189, 1011)
# # Training Examples 251897
# Finished epoch 156
# MODEL TEST (W/L/T): (796, 182, 1022)
# # Training Examples 253623
# Finished epoch 157
# MODEL TEST (W/L/T): (798, 209, 993)
# # Training Examples 255377
# Finished epoch 158
# MODEL TEST (W/L/T): (795, 206, 999)
# # Training Examples 257131
# Finished epoch 159
# MODEL TEST (W/L/T): (796, 206, 998)
# # Training Examples 258885
# Finished epoch 160
# MODEL TEST (W/L/T): (799, 210, 991)
# # Training Examples 260614
# Finished epoch 161
# MODEL TEST (W/L/T): (799, 206, 995)
# # Training Examples 262343
# Finished epoch 162
# MODEL TEST (W/L/T): (803, 206, 991)
# # Training Examples 264071
# Finished epoch 163
# MODEL TEST (W/L/T): (821, 198, 981)
# # Training Examples 265426
# Finished epoch 164
# MODEL TEST (W/L/T): (816, 212, 972)
# # Training Examples 266777
# Finished epoch 165
# MODEL TEST (W/L/T): (796, 192, 1012)
# # Training Examples 268143
# Finished epoch 166
# MODEL TEST (W/L/T): (816, 151, 1033)
# # Training Examples 269499
# Finished epoch 167
# MODEL TEST (W/L/T): (816, 152, 1032)
# # Training Examples 270847
# Finished epoch 168
# MODEL TEST (W/L/T): (817, 153, 1030)
# # Training Examples 272181
# Finished epoch 169
# MODEL TEST (W/L/T): (819, 166, 1015)
# # Training Examples 273509
# Finished epoch 170
# MODEL TEST (W/L/T): (817, 166, 1017)
# # Training Examples 274855
# Finished epoch 171
# MODEL TEST (W/L/T): (815, 159, 1026)
# # Training Examples 276173
# Finished epoch 172
# MODEL TEST (W/L/T): (812, 153, 1035)
# # Training Examples 277488
# Finished epoch 173
# MODEL TEST (W/L/T): (808, 150, 1042)
# # Training Examples 278818
# Finished epoch 174
# MODEL TEST (W/L/T): (805, 150, 1045)
# # Training Examples 280162
# Finished epoch 175
# MODEL TEST (W/L/T): (814, 181, 1005)
# # Training Examples 281513
# Finished epoch 176
# MODEL TEST (W/L/T): (807, 183, 1010)
# # Training Examples 282868
# Finished epoch 177
# MODEL TEST (W/L/T): (808, 182, 1010)
# # Training Examples 284218
# Finished epoch 178
# MODEL TEST (W/L/T): (802, 172, 1026)
# # Training Examples 285567
# Finished epoch 179
# MODEL TEST (W/L/T): (793, 131, 1076)
# # Training Examples 287274
# Finished epoch 180
# MODEL TEST (W/L/T): (807, 137, 1056)
# # Training Examples 288960
# Finished epoch 181
# MODEL TEST (W/L/T): (814, 141, 1045)
# # Training Examples 290653
# Finished epoch 182
# MODEL TEST (W/L/T): (830, 135, 1035)
# # Training Examples 292345
# Finished epoch 183
# MODEL TEST (W/L/T): (833, 132, 1035)
# # Training Examples 294038
# Finished epoch 184
# MODEL TEST (W/L/T): (834, 133, 1033)
# # Training Examples 295731
# Finished epoch 185
# MODEL TEST (W/L/T): (832, 127, 1041)
# # Training Examples 297424
# Finished epoch 186
# MODEL TEST (W/L/T): (825, 128, 1047)
# # Training Examples 299132
# Finished epoch 187
# MODEL TEST (W/L/T): (834, 136, 1030)
# # Training Examples 300819
# Finished epoch 188
# MODEL TEST (W/L/T): (834, 138, 1028)
# # Training Examples 302506
# Finished epoch 189
# MODEL TEST (W/L/T): (835, 135, 1030)
# # Training Examples 304194
# Finished epoch 190
# MODEL TEST (W/L/T): (823, 127, 1050)
# # Training Examples 305903
# Finished epoch 191
# MODEL TEST (W/L/T): (835, 125, 1040)
# # Training Examples 307616
# Finished epoch 192
# MODEL TEST (W/L/T): (834, 120, 1046)
# # Training Examples 309329
# Finished epoch 193
# MODEL TEST (W/L/T): (820, 120, 1060)
# # Training Examples 311038
# Finished epoch 194
# MODEL TEST (W/L/T): (822, 117, 1061)
# # Training Examples 312759
# Finished epoch 195
# MODEL TEST (W/L/T): (824, 118, 1058)
# # Training Examples 314482
# Finished epoch 196
# MODEL TEST (W/L/T): (824, 115, 1061)
# # Training Examples 316189
# Finished epoch 197
# MODEL TEST (W/L/T): (821, 113, 1066)
# # Training Examples 317909
# Finished epoch 198
# MODEL TEST (W/L/T): (819, 113, 1068)
# # Training Examples 319606
# Finished epoch 199
# MODEL TEST (W/L/T): (820, 111, 1069)
# # Training Examples 321316
# Finished epoch 200
# MODEL TEST (W/L/T): (822, 112, 1066)
# # Training Examples 323013
# Finished epoch 201
# MODEL TEST (W/L/T): (819, 110, 1071)
# # Training Examples 324716
# Finished epoch 202
# MODEL TEST (W/L/T): (819, 113, 1068)
# # Training Examples 326419
# Finished epoch 203
# MODEL TEST (W/L/T): (820, 110, 1070)
# # Training Examples 328122
# Finished epoch 204
# MODEL TEST (W/L/T): (822, 110, 1068)
# # Training Examples 329829
# Finished epoch 205
# MODEL TEST (W/L/T): (822, 109, 1069)
# # Training Examples 331532
# Finished epoch 206
# MODEL TEST (W/L/T): (823, 108, 1069)
# # Training Examples 333239
# Finished epoch 207
# MODEL TEST (W/L/T): (825, 108, 1067)
# # Training Examples 334946
# Finished epoch 208
# MODEL TEST (W/L/T): (826, 109, 1065)
# # Training Examples 336653
# Finished epoch 209
# MODEL TEST (W/L/T): (828, 105, 1067)
# # Training Examples 338360
# Finished epoch 210
# MODEL TEST (W/L/T): (813, 105, 1082)
# # Training Examples 340057
# Finished epoch 211
# MODEL TEST (W/L/T): (812, 105, 1083)
# # Training Examples 341754
# Finished epoch 212
# MODEL TEST (W/L/T): (809, 109, 1082)
# # Training Examples 343451
# Finished epoch 213
# MODEL TEST (W/L/T): (810, 103, 1087)
# # Training Examples 345148
# Finished epoch 214
# MODEL TEST (W/L/T): (805, 81, 1114)
# # Training Examples 346857
# Finished epoch 215
# MODEL TEST (W/L/T): (803, 102, 1095)
# # Training Examples 348556
# Finished epoch 216
# MODEL TEST (W/L/T): (803, 99, 1098)
# # Training Examples 350255
# Finished epoch 217
# MODEL TEST (W/L/T): (802, 98, 1100)
# # Training Examples 351954
# Finished epoch 218
# MODEL TEST (W/L/T): (805, 99, 1096)
# # Training Examples 353653
# Finished epoch 219
# MODEL TEST (W/L/T): (803, 100, 1097)
# # Training Examples 355352
# Finished epoch 220
# MODEL TEST (W/L/T): (793, 97, 1110)
# # Training Examples 357082
# Finished epoch 221
# MODEL TEST (W/L/T): (808, 100, 1092)
# # Training Examples 358781
# Finished epoch 222
# MODEL TEST (W/L/T): (805, 78, 1117)
# # Training Examples 360491
# Finished epoch 223
# MODEL TEST (W/L/T): (807, 94, 1099)
# # Training Examples 362195
# Finished epoch 224
# MODEL TEST (W/L/T): (807, 80, 1113)
# # Training Examples 363905
# Finished epoch 225
# MODEL TEST (W/L/T): (802, 80, 1118)
# # Training Examples 365615
# Finished epoch 226
# MODEL TEST (W/L/T): (803, 80, 1117)
# # Training Examples 367325
# Finished epoch 227
# MODEL TEST (W/L/T): (804, 79, 1117)
# # Training Examples 369035
# Finished epoch 228
# MODEL TEST (W/L/T): (802, 77, 1121)
# # Training Examples 370745
# Finished epoch 229
# MODEL TEST (W/L/T): (803, 69, 1128)
# # Training Examples 372455
# Finished epoch 230
# MODEL TEST (W/L/T): (798, 70, 1132)
# # Training Examples 374165
# Finished epoch 231
# MODEL TEST (W/L/T): (797, 71, 1132)
# # Training Examples 375875
# Finished epoch 232
# MODEL TEST (W/L/T): (796, 69, 1135)
# # Training Examples 377585
# Finished epoch 233
# MODEL TEST (W/L/T): (797, 68, 1135)
# # Training Examples 379295
# Finished epoch 234
# MODEL TEST (W/L/T): (797, 66, 1137)
# # Training Examples 380998
# Finished epoch 235
# MODEL TEST (W/L/T): (812, 105, 1083)
# # Training Examples 382715
# Finished epoch 236
# MODEL TEST (W/L/T): (816, 104, 1080)
# # Training Examples 384423
# Finished epoch 237
# MODEL TEST (W/L/T): (815, 106, 1079)
# # Training Examples 386142
# Finished epoch 238
# MODEL TEST (W/L/T): (814, 106, 1080)
# # Training Examples 387852
# Finished epoch 239
# MODEL TEST (W/L/T): (814, 105, 1081)
# # Training Examples 389562
# Finished epoch 240
# MODEL TEST (W/L/T): (795, 106, 1099)
# # Training Examples 391272
# Finished epoch 241
# MODEL TEST (W/L/T): (793, 105, 1102)
# # Training Examples 392982
# Finished epoch 242
# MODEL TEST (W/L/T): (790, 104, 1106)
# # Training Examples 394692
# Finished epoch 243
# MODEL TEST (W/L/T): (790, 103, 1107)
# # Training Examples 396402
# Finished epoch 244
# MODEL TEST (W/L/T): (790, 103, 1107)
# # Training Examples 398112
# Finished epoch 245
# MODEL TEST (W/L/T): (788, 103, 1109)
# # Training Examples 399822
# Finished epoch 246
# MODEL TEST (W/L/T): (786, 103, 1111)
# # Training Examples 401525
# Finished epoch 247
# MODEL TEST (W/L/T): (782, 100, 1118)
# # Training Examples 403228
# Finished epoch 248
# MODEL TEST (W/L/T): (787, 100, 1113)
# # Training Examples 404932
# Finished epoch 249
# MODEL TEST (W/L/T): (804, 100, 1096)
# # Training Examples 406634
# Finished epoch 250
# MODEL TEST (W/L/T): (804, 100, 1096)
# # Training Examples 408336
# Finished epoch 251
# MODEL TEST (W/L/T): (817, 98, 1085)
# # Training Examples 410038
# Finished epoch 252
# MODEL TEST (W/L/T): (817, 98, 1085)
# # Training Examples 411740
# Finished epoch 253
# MODEL TEST (W/L/T): (819, 94, 1087)
# # Training Examples 413442
# Finished epoch 254
# MODEL TEST (W/L/T): (819, 94, 1087)
# # Training Examples 415149
# Finished epoch 255
# MODEL TEST (W/L/T): (818, 95, 1087)
# # Training Examples 416856
# Finished epoch 256
# MODEL TEST (W/L/T): (818, 95, 1087)
# # Training Examples 418570
# Finished epoch 257
# MODEL TEST (W/L/T): (819, 99, 1082)
# # Training Examples 420286
# Finished epoch 258
# MODEL TEST (W/L/T): (820, 100, 1080)
# # Training Examples 422002
# Finished epoch 259
# MODEL TEST (W/L/T): (819, 100, 1081)
# # Training Examples 423327
# Finished epoch 260
# MODEL TEST (W/L/T): (819, 100, 1081)
# # Training Examples 424652
# Finished epoch 261
# MODEL TEST (W/L/T): (823, 103, 1074)
# # Training Examples 425995
# Finished epoch 262
# MODEL TEST (W/L/T): (818, 67, 1115)
# # Training Examples 427354
# Finished epoch 263
# MODEL TEST (W/L/T): (823, 87, 1090)
# # Training Examples 428710
# Finished epoch 264
# MODEL TEST (W/L/T): (820, 90, 1090)
# # Training Examples 430081
# Finished epoch 265
# MODEL TEST (W/L/T): (326, 325, 1349)
# # Training Examples 431827
# Finished epoch 266
# MODEL TEST (W/L/T): (601, 229, 1170)
# # Training Examples 433540
# Finished epoch 267
# MODEL TEST (W/L/T): (698, 281, 1021)
# # Training Examples 435278
# Finished epoch 268
# MODEL TEST (W/L/T): (722, 259, 1019)
# # Training Examples 436598
# Finished epoch 269
# MODEL TEST (W/L/T): (750, 275, 975)
# # Training Examples 437880
# Finished epoch 270
# MODEL TEST (W/L/T): (764, 167, 1069)
# # Training Examples 439198
# Finished epoch 271
# MODEL TEST (W/L/T): (773, 129, 1098)
# # Training Examples 440520
# Finished epoch 272
# MODEL TEST (W/L/T): (824, 115, 1061)
# # Training Examples 442089
# Finished epoch 273
# MODEL TEST (W/L/T): (823, 138, 1039)
# # Training Examples 443638
# Finished epoch 274
# MODEL TEST (W/L/T): (822, 142, 1036)
# # Training Examples 445193
# Finished epoch 275
# MODEL TEST (W/L/T): (845, 142, 1013)
# # Training Examples 446480
# Finished epoch 276
# MODEL TEST (W/L/T): (850, 182, 968)
# # Training Examples 447758
# Finished epoch 277
# MODEL TEST (W/L/T): (838, 151, 1011)
# # Training Examples 449065
# Finished epoch 278
# MODEL TEST (W/L/T): (836, 133, 1031)
# # Training Examples 450736
# Finished epoch 279
# MODEL TEST (W/L/T): (842, 138, 1020)
# # Training Examples 452407
# Finished epoch 280
# MODEL TEST (W/L/T): (844, 134, 1022)
# # Training Examples 454071
# Finished epoch 281
# MODEL TEST (W/L/T): (844, 124, 1032)
# # Training Examples 455743
# Finished epoch 282
# MODEL TEST (W/L/T): (841, 154, 1005)
# # Training Examples 457316
# Finished epoch 283
# MODEL TEST (W/L/T): (843, 138, 1019)
# # Training Examples 458898
# Finished epoch 284
# MODEL TEST (W/L/T): (842, 129, 1029)
# # Training Examples 460479
# Finished epoch 285
# MODEL TEST (W/L/T): (840, 118, 1042)
# # Training Examples 462079
# Finished epoch 286
# MODEL TEST (W/L/T): (824, 119, 1057)
# # Training Examples 463675
# Finished epoch 287
# MODEL TEST (W/L/T): (830, 114, 1056)
# # Training Examples 465275
# Finished epoch 288
# MODEL TEST (W/L/T): (826, 118, 1056)
# # Training Examples 466873
# Finished epoch 289
# MODEL TEST (W/L/T): (826, 111, 1063)
# # Training Examples 468472
# Finished epoch 290
# MODEL TEST (W/L/T): (825, 121, 1054)
# # Training Examples 470071
# Finished epoch 291
# MODEL TEST (W/L/T): (824, 114, 1062)
# # Training Examples 471669
# Finished epoch 292
# MODEL TEST (W/L/T): (827, 116, 1057)
# # Training Examples 473267
# Finished epoch 293
# MODEL TEST (W/L/T): (832, 109, 1059)
# # Training Examples 474874
# Finished epoch 294
# MODEL TEST (W/L/T): (832, 104, 1064)
# # Training Examples 476491
# Finished epoch 295
# MODEL TEST (W/L/T): (856, 91, 1053)
# # Training Examples 478113
# Finished epoch 296
# MODEL TEST (W/L/T): (853, 101, 1046)
# # Training Examples 479793
# Finished epoch 297
# MODEL TEST (W/L/T): (849, 112, 1039)
# # Training Examples 481473
# Finished epoch 298
# MODEL TEST (W/L/T): (854, 108, 1038)
# # Training Examples 483153
# Finished epoch 299
# MODEL TEST (W/L/T): (852, 101, 1047)
# # Training Examples 484836
# Finished epoch 300
# MODEL TEST (W/L/T): (854, 101, 1045)
# # Training Examples 486519
# Finished epoch 301
# MODEL TEST (W/L/T): (857, 103, 1040)
# # Training Examples 488202
# Finished epoch 302
# MODEL TEST (W/L/T): (856, 101, 1043)
# # Training Examples 489895
# Finished epoch 303
# MODEL TEST (W/L/T): (846, 98, 1056)
# # Training Examples 491581
# Finished epoch 304
# MODEL TEST (W/L/T): (839, 104, 1057)
# # Training Examples 493196
# Finished epoch 305
# MODEL TEST (W/L/T): (840, 103, 1057)
# # Training Examples 494927
# Finished epoch 306
# MODEL TEST (W/L/T): (839, 97, 1064)
# # Training Examples 496664
# Finished epoch 307
# MODEL TEST (W/L/T): (836, 95, 1069)
# # Training Examples 498382
# Finished epoch 308
# MODEL TEST (W/L/T): (842, 98, 1060)
# # Training Examples 500100
# Finished epoch 309
# MODEL TEST (W/L/T): (838, 100, 1062)
# # Training Examples 501816
# Finished epoch 310
# MODEL TEST (W/L/T): (835, 99, 1066)
# # Training Examples 503532
# Finished epoch 311
# MODEL TEST (W/L/T): (835, 94, 1071)
# # Training Examples 505248
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-cbfc0e71083a> in <module>()
#      46     X_train = X_train[-640000:]
#      47     Y_train = Y_train[-640000:]
# ---> 48     history = model.fit(numpy.array(X_train), numpy.array(Y_train), nb_epoch=50, shuffle=True, batch_size=1024, verbose=0)
#      49     model = history.model
#      50     #DumpModel(model)
#
# /usr/local/lib/python3.5/site-packages/Keras-0.3.1-py3.5.egg/keras/models.py in fit(self, X, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, show_accuracy, class_weight, sample_weight)
#     604                          verbose=verbose, callbacks=callbacks,
#     605                          val_f=val_f, val_ins=val_ins,
# --> 606                          shuffle=shuffle, metrics=metrics)
#     607
#     608     def predict(self, X, batch_size=128, verbose=0):
#
# /usr/local/lib/python3.5/site-packages/Keras-0.3.1-py3.5.egg/keras/models.py in _fit(self, f, ins, out_labels, batch_size, nb_epoch, verbose, callbacks, val_f, val_ins, shuffle, metrics)
#     249                 batch_logs['size'] = len(batch_ids)
#     250                 callbacks.on_batch_begin(batch_index, batch_logs)
# --> 251                 outs = f(ins_batch)
#     252                 if type(outs) != list:
#     253                     outs = [outs]
#
# /usr/local/lib/python3.5/site-packages/Keras-0.3.1-py3.5.egg/keras/backend/theano_backend.py in __call__(self, inputs)
#     391     def __call__(self, inputs):
#     392         assert type(inputs) in {list, tuple}
# --> 393         return self.function(*inputs)
#     394
#     395
#
# /usr/local/lib/python3.5/site-packages/theano/compile/function_module.py in __call__(self, *args, **kwargs)
#     857         t0_fn = time.time()
#     858         try:
# --> 859             outputs = self.fn()
#     860         except Exception:
#     861             if hasattr(self.fn, 'position_of_error'):
#
# KeyboardInterrupt:
